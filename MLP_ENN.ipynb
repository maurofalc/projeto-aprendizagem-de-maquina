# %%
import pandas as pd
import numpy as np
from keras.utils import np_utils
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import roc_auc_score,confusion_matrix, accuracy_score, make_scorer, f1_score,precision_score,recall_score, plot_confusion_matrix
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
from imblearn.under_sampling import EditedNearestNeighbours
from collections import Counter
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
def print_distribution(arr, print_nl=True):
    arr = np.unique(arr, return_counts=True)[1] / len(arr)
    for i in range(arr.shape[0]):
        print("Classe %d: %.2f%%" %(i, arr[i]*100))

    if print_nl:
        print("\n")

# %%
def taste(quality):
  if quality <= 5:
    return 0
  elif quality == 6:
    return 1
  else:
    return 2

# %%
data = pd.read_csv("wine_quality.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed.acidity         6497 non-null   float64
#  1   volatile.acidity      6497 non-null   float64
#  2   citric.acid           6497 non-null   float64
#  3   residual.sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free.sulfur.dioxide   6497 non-null   float64
#  6   total.sulfur.dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 609.2 KB

# %%
new_data = data
new_data["taste"] = data["quality"].apply(taste)

# %%
new_data
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  taste
# 0         9.4        5      0
# 1         9.8        5      0
# 2         9.8        5      0
# 3         9.8        6      1
# 4         9.4        5      0
# ...       ...      ...    ...
# 6492     11.2        6      1
# 6493      9.6        5      0
# 6494      9.4        6      1
# 6495     12.8        7      2
# 6496     11.8        6      1
#
# [6497 rows x 13 columns]

# %% [markdown]
# ## Divisão de base de dados e separação de base

# %%
X = new_data.iloc[:, 0:11].values
y = new_data.iloc[:, 12].values

# %%
scaler = MinMaxScaler()
scaler.fit(X)
print(scaler.data_max_)
X_normalized = scaler.transform(X)
print(X_normalized)
# Out:
# [ 15.9       1.58      1.66     65.8       0.611   289.      440.
#    1.03898   4.01      2.       14.9    ]
# [[0.29752066 0.41333333 0.         ... 0.6124031  0.19101124 0.20289855]
#  [0.33057851 0.53333333 0.         ... 0.37209302 0.25842697 0.26086957]
#  [0.33057851 0.45333333 0.02409639 ... 0.41860465 0.24157303 0.26086957]
#  ...
#  [0.2231405  0.10666667 0.11445783 ... 0.20930233 0.13483146 0.20289855]
#  [0.14049587 0.14       0.18072289 ... 0.48062016 0.08988764 0.69565217]
#  [0.18181818 0.08666667 0.22891566 ... 0.41860465 0.05617978 0.55072464]]

# %%
print("Proporções por classe no dataset em geral:")
print_distribution(y)

kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=199)
fold = 0
for train, test in kf.split(X_normalized, y):
    print("Fold %d" %(fold))
    print_distribution(y[train], print_nl=(fold != 2))
    fold += 1
# Out:
# Proporções por classe no dataset em geral:
# Classe 0: 36.69%
# Classe 1: 43.65%
# Classe 2: 19.66%
#
#
# Fold 0
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 1
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 2
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
# Fold 3
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 4
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 5
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 6
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 7
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 8
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 9
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%

# %%
kf_accuracy = list()
kf_conf_mat = list()
kf_precision = list()
kf_f1 = list()
kf_recall = list()
kf_roc = list()

# %%
enn = EditedNearestNeighbours(sampling_strategy='all', n_neighbors=1, kind_sel='all', n_jobs=-1)

# %% [markdown]
# ## Laço para execução do gridsearch em cada fold

# %%
for train_ix, test_ix in kf.split(X_normalized,y):
    X_train, X_test = X_normalized[train_ix, :], X_normalized[test_ix, :]
    y_train, y_test = y[train_ix], y[test_ix]
    X_train_res, y_train_res = enn.fit_resample(X_train, y_train)
    model = Sequential()
    model.add(Dense(units=16, activation="linear",input_dim=11))
    model.add(Dropout(0.1))
    model.add(Dense(units=16, activation="linear"))
    model.add(Dropout(0.1))
    model.add(Dense(units=3, activation="softmax"))
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"])
    # executar treinamento do modelo
    result = model.fit(X_train_res, y_train_res, batch_size=32, epochs=20)
    # teste dos melhores parâmetros
    predicted_y = model.predict(X_test)
    predicted_y_transform = [np.argmax(t) for t in predicted_y]
    #transformação de itens para cálculo do ROC
    le = LabelEncoder()
    y_test_dummy = le.fit_transform(y_test)
    predicted_y_dummy = le.fit_transform(predicted_y_transform)
    y_test_dummy = np_utils.to_categorical(y_test)
    predicted_y_dummy = np_utils.to_categorical(predicted_y_dummy)
    # métricas do modelo
    acc = accuracy_score(y_test, predicted_y_transform)
    conf_mat = confusion_matrix(y_test, predicted_y_transform)
    f1 = f1_score(y_test, predicted_y_transform, average = "macro")
    recall = recall_score(y_test, predicted_y_transform, average = "macro")
    roc = roc_auc_score(y_test_dummy,predicted_y_dummy,multi_class="ovo",average = "macro")
    #armazenamento de métricas
    kf_accuracy.append(acc)
    kf_conf_mat.append(conf_mat)
    kf_f1.append(f1)
    kf_recall.append(recall)
    kf_roc.append(roc)
    #métricas
    print(">acc=%.4f,>f1=%.4f,>rec=%.4f,>roc=%.4f" % (acc,f1,recall,roc))
    print(conf_mat)
# Out:
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 1.0300 - sparse_categorical_accuracy: 0.4748
# Epoch 2/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.9264 - sparse_categorical_accuracy: 0.5631
# Epoch 3/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8607 - sparse_categorical_accuracy: 0.5823
# Epoch 4/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8380 - sparse_categorical_accuracy: 0.5993
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8253 - sparse_categorical_accuracy: 0.6060
# Epoch 6/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8213 - sparse_categorical_accuracy: 0.6057
# Epoch 7/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8141 - sparse_categorical_accuracy: 0.6157
# Epoch 8/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8060 - sparse_categorical_accuracy: 0.6197
# Epoch 9/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8072 - sparse_categorical_accuracy: 0.6177
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8043 - sparse_categorical_accuracy: 0.6207
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8073 - sparse_categorical_accuracy: 0.6172
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8061 - sparse_categorical_accuracy: 0.6207
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8069 - sparse_categorical_accuracy: 0.6175
# Epoch 14/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7995 - sparse_categorical_accuracy: 0.6172
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7999 - sparse_categorical_accuracy: 0.6264
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8023 - sparse_categorical_accuracy: 0.6197
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8019 - sparse_categorical_accuracy: 0.6175
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8017 - sparse_categorical_accuracy: 0.6212
# Epoch 19/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8014 - sparse_categorical_accuracy: 0.6200
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8045 - sparse_categorical_accuracy: 0.6180
# >acc=0.5677,>f1=0.5356,>rec=0.5264,>roc=0.6444
# [[160  77   2]
#  [ 82 169  32]
#  [  5  83  40]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 1.0027 - sparse_categorical_accuracy: 0.5084
# Epoch 2/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.9052 - sparse_categorical_accuracy: 0.5671
# Epoch 3/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8618 - sparse_categorical_accuracy: 0.5770
# Epoch 4/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8404 - sparse_categorical_accuracy: 0.5922
# Epoch 5/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8301 - sparse_categorical_accuracy: 0.5870
# Epoch 6/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8240 - sparse_categorical_accuracy: 0.6056
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8177 - sparse_categorical_accuracy: 0.6064
# Epoch 8/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8159 - sparse_categorical_accuracy: 0.6103
# Epoch 9/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8168 - sparse_categorical_accuracy: 0.6071
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8074 - sparse_categorical_accuracy: 0.6098
# Epoch 11/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8084 - sparse_categorical_accuracy: 0.6088
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8100 - sparse_categorical_accuracy: 0.6106
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8027 - sparse_categorical_accuracy: 0.6133
# Epoch 14/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8070 - sparse_categorical_accuracy: 0.6153
# Epoch 15/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8047 - sparse_categorical_accuracy: 0.6128
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8062 - sparse_categorical_accuracy: 0.6083
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8055 - sparse_categorical_accuracy: 0.6113
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8032 - sparse_categorical_accuracy: 0.6128
# Epoch 19/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8029 - sparse_categorical_accuracy: 0.6111
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8068 - sparse_categorical_accuracy: 0.6126
# >acc=0.5677,>f1=0.5343,>rec=0.5222,>roc=0.6415
# [[134  98   7]
#  [ 59 194  30]
#  [  3  84  41]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 0.9857 - sparse_categorical_accuracy: 0.4797
# Epoch 2/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.9186 - sparse_categorical_accuracy: 0.5374
# Epoch 3/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8802 - sparse_categorical_accuracy: 0.5630
# Epoch 4/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8626 - sparse_categorical_accuracy: 0.5779
# Epoch 5/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8462 - sparse_categorical_accuracy: 0.5841
# Epoch 6/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8359 - sparse_categorical_accuracy: 0.5933
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8239 - sparse_categorical_accuracy: 0.6033
# Epoch 8/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8194 - sparse_categorical_accuracy: 0.6132
# Epoch 9/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8114 - sparse_categorical_accuracy: 0.6150
# Epoch 10/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8090 - sparse_categorical_accuracy: 0.6117
# Epoch 11/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8006 - sparse_categorical_accuracy: 0.6214
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8038 - sparse_categorical_accuracy: 0.6177
# Epoch 13/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8027 - sparse_categorical_accuracy: 0.6184
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8046 - sparse_categorical_accuracy: 0.6222
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7971 - sparse_categorical_accuracy: 0.6182
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7982 - sparse_categorical_accuracy: 0.6227
# Epoch 17/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7988 - sparse_categorical_accuracy: 0.6306
# Epoch 18/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7966 - sparse_categorical_accuracy: 0.6239
# Epoch 19/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7994 - sparse_categorical_accuracy: 0.6167
# Epoch 20/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7999 - sparse_categorical_accuracy: 0.6234
# >acc=0.5908,>f1=0.5623,>rec=0.5491,>roc=0.6614
# [[157  80   2]
#  [ 78 183  22]
#  [ 13  71  44]]
# Epoch 1/20
# 127/127 [==============================] - 1s 2ms/step - loss: 1.0434 - sparse_categorical_accuracy: 0.4335
# Epoch 2/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.9470 - sparse_categorical_accuracy: 0.5315
# Epoch 3/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8804 - sparse_categorical_accuracy: 0.5648
# Epoch 4/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8500 - sparse_categorical_accuracy: 0.5852
# Epoch 5/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8383 - sparse_categorical_accuracy: 0.5882
# Epoch 6/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8273 - sparse_categorical_accuracy: 0.5996
# Epoch 7/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8224 - sparse_categorical_accuracy: 0.6038
# Epoch 8/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8154 - sparse_categorical_accuracy: 0.6045
# Epoch 9/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8125 - sparse_categorical_accuracy: 0.6149A: 0s - loss: 0.8260 - sparse_categorical_accuracy: 0.60
# Epoch 10/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8126 - sparse_categorical_accuracy: 0.6060
# Epoch 11/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8102 - sparse_categorical_accuracy: 0.6129
# Epoch 12/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8059 - sparse_categorical_accuracy: 0.6144
# Epoch 13/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8065 - sparse_categorical_accuracy: 0.6178
# Epoch 14/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8121 - sparse_categorical_accuracy: 0.6089
# Epoch 15/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8053 - sparse_categorical_accuracy: 0.6116
# Epoch 16/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8059 - sparse_categorical_accuracy: 0.6163
# Epoch 17/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8038 - sparse_categorical_accuracy: 0.6176
# Epoch 18/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8031 - sparse_categorical_accuracy: 0.6158
# Epoch 19/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8047 - sparse_categorical_accuracy: 0.6190
# Epoch 20/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8037 - sparse_categorical_accuracy: 0.6153
# >acc=0.5677,>f1=0.5292,>rec=0.5208,>roc=0.6416
# [[154  83   2]
#  [ 70 178  35]
#  [  9  82  37]]
# Epoch 1/20
# 125/125 [==============================] - 0s 1ms/step - loss: 1.0378 - sparse_categorical_accuracy: 0.4400
# Epoch 2/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.9254 - sparse_categorical_accuracy: 0.5588
# Epoch 3/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8589 - sparse_categorical_accuracy: 0.5918
# Epoch 4/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8371 - sparse_categorical_accuracy: 0.5990
# Epoch 5/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8257 - sparse_categorical_accuracy: 0.6068
# Epoch 6/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8208 - sparse_categorical_accuracy: 0.6046
# Epoch 7/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8203 - sparse_categorical_accuracy: 0.6186
# Epoch 8/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8188 - sparse_categorical_accuracy: 0.6091
# Epoch 9/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8104 - sparse_categorical_accuracy: 0.6148
# Epoch 10/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8101 - sparse_categorical_accuracy: 0.6146
# Epoch 11/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8089 - sparse_categorical_accuracy: 0.6203
# Epoch 12/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8101 - sparse_categorical_accuracy: 0.6191
# Epoch 13/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8120 - sparse_categorical_accuracy: 0.6191
# Epoch 14/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8085 - sparse_categorical_accuracy: 0.6188
# Epoch 15/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8051 - sparse_categorical_accuracy: 0.6258
# Epoch 16/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8082 - sparse_categorical_accuracy: 0.6208
# Epoch 17/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8058 - sparse_categorical_accuracy: 0.6221
# Epoch 18/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8101 - sparse_categorical_accuracy: 0.6218
# Epoch 19/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8054 - sparse_categorical_accuracy: 0.6196
# Epoch 20/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8057 - sparse_categorical_accuracy: 0.6208
# >acc=0.5662,>f1=0.5113,>rec=0.5053,>roc=0.6317
# [[147  90   1]
#  [ 64 193  27]
#  [  7  93  28]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 1.0013 - sparse_categorical_accuracy: 0.4752
# Epoch 2/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.9080 - sparse_categorical_accuracy: 0.5532
# Epoch 3/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8561 - sparse_categorical_accuracy: 0.5949
# Epoch 4/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8425 - sparse_categorical_accuracy: 0.5929
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8335 - sparse_categorical_accuracy: 0.5934
# Epoch 6/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8279 - sparse_categorical_accuracy: 0.6028
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8243 - sparse_categorical_accuracy: 0.6138
# Epoch 8/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8208 - sparse_categorical_accuracy: 0.6116
# Epoch 9/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8178 - sparse_categorical_accuracy: 0.6073
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8159 - sparse_categorical_accuracy: 0.6131
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8152 - sparse_categorical_accuracy: 0.6096
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8114 - sparse_categorical_accuracy: 0.6166
# Epoch 13/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8191 - sparse_categorical_accuracy: 0.6093
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8157 - sparse_categorical_accuracy: 0.6113A: 0s - loss: 0.8313 - sparse_categorical_accuracy: 0.5
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8170 - sparse_categorical_accuracy: 0.6093
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8128 - sparse_categorical_accuracy: 0.6200
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8098 - sparse_categorical_accuracy: 0.6133
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8136 - sparse_categorical_accuracy: 0.6123
# Epoch 19/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8132 - sparse_categorical_accuracy: 0.6091
# Epoch 20/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8138 - sparse_categorical_accuracy: 0.6183
# >acc=0.5831,>f1=0.5650,>rec=0.5508,>roc=0.6603
# [[139  94   5]
#  [ 66 188  30]
#  [  4  72  52]]
# Epoch 1/20
# 127/127 [==============================] - 1s 2ms/step - loss: 1.0302 - sparse_categorical_accuracy: 0.4462
# Epoch 2/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.9681 - sparse_categorical_accuracy: 0.5176
# Epoch 3/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.9160 - sparse_categorical_accuracy: 0.5468
# Epoch 4/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8842 - sparse_categorical_accuracy: 0.5701
# Epoch 5/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8638 - sparse_categorical_accuracy: 0.5738
# Epoch 6/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8521 - sparse_categorical_accuracy: 0.5847
# Epoch 7/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8425 - sparse_categorical_accuracy: 0.5870
# Epoch 8/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8322 - sparse_categorical_accuracy: 0.6036
# Epoch 9/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8214 - sparse_categorical_accuracy: 0.6023
# Epoch 10/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8229 - sparse_categorical_accuracy: 0.6048
# Epoch 11/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8186 - sparse_categorical_accuracy: 0.5996
# Epoch 12/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8193 - sparse_categorical_accuracy: 0.6090
# Epoch 13/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8144 - sparse_categorical_accuracy: 0.6108
# Epoch 14/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8141 - sparse_categorical_accuracy: 0.6098
# Epoch 15/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8142 - sparse_categorical_accuracy: 0.6167
# Epoch 16/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8082 - sparse_categorical_accuracy: 0.6110
# Epoch 17/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8122 - sparse_categorical_accuracy: 0.6162
# Epoch 18/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8112 - sparse_categorical_accuracy: 0.6160
# Epoch 19/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8121 - sparse_categorical_accuracy: 0.6117
# Epoch 20/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8106 - sparse_categorical_accuracy: 0.6117
# >acc=0.5908,>f1=0.5695,>rec=0.5541,>roc=0.6636
# [[153  84   1]
#  [ 77 183  24]
#  [  7  73  48]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 1.0493 - sparse_categorical_accuracy: 0.4511
# Epoch 2/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.9333 - sparse_categorical_accuracy: 0.5514
# Epoch 3/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8699 - sparse_categorical_accuracy: 0.5885
# Epoch 4/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8387 - sparse_categorical_accuracy: 0.5978
# Epoch 5/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8236 - sparse_categorical_accuracy: 0.6035
# Epoch 6/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8132 - sparse_categorical_accuracy: 0.6187
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8082 - sparse_categorical_accuracy: 0.6219
# Epoch 8/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8018 - sparse_categorical_accuracy: 0.6187
# Epoch 9/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8021 - sparse_categorical_accuracy: 0.6222
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8007 - sparse_categorical_accuracy: 0.6289
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7977 - sparse_categorical_accuracy: 0.6269
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7946 - sparse_categorical_accuracy: 0.6324A: 0s - loss: 0.7823 - sparse_categorical_accuracy: 0.6
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7966 - sparse_categorical_accuracy: 0.6239
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7955 - sparse_categorical_accuracy: 0.6279
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7932 - sparse_categorical_accuracy: 0.6327
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7926 - sparse_categorical_accuracy: 0.6294
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7947 - sparse_categorical_accuracy: 0.6299
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7930 - sparse_categorical_accuracy: 0.6264
# Epoch 19/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7893 - sparse_categorical_accuracy: 0.6364
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7869 - sparse_categorical_accuracy: 0.6357
# >acc=0.5393,>f1=0.5072,>rec=0.4947,>roc=0.6192
# [[127 106   5]
#  [ 74 185  25]
#  [  9  80  38]]
# Epoch 1/20
# 125/125 [==============================] - 1s 2ms/step - loss: 1.0194 - sparse_categorical_accuracy: 0.4704
# Epoch 2/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.9263 - sparse_categorical_accuracy: 0.5601
# Epoch 3/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8669 - sparse_categorical_accuracy: 0.5846
# Epoch 4/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8392 - sparse_categorical_accuracy: 0.6027
# Epoch 5/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8315 - sparse_categorical_accuracy: 0.6017
# Epoch 6/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8257 - sparse_categorical_accuracy: 0.6162
# Epoch 7/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8196 - sparse_categorical_accuracy: 0.6112
# Epoch 8/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8127 - sparse_categorical_accuracy: 0.6157
# Epoch 9/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8105 - sparse_categorical_accuracy: 0.6219
# Epoch 10/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8088 - sparse_categorical_accuracy: 0.6139
# Epoch 11/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8057 - sparse_categorical_accuracy: 0.6209
# Epoch 12/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8028 - sparse_categorical_accuracy: 0.6224
# Epoch 13/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8006 - sparse_categorical_accuracy: 0.6244
# Epoch 14/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8053 - sparse_categorical_accuracy: 0.6202
# Epoch 15/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8038 - sparse_categorical_accuracy: 0.6252
# Epoch 16/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8006 - sparse_categorical_accuracy: 0.6264
# Epoch 17/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8019 - sparse_categorical_accuracy: 0.6157
# Epoch 18/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8006 - sparse_categorical_accuracy: 0.6262
# Epoch 19/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8012 - sparse_categorical_accuracy: 0.6209
# Epoch 20/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8043 - sparse_categorical_accuracy: 0.6207
# >acc=0.5547,>f1=0.5018,>rec=0.4981,>roc=0.6257
# [[154  82   2]
#  [ 82 178  24]
#  [ 17  82  28]]
# Epoch 1/20
# 127/127 [==============================] - 1s 2ms/step - loss: 0.9932 - sparse_categorical_accuracy: 0.4875
# Epoch 2/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.9187 - sparse_categorical_accuracy: 0.5573
# Epoch 3/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8711 - sparse_categorical_accuracy: 0.5784
# Epoch 4/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8462 - sparse_categorical_accuracy: 0.5891
# Epoch 5/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8365 - sparse_categorical_accuracy: 0.5957
# Epoch 6/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8300 - sparse_categorical_accuracy: 0.6000
# Epoch 7/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8257 - sparse_categorical_accuracy: 0.6029
# Epoch 8/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8195 - sparse_categorical_accuracy: 0.6027
# Epoch 9/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8238 - sparse_categorical_accuracy: 0.6014
# Epoch 10/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8181 - sparse_categorical_accuracy: 0.6056A: 0s - loss: 0.8197 - sparse_categorical_accuracy: 0.603
# Epoch 11/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8181 - sparse_categorical_accuracy: 0.6096
# Epoch 12/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8134 - sparse_categorical_accuracy: 0.6066
# Epoch 13/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8110 - sparse_categorical_accuracy: 0.6086
# Epoch 14/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8134 - sparse_categorical_accuracy: 0.6153
# Epoch 15/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8129 - sparse_categorical_accuracy: 0.6113
# Epoch 16/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8136 - sparse_categorical_accuracy: 0.6123
# Epoch 17/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8143 - sparse_categorical_accuracy: 0.6059
# Epoch 18/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8146 - sparse_categorical_accuracy: 0.6089
# Epoch 19/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8152 - sparse_categorical_accuracy: 0.6071
# Epoch 20/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8098 - sparse_categorical_accuracy: 0.6071
# >acc=0.5809,>f1=0.5411,>rec=0.5338,>roc=0.6526
# [[153  78   7]
#  [ 60 185  39]
#  [ 11  77  39]]

# %%
print("Accuracy: %.4f (%.4f)" % (np.mean(kf_accuracy), np.std(kf_accuracy)))
print("F1-score: %.4f (%.4f)" % (np.mean(kf_f1), np.std(kf_f1)))
print("Recall: %.4f (%.4f)" % (np.mean(kf_recall), np.std(kf_recall)))
print("ROC: %.4f (%.4f)" % (np.mean(kf_roc), np.std(kf_roc)))
# Out:
# Accuracy: 0.5709 (0.0153)
# F1-score: 0.5357 (0.0231)
# Recall: 0.5255 (0.0205)
# ROC: 0.6442 (0.0146)

# %%
kf_accuracy
# Out:
# [0.5676923076923077,
#  0.5676923076923077,
#  0.5907692307692308,
#  0.5676923076923077,
#  0.5661538461538461,
#  0.583076923076923,
#  0.5907692307692308,
#  0.539291217257319,
#  0.5546995377503852,
#  0.5808936825885979]

# %%
conf_mat_mean = np.mean(kf_conf_mat,axis=0)

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
plot_confusion_matrix(conf_mat_mean,["0-Bad","1-Medium","2-Good"])
plt.savefig('MLP_ENN.png', transparent=True, dpi=300, bbox_inches="tight")
# Out:
# Confusion matrix, without normalization
# [[147.8  87.2   3.4]
#  [ 71.2 183.6  28.8]
#  [  8.5  79.7  39.5]]
