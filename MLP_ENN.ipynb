# %%
import pandas as pd
import numpy as np
from keras.utils import np_utils
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import roc_auc_score,confusion_matrix, accuracy_score, make_scorer, f1_score,precision_score,recall_score, plot_confusion_matrix
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
from imblearn.under_sampling import EditedNearestNeighbours
from collections import Counter
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
def print_distribution(arr, print_nl=True):
    arr = np.unique(arr, return_counts=True)[1] / len(arr)
    for i in range(arr.shape[0]):
        print("Classe %d: %.2f%%" %(i, arr[i]*100))

    if print_nl:
        print("\n")

# %%
def taste(quality):
  if quality <= 5:
    return 0
  elif quality == 6:
    return 1
  else:
    return 2

# %%
data = pd.read_csv("wine_quality.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed.acidity         6497 non-null   float64
#  1   volatile.acidity      6497 non-null   float64
#  2   citric.acid           6497 non-null   float64
#  3   residual.sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free.sulfur.dioxide   6497 non-null   float64
#  6   total.sulfur.dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 609.2 KB

# %%
new_data = data
new_data["taste"] = data["quality"].apply(taste)

# %%
new_data
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  taste
# 0         9.4        5      0
# 1         9.8        5      0
# 2         9.8        5      0
# 3         9.8        6      1
# 4         9.4        5      0
# ...       ...      ...    ...
# 6492     11.2        6      1
# 6493      9.6        5      0
# 6494      9.4        6      1
# 6495     12.8        7      2
# 6496     11.8        6      1
#
# [6497 rows x 13 columns]

# %% [markdown]
# ## Divisão de base de dados e separação de base

# %%
X = new_data.iloc[:, 0:11].values
y = new_data.iloc[:, 12].values

# %%
scaler = MinMaxScaler()
scaler.fit(X)
print(scaler.data_max_)
X_normalized = scaler.transform(X)
print(X_normalized)
# Out:
# [ 15.9       1.58      1.66     65.8       0.611   289.      440.
#    1.03898   4.01      2.       14.9    ]
# [[0.29752066 0.41333333 0.         ... 0.6124031  0.19101124 0.20289855]
#  [0.33057851 0.53333333 0.         ... 0.37209302 0.25842697 0.26086957]
#  [0.33057851 0.45333333 0.02409639 ... 0.41860465 0.24157303 0.26086957]
#  ...
#  [0.2231405  0.10666667 0.11445783 ... 0.20930233 0.13483146 0.20289855]
#  [0.14049587 0.14       0.18072289 ... 0.48062016 0.08988764 0.69565217]
#  [0.18181818 0.08666667 0.22891566 ... 0.41860465 0.05617978 0.55072464]]

# %%
print("Proporções por classe no dataset em geral:")
print_distribution(y)

kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=199)
fold = 0
for train, test in kf.split(X_normalized, y):
    print("Fold %d" %(fold))
    print_distribution(y[train], print_nl=(fold != 2))
    fold += 1
# Out:
# Proporções por classe no dataset em geral:
# Classe 0: 36.69%
# Classe 1: 43.65%
# Classe 2: 19.66%
#
#
# Fold 0
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 1
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 2
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
# Fold 3
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 4
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 5
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 6
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 7
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 8
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 9
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%

# %%
kf_accuracy = list()
kf_conf_mat = list()
kf_precision = list()
kf_f1 = list()
kf_recall = list()
kf_roc = list()

# %%
# pca = PCA(n_components=5)
# fit = pca.fit(X_normalized)
# # summarize components
# print("Explained Variance: %s" % fit.explained_variance_ratio_)
# print(fit.components_)

# %%
enn = EditedNearestNeighbours()

# %% [markdown]
# ## Laço para execução do gridsearch em cada fold

# %%
for train_ix, test_ix in kf.split(X_normalized,y):
    X_train, X_test = X_normalized[train_ix, :], X_normalized[test_ix, :]
    y_train, y_test = y[train_ix], y[test_ix]
    X_train_res, y_train_res = enn.fit_resample(X_train, y_train)
    #X_test_res, y_test_res = enn.fit_resample(X_test, y_test)
    model = Sequential()
    model.add(Dense(units=16, activation="linear",input_dim=11))
    model.add(Dropout(0.1))
    model.add(Dense(units=16, activation="linear"))
    model.add(Dropout(0.1))
    model.add(Dense(units=3, activation="softmax"))
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"])
    # executar e salvar melhores parâmetros do grisearch
    result = model.fit(X_train_res, y_train_res, batch_size=32, epochs=20)
    # teste dos melhores parâmetros
    predicted_y = model.predict(X_test)
    #y_test_transform = [np.argmax(t) for t in y_test]
    predicted_y_transform = [np.argmax(t) for t in predicted_y]
    #transformação de itens para cálculo do ROC
    le = LabelEncoder()
    y_test_dummy = le.fit_transform(y_test)
    predicted_y_dummy = le.fit_transform(predicted_y_transform)
    y_test_dummy = np_utils.to_categorical(y_test)
    predicted_y_dummy = np_utils.to_categorical(predicted_y_dummy)
    # métricas do modelo
    acc = accuracy_score(y_test, predicted_y_transform)
    conf_mat = confusion_matrix(y_test, predicted_y_transform)
    f1 = f1_score(y_test, predicted_y_transform, average = "macro")
    recall = recall_score(y_test, predicted_y_transform, average = "macro")
    roc = roc_auc_score(y_test_dummy,predicted_y_dummy,multi_class="ovo",average = "macro")
    #armazenamento de métricas
    kf_accuracy.append(acc)
    kf_conf_mat.append(conf_mat)
    kf_f1.append(f1)
    kf_recall.append(recall)
    kf_roc.append(roc)
    #métricas
    print(">acc=%.4f,>f1=%.4f,>rec=%.4f,>roc=%.4f" % (acc,f1,recall,roc))
    print(conf_mat)
# Out:
# Epoch 1/20
# 82/82 [==============================] - 1s 3ms/step - loss: 1.0208 - sparse_categorical_accuracy: 0.4708
# Epoch 2/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.9265 - sparse_categorical_accuracy: 0.5827
# Epoch 3/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.8184 - sparse_categorical_accuracy: 0.6408
# Epoch 4/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7602 - sparse_categorical_accuracy: 0.6599
# Epoch 5/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7380 - sparse_categorical_accuracy: 0.6718
# Epoch 6/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7332 - sparse_categorical_accuracy: 0.6580
# Epoch 7/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7205 - sparse_categorical_accuracy: 0.6718
# Epoch 8/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7228 - sparse_categorical_accuracy: 0.6767
# Epoch 9/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7172 - sparse_categorical_accuracy: 0.6763
# Epoch 10/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7116 - sparse_categorical_accuracy: 0.6798
# Epoch 11/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7120 - sparse_categorical_accuracy: 0.6775
# Epoch 12/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7126 - sparse_categorical_accuracy: 0.6763
# Epoch 13/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7113 - sparse_categorical_accuracy: 0.6775
# Epoch 14/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7094 - sparse_categorical_accuracy: 0.6809
# Epoch 15/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7065 - sparse_categorical_accuracy: 0.6840
# Epoch 16/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7119 - sparse_categorical_accuracy: 0.6767
# Epoch 17/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7089 - sparse_categorical_accuracy: 0.6783
# Epoch 18/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7060 - sparse_categorical_accuracy: 0.6798
# Epoch 19/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7065 - sparse_categorical_accuracy: 0.6767
# Epoch 20/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7025 - sparse_categorical_accuracy: 0.6832
# >acc=0.4738,>f1=0.4576,>rec=0.5516,>roc=0.6529
# [[154  34  51]
#  [ 79  45 159]
#  [  5  14 109]]
# Epoch 1/20
# 83/83 [==============================] - 1s 3ms/step - loss: 1.0381 - sparse_categorical_accuracy: 0.4398
# Epoch 2/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.9080 - sparse_categorical_accuracy: 0.6137
# Epoch 3/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.8163 - sparse_categorical_accuracy: 0.6419
# Epoch 4/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7673 - sparse_categorical_accuracy: 0.6570
# Epoch 5/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7482 - sparse_categorical_accuracy: 0.6630
# Epoch 6/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7359 - sparse_categorical_accuracy: 0.6687
# Epoch 7/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7325 - sparse_categorical_accuracy: 0.6755
# Epoch 8/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7220 - sparse_categorical_accuracy: 0.6762
# Epoch 9/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7213 - sparse_categorical_accuracy: 0.6721
# Epoch 10/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7245 - sparse_categorical_accuracy: 0.6751
# Epoch 11/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7158 - sparse_categorical_accuracy: 0.6770
# Epoch 12/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7172 - sparse_categorical_accuracy: 0.6721
# Epoch 13/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7177 - sparse_categorical_accuracy: 0.6830
# Epoch 14/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7071 - sparse_categorical_accuracy: 0.6871
# Epoch 15/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7129 - sparse_categorical_accuracy: 0.6758
# Epoch 16/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7126 - sparse_categorical_accuracy: 0.6830
# Epoch 17/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7122 - sparse_categorical_accuracy: 0.6770
# Epoch 18/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7097 - sparse_categorical_accuracy: 0.6834
# Epoch 19/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7108 - sparse_categorical_accuracy: 0.6815
# Epoch 20/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7101 - sparse_categorical_accuracy: 0.6826
# >acc=0.4754,>f1=0.4570,>rec=0.5506,>roc=0.6535
# [[157  29  53]
#  [ 78  45 160]
#  [ 10  11 107]]
# Epoch 1/20
# 82/82 [==============================] - 1s 3ms/step - loss: 1.0566 - sparse_categorical_accuracy: 0.4565
# Epoch 2/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.9526 - sparse_categorical_accuracy: 0.5889
# Epoch 3/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.8558 - sparse_categorical_accuracy: 0.6320
# Epoch 4/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7974 - sparse_categorical_accuracy: 0.6449
# Epoch 5/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7698 - sparse_categorical_accuracy: 0.6514
# Epoch 6/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7615 - sparse_categorical_accuracy: 0.6510
# Epoch 7/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7491 - sparse_categorical_accuracy: 0.6587
# Epoch 8/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7430 - sparse_categorical_accuracy: 0.6598
# Epoch 9/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7391 - sparse_categorical_accuracy: 0.6606
# Epoch 10/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7291 - sparse_categorical_accuracy: 0.6632
# Epoch 11/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7248 - sparse_categorical_accuracy: 0.6690
# Epoch 12/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7279 - sparse_categorical_accuracy: 0.6758
# Epoch 13/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7251 - sparse_categorical_accuracy: 0.6785
# Epoch 14/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7183 - sparse_categorical_accuracy: 0.6739
# Epoch 15/20
# 82/82 [==============================] - 0s 2ms/step - loss: 0.7194 - sparse_categorical_accuracy: 0.6739
# Epoch 16/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7152 - sparse_categorical_accuracy: 0.6659
# Epoch 17/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7195 - sparse_categorical_accuracy: 0.6773
# Epoch 18/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7164 - sparse_categorical_accuracy: 0.6762
# Epoch 19/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7151 - sparse_categorical_accuracy: 0.6785
# Epoch 20/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7147 - sparse_categorical_accuracy: 0.6777
# >acc=0.4769,>f1=0.4535,>rec=0.5572,>roc=0.6564
# [[162  36  41]
#  [ 81  38 164]
#  [ 14   4 110]]
# Epoch 1/20
# 83/83 [==============================] - 1s 3ms/step - loss: 1.0148 - sparse_categorical_accuracy: 0.4774
# Epoch 2/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.9227 - sparse_categorical_accuracy: 0.5991
# Epoch 3/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.8496 - sparse_categorical_accuracy: 0.6196
# Epoch 4/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.8098 - sparse_categorical_accuracy: 0.6398
# Epoch 5/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7847 - sparse_categorical_accuracy: 0.6459
# Epoch 6/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7689 - sparse_categorical_accuracy: 0.6508
# Epoch 7/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7586 - sparse_categorical_accuracy: 0.6523
# Epoch 8/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7434 - sparse_categorical_accuracy: 0.6622
# Epoch 9/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7393 - sparse_categorical_accuracy: 0.6584
# Epoch 10/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7306 - sparse_categorical_accuracy: 0.6645
# Epoch 11/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7271 - sparse_categorical_accuracy: 0.6657
# Epoch 12/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7182 - sparse_categorical_accuracy: 0.6634
# Epoch 13/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7228 - sparse_categorical_accuracy: 0.6710
# Epoch 14/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7204 - sparse_categorical_accuracy: 0.6687
# Epoch 15/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7202 - sparse_categorical_accuracy: 0.6748
# Epoch 16/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7166 - sparse_categorical_accuracy: 0.6714
# Epoch 17/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7144 - sparse_categorical_accuracy: 0.6687
# Epoch 18/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7110 - sparse_categorical_accuracy: 0.6698
# Epoch 19/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7193 - sparse_categorical_accuracy: 0.6721
# Epoch 20/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7164 - sparse_categorical_accuracy: 0.6714
# >acc=0.4769,>f1=0.4579,>rec=0.5626,>roc=0.6615
# [[154  30  55]
#  [ 67  41 175]
#  [  7   6 115]]
# Epoch 1/20
# 82/82 [==============================] - 1s 3ms/step - loss: 1.0633 - sparse_categorical_accuracy: 0.4171
# Epoch 2/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.9565 - sparse_categorical_accuracy: 0.5609
# Epoch 3/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.8718 - sparse_categorical_accuracy: 0.6295
# Epoch 4/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7975 - sparse_categorical_accuracy: 0.6515
# Epoch 5/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7615 - sparse_categorical_accuracy: 0.6546
# Epoch 6/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7437 - sparse_categorical_accuracy: 0.6596
# Epoch 7/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7380 - sparse_categorical_accuracy: 0.6635
# Epoch 8/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7311 - sparse_categorical_accuracy: 0.6685
# Epoch 9/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7199 - sparse_categorical_accuracy: 0.6715
# Epoch 10/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7158 - sparse_categorical_accuracy: 0.6704
# Epoch 11/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7099 - sparse_categorical_accuracy: 0.6789
# Epoch 12/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7160 - sparse_categorical_accuracy: 0.6777
# Epoch 13/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7106 - sparse_categorical_accuracy: 0.6715
# Epoch 14/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7132 - sparse_categorical_accuracy: 0.6731
# Epoch 15/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7124 - sparse_categorical_accuracy: 0.6793
# Epoch 16/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7106 - sparse_categorical_accuracy: 0.6746
# Epoch 17/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7138 - sparse_categorical_accuracy: 0.6762
# Epoch 18/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7144 - sparse_categorical_accuracy: 0.6746
# Epoch 19/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7073 - sparse_categorical_accuracy: 0.6750
# Epoch 20/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7116 - sparse_categorical_accuracy: 0.6789
# >acc=0.4754,>f1=0.4565,>rec=0.5605,>roc=0.6609
# [[153  24  61]
#  [ 67  42 175]
#  [  8   6 114]]
# Epoch 1/20
# 84/84 [==============================] - 1s 3ms/step - loss: 1.0513 - sparse_categorical_accuracy: 0.4311
# Epoch 2/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.9411 - sparse_categorical_accuracy: 0.5959
# Epoch 3/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.8502 - sparse_categorical_accuracy: 0.6275
# Epoch 4/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.8041 - sparse_categorical_accuracy: 0.6354
# Epoch 5/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7702 - sparse_categorical_accuracy: 0.6504
# Epoch 6/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7594 - sparse_categorical_accuracy: 0.6545
# Epoch 7/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7450 - sparse_categorical_accuracy: 0.6557
# Epoch 8/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7433 - sparse_categorical_accuracy: 0.6583
# Epoch 9/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7327 - sparse_categorical_accuracy: 0.6635
# Epoch 10/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7292 - sparse_categorical_accuracy: 0.6680
# Epoch 11/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7259 - sparse_categorical_accuracy: 0.6635
# Epoch 12/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7258 - sparse_categorical_accuracy: 0.6692
# Epoch 13/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7289 - sparse_categorical_accuracy: 0.6673
# Epoch 14/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7246 - sparse_categorical_accuracy: 0.6673
# Epoch 15/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7224 - sparse_categorical_accuracy: 0.6695
# Epoch 16/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7227 - sparse_categorical_accuracy: 0.6699
# Epoch 17/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7231 - sparse_categorical_accuracy: 0.6725
# Epoch 18/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7217 - sparse_categorical_accuracy: 0.6695
# Epoch 19/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7192 - sparse_categorical_accuracy: 0.6699
# Epoch 20/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7156 - sparse_categorical_accuracy: 0.6759
# >acc=0.4908,>f1=0.4614,>rec=0.5809,>roc=0.6747
# [[166  16  56]
#  [ 80  35 169]
#  [  7   3 118]]
# Epoch 1/20
# 83/83 [==============================] - 1s 3ms/step - loss: 1.0156 - sparse_categorical_accuracy: 0.4711
# Epoch 2/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.9073 - sparse_categorical_accuracy: 0.6021
# Epoch 3/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.8261 - sparse_categorical_accuracy: 0.6416
# Epoch 4/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7875 - sparse_categorical_accuracy: 0.6462
# Epoch 5/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7667 - sparse_categorical_accuracy: 0.6481
# Epoch 6/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7526 - sparse_categorical_accuracy: 0.6598
# Epoch 7/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7448 - sparse_categorical_accuracy: 0.6606
# Epoch 8/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7413 - sparse_categorical_accuracy: 0.6595
# Epoch 9/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7252 - sparse_categorical_accuracy: 0.6705
# Epoch 10/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7251 - sparse_categorical_accuracy: 0.6716
# Epoch 11/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7230 - sparse_categorical_accuracy: 0.6781
# Epoch 12/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7173 - sparse_categorical_accuracy: 0.6678
# Epoch 13/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7146 - sparse_categorical_accuracy: 0.6754
# Epoch 14/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7129 - sparse_categorical_accuracy: 0.6781
# Epoch 15/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7080 - sparse_categorical_accuracy: 0.6788
# Epoch 16/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7101 - sparse_categorical_accuracy: 0.6731
# Epoch 17/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7094 - sparse_categorical_accuracy: 0.6762
# Epoch 18/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7049 - sparse_categorical_accuracy: 0.6811
# Epoch 19/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7091 - sparse_categorical_accuracy: 0.6807
# Epoch 20/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7138 - sparse_categorical_accuracy: 0.6800
# >acc=0.4846,>f1=0.4675,>rec=0.5528,>roc=0.6543
# [[164  37  37]
#  [ 84  49 151]
#  [ 11  15 102]]
# Epoch 1/20
# 84/84 [==============================] - 1s 3ms/step - loss: 1.0774 - sparse_categorical_accuracy: 0.4206
# Epoch 2/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.9835 - sparse_categorical_accuracy: 0.5261
# Epoch 3/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.8946 - sparse_categorical_accuracy: 0.6151
# Epoch 4/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.8285 - sparse_categorical_accuracy: 0.6312
# Epoch 5/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7866 - sparse_categorical_accuracy: 0.6493
# Epoch 6/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7709 - sparse_categorical_accuracy: 0.6534
# Epoch 7/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7508 - sparse_categorical_accuracy: 0.6564
# Epoch 8/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7378 - sparse_categorical_accuracy: 0.6553
# Epoch 9/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7286 - sparse_categorical_accuracy: 0.6677
# Epoch 10/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7246 - sparse_categorical_accuracy: 0.6703
# Epoch 11/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7172 - sparse_categorical_accuracy: 0.6699
# Epoch 12/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7176 - sparse_categorical_accuracy: 0.6699
# Epoch 13/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7097 - sparse_categorical_accuracy: 0.6771
# Epoch 14/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7153 - sparse_categorical_accuracy: 0.6714
# Epoch 15/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7137 - sparse_categorical_accuracy: 0.6703
# Epoch 16/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7143 - sparse_categorical_accuracy: 0.6699
# Epoch 17/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7094 - sparse_categorical_accuracy: 0.6782
# Epoch 18/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7096 - sparse_categorical_accuracy: 0.6673
# Epoch 19/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7076 - sparse_categorical_accuracy: 0.6684
# Epoch 20/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7085 - sparse_categorical_accuracy: 0.6692
# >acc=0.4314,>f1=0.4147,>rec=0.5182,>roc=0.6273
# [[132  33  73]
#  [ 88  38 158]
#  [ 10   7 110]]
# Epoch 1/20
# 82/82 [==============================] - 1s 3ms/step - loss: 1.0855 - sparse_categorical_accuracy: 0.4024
# Epoch 2/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.9734 - sparse_categorical_accuracy: 0.5198
# Epoch 3/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.8670 - sparse_categorical_accuracy: 0.6346
# Epoch 4/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7805 - sparse_categorical_accuracy: 0.6611
# Epoch 5/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7356 - sparse_categorical_accuracy: 0.6650
# Epoch 6/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7150 - sparse_categorical_accuracy: 0.6715
# Epoch 7/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7009 - sparse_categorical_accuracy: 0.6731
# Epoch 8/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6984 - sparse_categorical_accuracy: 0.6808
# Epoch 9/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6941 - sparse_categorical_accuracy: 0.6742
# Epoch 10/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6911 - sparse_categorical_accuracy: 0.6812
# Epoch 11/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6909 - sparse_categorical_accuracy: 0.6831
# Epoch 12/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6889 - sparse_categorical_accuracy: 0.6762
# Epoch 13/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6831 - sparse_categorical_accuracy: 0.6846
# Epoch 14/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6890 - sparse_categorical_accuracy: 0.6792
# Epoch 15/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6861 - sparse_categorical_accuracy: 0.6769
# Epoch 16/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6871 - sparse_categorical_accuracy: 0.6816
# Epoch 17/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6875 - sparse_categorical_accuracy: 0.6750
# Epoch 18/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6858 - sparse_categorical_accuracy: 0.6831
# Epoch 19/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6850 - sparse_categorical_accuracy: 0.6816
# Epoch 20/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.6808 - sparse_categorical_accuracy: 0.6869
# >acc=0.4530,>f1=0.4423,>rec=0.5329,>roc=0.6422
# [[137  29  72]
#  [ 58  49 177]
#  [ 13   6 108]]
# Epoch 1/20
# 82/82 [==============================] - 1s 3ms/step - loss: 1.0536 - sparse_categorical_accuracy: 0.4288
# Epoch 2/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.9434 - sparse_categorical_accuracy: 0.5770
# Epoch 3/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.8647 - sparse_categorical_accuracy: 0.6343
# Epoch 4/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.8018 - sparse_categorical_accuracy: 0.6486
# Epoch 5/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7680 - sparse_categorical_accuracy: 0.6497
# Epoch 6/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7594 - sparse_categorical_accuracy: 0.6620
# Epoch 7/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7444 - sparse_categorical_accuracy: 0.6597
# Epoch 8/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7322 - sparse_categorical_accuracy: 0.6721
# Epoch 9/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7252 - sparse_categorical_accuracy: 0.6705
# Epoch 10/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7220 - sparse_categorical_accuracy: 0.6709
# Epoch 11/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7232 - sparse_categorical_accuracy: 0.6717
# Epoch 12/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7152 - sparse_categorical_accuracy: 0.6771
# Epoch 13/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7125 - sparse_categorical_accuracy: 0.6740
# Epoch 14/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7155 - sparse_categorical_accuracy: 0.6701
# Epoch 15/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7150 - sparse_categorical_accuracy: 0.6771
# Epoch 16/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7093 - sparse_categorical_accuracy: 0.6763
# Epoch 17/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7065 - sparse_categorical_accuracy: 0.6801
# Epoch 18/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7081 - sparse_categorical_accuracy: 0.6771
# Epoch 19/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7137 - sparse_categorical_accuracy: 0.6709
# Epoch 20/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7053 - sparse_categorical_accuracy: 0.6824
# >acc=0.4884,>f1=0.4740,>rec=0.5603,>roc=0.6628
# [[158  25  55]
#  [ 64  54 166]
#  [ 13   9 105]]

# %%
print("Accuracy: %.4f (%.4f)" % (np.mean(kf_accuracy), np.std(kf_accuracy)))
print("F1-score: %.4f (%.4f)" % (np.mean(kf_f1), np.std(kf_f1)))
print("Recall: %.4f (%.4f)" % (np.mean(kf_recall), np.std(kf_recall)))
print("ROC: %.4f (%.4f)" % (np.mean(kf_roc), np.std(kf_roc)))
# Out:
# Accuracy: 0.4727 (0.0169)
# F1-score: 0.4542 (0.0154)
# Recall: 0.5527 (0.0162)
# ROC: 0.6546 (0.0121)

# %%
conf_mat_mean = np.mean(kf_conf_mat,axis=0)

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
plot_confusion_matrix(conf_mat_mean,["0-Bad","1-Medium","2-Good"])
plt.savefig('MLP_ENN.png', transparent=True, dpi=300, bbox_inches="tight")
# Out:
# Confusion matrix, without normalization
# [[153.7  29.3  55.4]
#  [ 74.6  43.6 165.4]
#  [  9.8   8.1 109.8]]
