# %%
import pandas as pd
import numpy as np
from keras.utils import np_utils
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import roc_auc_score,confusion_matrix, accuracy_score, make_scorer, f1_score,precision_score,recall_score, plot_confusion_matrix
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
from imblearn.under_sampling import EditedNearestNeighbours
from collections import Counter
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
def print_distribution(arr, print_nl=True):
    arr = np.unique(arr, return_counts=True)[1] / len(arr)
    for i in range(arr.shape[0]):
        print("Classe %d: %.2f%%" %(i, arr[i]*100))

    if print_nl:
        print("\n")

# %%
def taste(quality):
  if quality <= 5:
    return 0
  elif quality == 6:
    return 1
  else:
    return 2

# %%
data = pd.read_csv("wine_quality.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed.acidity         6497 non-null   float64
#  1   volatile.acidity      6497 non-null   float64
#  2   citric.acid           6497 non-null   float64
#  3   residual.sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free.sulfur.dioxide   6497 non-null   float64
#  6   total.sulfur.dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 609.2 KB

# %%
new_data = data
new_data["taste"] = data["quality"].apply(taste)

# %%
new_data
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  taste
# 0         9.4        5      0
# 1         9.8        5      0
# 2         9.8        5      0
# 3         9.8        6      1
# 4         9.4        5      0
# ...       ...      ...    ...
# 6492     11.2        6      1
# 6493      9.6        5      0
# 6494      9.4        6      1
# 6495     12.8        7      2
# 6496     11.8        6      1
#
# [6497 rows x 13 columns]

# %% [markdown]
# ## Divisão de base de dados e separação de base

# %%
X = new_data.iloc[:, 0:11].values
y = new_data.iloc[:, 12].values

# %%
scaler = MinMaxScaler()
scaler.fit(X)
print(scaler.data_max_)
X_normalized = scaler.transform(X)
print(X_normalized)
# Out:
# [ 15.9       1.58      1.66     65.8       0.611   289.      440.
#    1.03898   4.01      2.       14.9    ]
# [[0.29752066 0.41333333 0.         ... 0.6124031  0.19101124 0.20289855]
#  [0.33057851 0.53333333 0.         ... 0.37209302 0.25842697 0.26086957]
#  [0.33057851 0.45333333 0.02409639 ... 0.41860465 0.24157303 0.26086957]
#  ...
#  [0.2231405  0.10666667 0.11445783 ... 0.20930233 0.13483146 0.20289855]
#  [0.14049587 0.14       0.18072289 ... 0.48062016 0.08988764 0.69565217]
#  [0.18181818 0.08666667 0.22891566 ... 0.41860465 0.05617978 0.55072464]]

# %%
print("Proporções por classe no dataset em geral:")
print_distribution(y)

kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=199)
fold = 0
for train, test in kf.split(X_normalized, y):
    print("Fold %d" %(fold))
    print_distribution(y[train], print_nl=(fold != 2))
    fold += 1
# Out:
# Proporções por classe no dataset em geral:
# Classe 0: 36.69%
# Classe 1: 43.65%
# Classe 2: 19.66%
#
#
# Fold 0
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 1
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 2
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
# Fold 3
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 4
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 5
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 6
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 7
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 8
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 9
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%

# %%
kf_accuracy = list()
kf_conf_mat = list()
kf_precision = list()
kf_f1 = list()
kf_recall = list()
kf_roc = list()

# %%
# pca = PCA(n_components=5)
# fit = pca.fit(X_normalized)
# # summarize components
# print("Explained Variance: %s" % fit.explained_variance_ratio_)
# print(fit.components_)

# %%
enn = EditedNearestNeighbours(sampling_strategy='all', n_neighbors=1, kind_sel='all', n_jobs=-1)

# %% [markdown]
# ## Laço para execução do gridsearch em cada fold

# %%
for train_ix, test_ix in kf.split(X_normalized,y):
    X_train, X_test = X_normalized[train_ix, :], X_normalized[test_ix, :]
    y_train, y_test = y[train_ix], y[test_ix]
    X_train_res, y_train_res = enn.fit_resample(X_train, y_train)
    #X_test_res, y_test_res = enn.fit_resample(X_test, y_test)
    model = Sequential()
    model.add(Dense(units=16, activation="linear",input_dim=11))
    model.add(Dropout(0.1))
    model.add(Dense(units=16, activation="linear"))
    model.add(Dropout(0.1))
    model.add(Dense(units=3, activation="softmax"))
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"])
    # executar e salvar melhores parâmetros do grisearch
    result = model.fit(X_train_res, y_train_res, batch_size=32, epochs=20)
    # teste dos melhores parâmetros
    predicted_y = model.predict(X_test)
    #y_test_transform = [np.argmax(t) for t in y_test]
    predicted_y_transform = [np.argmax(t) for t in predicted_y]
    #transformação de itens para cálculo do ROC
    le = LabelEncoder()
    y_test_dummy = le.fit_transform(y_test)
    predicted_y_dummy = le.fit_transform(predicted_y_transform)
    y_test_dummy = np_utils.to_categorical(y_test)
    predicted_y_dummy = np_utils.to_categorical(predicted_y_dummy)
    # métricas do modelo
    acc = accuracy_score(y_test, predicted_y_transform)
    conf_mat = confusion_matrix(y_test, predicted_y_transform)
    f1 = f1_score(y_test, predicted_y_transform, average = "macro")
    recall = recall_score(y_test, predicted_y_transform, average = "macro")
    roc = roc_auc_score(y_test_dummy,predicted_y_dummy,multi_class="ovo",average = "macro")
    #armazenamento de métricas
    kf_accuracy.append(acc)
    kf_conf_mat.append(conf_mat)
    kf_f1.append(f1)
    kf_recall.append(recall)
    kf_roc.append(roc)
    #métricas
    print(">acc=%.4f,>f1=%.4f,>rec=%.4f,>roc=%.4f" % (acc,f1,recall,roc))
    print(conf_mat)
# Out:
# Epoch 1/20
# 126/126 [==============================] - 1s 1ms/step - loss: 0.9903 - sparse_categorical_accuracy: 0.5127
# Epoch 2/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.9109 - sparse_categorical_accuracy: 0.5469
# Epoch 3/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8749 - sparse_categorical_accuracy: 0.5611
# Epoch 4/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8561 - sparse_categorical_accuracy: 0.5778
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8437 - sparse_categorical_accuracy: 0.5918
# Epoch 6/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8385 - sparse_categorical_accuracy: 0.5940
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8280 - sparse_categorical_accuracy: 0.5983
# Epoch 8/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8218 - sparse_categorical_accuracy: 0.6075
# Epoch 9/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8140 - sparse_categorical_accuracy: 0.6057
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8093 - sparse_categorical_accuracy: 0.6202
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8114 - sparse_categorical_accuracy: 0.6117
# Epoch 12/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8067 - sparse_categorical_accuracy: 0.6167
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8062 - sparse_categorical_accuracy: 0.6192
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8029 - sparse_categorical_accuracy: 0.6187
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8068 - sparse_categorical_accuracy: 0.6175
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8056 - sparse_categorical_accuracy: 0.6277
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8008 - sparse_categorical_accuracy: 0.6244
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8024 - sparse_categorical_accuracy: 0.6195
# Epoch 19/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8024 - sparse_categorical_accuracy: 0.6217
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8007 - sparse_categorical_accuracy: 0.6219
# >acc=0.5662,>f1=0.5280,>rec=0.5197,>roc=0.6401
# [[161  77   1]
#  [ 84 171  28]
#  [  7  85  36]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 1.0382 - sparse_categorical_accuracy: 0.4344
# Epoch 2/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.9514 - sparse_categorical_accuracy: 0.5303
# Epoch 3/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8850 - sparse_categorical_accuracy: 0.5686
# Epoch 4/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8477 - sparse_categorical_accuracy: 0.5855
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8346 - sparse_categorical_accuracy: 0.5890
# Epoch 6/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8231 - sparse_categorical_accuracy: 0.5964
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8164 - sparse_categorical_accuracy: 0.6069
# Epoch 8/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8154 - sparse_categorical_accuracy: 0.6076
# Epoch 9/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8133 - sparse_categorical_accuracy: 0.6081
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8095 - sparse_categorical_accuracy: 0.6056
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8091 - sparse_categorical_accuracy: 0.6108
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8067 - sparse_categorical_accuracy: 0.6188
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8081 - sparse_categorical_accuracy: 0.6175
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8052 - sparse_categorical_accuracy: 0.6188
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8059 - sparse_categorical_accuracy: 0.6136
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8048 - sparse_categorical_accuracy: 0.6210
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8073 - sparse_categorical_accuracy: 0.6180
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8022 - sparse_categorical_accuracy: 0.6178
# Epoch 19/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8025 - sparse_categorical_accuracy: 0.6210
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8043 - sparse_categorical_accuracy: 0.6156
# >acc=0.5892,>f1=0.5419,>rec=0.5350,>roc=0.6540
# [[163  73   3]
#  [ 73 186  24]
#  [ 11  83  34]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 1.0209 - sparse_categorical_accuracy: 0.4984
# Epoch 2/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.9246 - sparse_categorical_accuracy: 0.5526
# Epoch 3/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8670 - sparse_categorical_accuracy: 0.5797
# Epoch 4/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8364 - sparse_categorical_accuracy: 0.6000
# Epoch 5/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8255 - sparse_categorical_accuracy: 0.5998
# Epoch 6/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8178 - sparse_categorical_accuracy: 0.6075
# Epoch 7/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8159 - sparse_categorical_accuracy: 0.6115
# Epoch 8/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8092 - sparse_categorical_accuracy: 0.6120
# Epoch 9/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8063 - sparse_categorical_accuracy: 0.6174
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8066 - sparse_categorical_accuracy: 0.6150
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8055 - sparse_categorical_accuracy: 0.6194
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8072 - sparse_categorical_accuracy: 0.6192
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8025 - sparse_categorical_accuracy: 0.6125
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8058 - sparse_categorical_accuracy: 0.6130
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8055 - sparse_categorical_accuracy: 0.6219
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8027 - sparse_categorical_accuracy: 0.6209
# Epoch 17/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8011 - sparse_categorical_accuracy: 0.6214
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7989 - sparse_categorical_accuracy: 0.6264
# Epoch 19/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7980 - sparse_categorical_accuracy: 0.6207
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8016 - sparse_categorical_accuracy: 0.6192
# >acc=0.5908,>f1=0.5612,>rec=0.5511,>roc=0.6632
# [[166  71   2]
#  [ 83 174  26]
#  [ 13  71  44]]
# Epoch 1/20
# 127/127 [==============================] - 1s 2ms/step - loss: 1.0312 - sparse_categorical_accuracy: 0.4335
# Epoch 2/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.9312 - sparse_categorical_accuracy: 0.5406
# Epoch 3/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8740 - sparse_categorical_accuracy: 0.5670
# Epoch 4/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8516 - sparse_categorical_accuracy: 0.5796A: 0s - loss: 0.8541 - sparse_categorical_accuracy: 0.5
# Epoch 5/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8380 - sparse_categorical_accuracy: 0.5931
# Epoch 6/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8261 - sparse_categorical_accuracy: 0.6038
# Epoch 7/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8227 - sparse_categorical_accuracy: 0.5946
# Epoch 8/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8170 - sparse_categorical_accuracy: 0.6042
# Epoch 9/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8145 - sparse_categorical_accuracy: 0.6047
# Epoch 10/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8157 - sparse_categorical_accuracy: 0.6042
# Epoch 11/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8079 - sparse_categorical_accuracy: 0.6121
# Epoch 12/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8141 - sparse_categorical_accuracy: 0.6082
# Epoch 13/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8091 - sparse_categorical_accuracy: 0.6112
# Epoch 14/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8133 - sparse_categorical_accuracy: 0.6075
# Epoch 15/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8086 - sparse_categorical_accuracy: 0.6109
# Epoch 16/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8055 - sparse_categorical_accuracy: 0.6153
# Epoch 17/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8069 - sparse_categorical_accuracy: 0.6109
# Epoch 18/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8119 - sparse_categorical_accuracy: 0.6104
# Epoch 19/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8027 - sparse_categorical_accuracy: 0.6104
# Epoch 20/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8041 - sparse_categorical_accuracy: 0.6158
# >acc=0.5800,>f1=0.5492,>rec=0.5370,>roc=0.6527
# [[146  91   2]
#  [ 60 188  35]
#  [  6  79  43]]
# Epoch 1/20
# 125/125 [==============================] - 1s 2ms/step - loss: 1.0610 - sparse_categorical_accuracy: 0.4377
# Epoch 2/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.9768 - sparse_categorical_accuracy: 0.5345
# Epoch 3/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.9001 - sparse_categorical_accuracy: 0.5670
# Epoch 4/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8603 - sparse_categorical_accuracy: 0.5903
# Epoch 5/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8405 - sparse_categorical_accuracy: 0.5958
# Epoch 6/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8330 - sparse_categorical_accuracy: 0.5980
# Epoch 7/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8317 - sparse_categorical_accuracy: 0.5993
# Epoch 8/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8233 - sparse_categorical_accuracy: 0.6063
# Epoch 9/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8219 - sparse_categorical_accuracy: 0.6036
# Epoch 10/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8173 - sparse_categorical_accuracy: 0.6133
# Epoch 11/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8153 - sparse_categorical_accuracy: 0.6171
# Epoch 12/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8108 - sparse_categorical_accuracy: 0.6101
# Epoch 13/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8153 - sparse_categorical_accuracy: 0.6116
# Epoch 14/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8082 - sparse_categorical_accuracy: 0.6151
# Epoch 15/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8107 - sparse_categorical_accuracy: 0.6196
# Epoch 16/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8090 - sparse_categorical_accuracy: 0.6143
# Epoch 17/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8104 - sparse_categorical_accuracy: 0.6133
# Epoch 18/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8115 - sparse_categorical_accuracy: 0.6198
# Epoch 19/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8039 - sparse_categorical_accuracy: 0.6141
# Epoch 20/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8087 - sparse_categorical_accuracy: 0.6188
# >acc=0.5569,>f1=0.5207,>rec=0.5096,>roc=0.6323
# [[134 101   3]
#  [ 57 190  37]
#  [  5  85  38]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 1.0263 - sparse_categorical_accuracy: 0.4580
# Epoch 2/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.9092 - sparse_categorical_accuracy: 0.5642
# Epoch 3/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8623 - sparse_categorical_accuracy: 0.5844
# Epoch 4/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8421 - sparse_categorical_accuracy: 0.5921
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8308 - sparse_categorical_accuracy: 0.5974
# Epoch 6/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8237 - sparse_categorical_accuracy: 0.6056
# Epoch 7/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8221 - sparse_categorical_accuracy: 0.6146
# Epoch 8/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8234 - sparse_categorical_accuracy: 0.6088
# Epoch 9/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8192 - sparse_categorical_accuracy: 0.6083
# Epoch 10/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8151 - sparse_categorical_accuracy: 0.6136
# Epoch 11/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8191 - sparse_categorical_accuracy: 0.6088
# Epoch 12/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8138 - sparse_categorical_accuracy: 0.6101
# Epoch 13/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8143 - sparse_categorical_accuracy: 0.6061
# Epoch 14/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8142 - sparse_categorical_accuracy: 0.6128
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8174 - sparse_categorical_accuracy: 0.6126
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8143 - sparse_categorical_accuracy: 0.6048
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8111 - sparse_categorical_accuracy: 0.6153
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8075 - sparse_categorical_accuracy: 0.6230
# Epoch 19/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8156 - sparse_categorical_accuracy: 0.6103
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8158 - sparse_categorical_accuracy: 0.6088
# >acc=0.5831,>f1=0.5607,>rec=0.5459,>roc=0.6575
# [[143  91   4]
#  [ 69 188  27]
#  [  4  76  48]]
# Epoch 1/20
# 127/127 [==============================] - 1s 2ms/step - loss: 1.0411 - sparse_categorical_accuracy: 0.4859
# Epoch 2/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.9844 - sparse_categorical_accuracy: 0.5330
# Epoch 3/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.9143 - sparse_categorical_accuracy: 0.5602
# Epoch 4/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8704 - sparse_categorical_accuracy: 0.5785
# Epoch 5/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8503 - sparse_categorical_accuracy: 0.5899
# Epoch 6/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8390 - sparse_categorical_accuracy: 0.5912
# Epoch 7/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8264 - sparse_categorical_accuracy: 0.6073
# Epoch 8/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8216 - sparse_categorical_accuracy: 0.6115
# Epoch 9/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8186 - sparse_categorical_accuracy: 0.6117
# Epoch 10/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8201 - sparse_categorical_accuracy: 0.6075
# Epoch 11/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8152 - sparse_categorical_accuracy: 0.6053
# Epoch 12/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8111 - sparse_categorical_accuracy: 0.6132
# Epoch 13/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8167 - sparse_categorical_accuracy: 0.6063
# Epoch 14/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8094 - sparse_categorical_accuracy: 0.6152
# Epoch 15/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8089 - sparse_categorical_accuracy: 0.6115
# Epoch 16/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8103 - sparse_categorical_accuracy: 0.6130
# Epoch 17/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8132 - sparse_categorical_accuracy: 0.6179
# Epoch 18/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8106 - sparse_categorical_accuracy: 0.6199
# Epoch 19/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8084 - sparse_categorical_accuracy: 0.6145
# Epoch 20/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8044 - sparse_categorical_accuracy: 0.6169
# >acc=0.5831,>f1=0.5599,>rec=0.5442,>roc=0.6562
# [[148  90   0]
#  [ 74 185  25]
#  [  7  75  46]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 1.0089 - sparse_categorical_accuracy: 0.4895
# Epoch 2/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.9260 - sparse_categorical_accuracy: 0.5603
# Epoch 3/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8770 - sparse_categorical_accuracy: 0.5763
# Epoch 4/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8502 - sparse_categorical_accuracy: 0.5970
# Epoch 5/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8413 - sparse_categorical_accuracy: 0.5985
# Epoch 6/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8267 - sparse_categorical_accuracy: 0.6125
# Epoch 7/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8142 - sparse_categorical_accuracy: 0.6135
# Epoch 8/20
# 126/126 [==============================] - ETA: 0s - loss: 0.8085 - sparse_categorical_accuracy: 0.618 - 0s 2ms/step - loss: 0.8125 - sparse_categorical_accuracy: 0.6157
# Epoch 9/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8093 - sparse_categorical_accuracy: 0.6252
# Epoch 10/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8022 - sparse_categorical_accuracy: 0.6217
# Epoch 11/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8052 - sparse_categorical_accuracy: 0.6170
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7987 - sparse_categorical_accuracy: 0.6284
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8008 - sparse_categorical_accuracy: 0.6204
# Epoch 14/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8002 - sparse_categorical_accuracy: 0.6229
# Epoch 15/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8008 - sparse_categorical_accuracy: 0.6244
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7960 - sparse_categorical_accuracy: 0.6264
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7965 - sparse_categorical_accuracy: 0.6259
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7935 - sparse_categorical_accuracy: 0.6287
# Epoch 19/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7918 - sparse_categorical_accuracy: 0.6342
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7948 - sparse_categorical_accuracy: 0.6279
# >acc=0.5347,>f1=0.5102,>rec=0.4972,>roc=0.6198
# [[134 100   4]
#  [ 86 172  26]
#  [ 11  75  41]]
# Epoch 1/20
# 125/125 [==============================] - 1s 2ms/step - loss: 1.0020 - sparse_categorical_accuracy: 0.4939
# Epoch 2/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.9157 - sparse_categorical_accuracy: 0.5449
# Epoch 3/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8704 - sparse_categorical_accuracy: 0.5759
# Epoch 4/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8461 - sparse_categorical_accuracy: 0.5921
# Epoch 5/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8357 - sparse_categorical_accuracy: 0.5999
# Epoch 6/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8227 - sparse_categorical_accuracy: 0.6014
# Epoch 7/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8227 - sparse_categorical_accuracy: 0.6089
# Epoch 8/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8140 - sparse_categorical_accuracy: 0.6132
# Epoch 9/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8099 - sparse_categorical_accuracy: 0.6169
# Epoch 10/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8119 - sparse_categorical_accuracy: 0.6209
# Epoch 11/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8056 - sparse_categorical_accuracy: 0.6209
# Epoch 12/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8078 - sparse_categorical_accuracy: 0.6214
# Epoch 13/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8081 - sparse_categorical_accuracy: 0.6257
# Epoch 14/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8047 - sparse_categorical_accuracy: 0.6204
# Epoch 15/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8066 - sparse_categorical_accuracy: 0.6202
# Epoch 16/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8048 - sparse_categorical_accuracy: 0.6264
# Epoch 17/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.7988 - sparse_categorical_accuracy: 0.6299
# Epoch 18/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8075 - sparse_categorical_accuracy: 0.6227
# Epoch 19/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8045 - sparse_categorical_accuracy: 0.6284
# Epoch 20/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8052 - sparse_categorical_accuracy: 0.6222
# >acc=0.5624,>f1=0.5124,>rec=0.5049,>roc=0.6308
# [[139  97   2]
#  [ 60 195  29]
#  [ 14  82  31]]
# Epoch 1/20
# 127/127 [==============================] - 1s 2ms/step - loss: 1.0413 - sparse_categorical_accuracy: 0.4444
# Epoch 2/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.9332 - sparse_categorical_accuracy: 0.5326
# Epoch 3/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8751 - sparse_categorical_accuracy: 0.5725
# Epoch 4/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8533 - sparse_categorical_accuracy: 0.5782
# Epoch 5/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8415 - sparse_categorical_accuracy: 0.5831
# Epoch 6/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8314 - sparse_categorical_accuracy: 0.5980
# Epoch 7/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8227 - sparse_categorical_accuracy: 0.5955
# Epoch 8/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8214 - sparse_categorical_accuracy: 0.5972
# Epoch 9/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8231 - sparse_categorical_accuracy: 0.5985
# Epoch 10/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8185 - sparse_categorical_accuracy: 0.6014
# Epoch 11/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8172 - sparse_categorical_accuracy: 0.6039
# Epoch 12/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8171 - sparse_categorical_accuracy: 0.6037
# Epoch 13/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8156 - sparse_categorical_accuracy: 0.6042
# Epoch 14/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8119 - sparse_categorical_accuracy: 0.6042
# Epoch 15/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8169 - sparse_categorical_accuracy: 0.6094
# Epoch 16/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8113 - sparse_categorical_accuracy: 0.6123
# Epoch 17/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8131 - sparse_categorical_accuracy: 0.6056
# Epoch 18/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8069 - sparse_categorical_accuracy: 0.6104
# Epoch 19/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8092 - sparse_categorical_accuracy: 0.6049
# Epoch 20/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8089 - sparse_categorical_accuracy: 0.6101
# >acc=0.5948,>f1=0.5519,>rec=0.5443,>roc=0.6610
# [[159  74   5]
#  [ 62 189  33]
#  [ 11  78  38]]

# %%
print("Accuracy: %.4f (%.4f)" % (np.mean(kf_accuracy), np.std(kf_accuracy)))
print("F1-score: %.4f (%.4f)" % (np.mean(kf_f1), np.std(kf_f1)))
print("Recall: %.4f (%.4f)" % (np.mean(kf_recall), np.std(kf_recall)))
print("ROC: %.4f (%.4f)" % (np.mean(kf_roc), np.std(kf_roc)))
# Out:
# Accuracy: 0.5741 (0.0178)
# F1-score: 0.5396 (0.0191)
# Recall: 0.5289 (0.0184)
# ROC: 0.6468 (0.0141)

# %%
conf_mat_mean = np.mean(kf_conf_mat,axis=0)

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
plot_confusion_matrix(conf_mat_mean,["0-Bad","1-Medium","2-Good"])
plt.savefig('MLP_ENN.png', transparent=True, dpi=300, bbox_inches="tight")
# Out:
# Confusion matrix, without normalization
# [[149.3  86.5   2.6]
#  [ 70.8 183.8  29. ]
#  [  8.9  78.9  39.9]]
