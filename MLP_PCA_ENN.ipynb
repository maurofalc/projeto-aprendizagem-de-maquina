# %%
import pandas as pd
import numpy as np
from keras.utils import np_utils
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import roc_auc_score,confusion_matrix, accuracy_score, make_scorer, f1_score,precision_score,recall_score, plot_confusion_matrix
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
from sklearn.decomposition import PCA
from imblearn.under_sampling import EditedNearestNeighbours
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
def print_distribution(arr, print_nl=True):
    arr = np.unique(arr, return_counts=True)[1] / len(arr)
    for i in range(arr.shape[0]):
        print("Classe %d: %.2f%%" %(i, arr[i]*100))

    if print_nl:
        print("\n")

# %%
def taste(quality):
  if quality <= 5:
    return 0
  elif quality == 6:
    return 1
  else:
    return 2

# %%
data = pd.read_csv("wine_quality.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed.acidity         6497 non-null   float64
#  1   volatile.acidity      6497 non-null   float64
#  2   citric.acid           6497 non-null   float64
#  3   residual.sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free.sulfur.dioxide   6497 non-null   float64
#  6   total.sulfur.dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 609.2 KB

# %%
new_data = data
new_data["taste"] = data["quality"].apply(taste)

# %%
new_data
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  taste
# 0         9.4        5      0
# 1         9.8        5      0
# 2         9.8        5      0
# 3         9.8        6      1
# 4         9.4        5      0
# ...       ...      ...    ...
# 6492     11.2        6      1
# 6493      9.6        5      0
# 6494      9.4        6      1
# 6495     12.8        7      2
# 6496     11.8        6      1
#
# [6497 rows x 13 columns]

# %% [markdown]
# ## Divisão de base de dados e separação de base

# %%
X = new_data.iloc[:, 0:11].values
y = new_data.iloc[:, 12].values

# %%
scaler = MinMaxScaler()
scaler.fit(X)
print(scaler.data_max_)
X_normalized = scaler.transform(X)
print(X_normalized)
# Out:
# [ 15.9       1.58      1.66     65.8       0.611   289.      440.
#    1.03898   4.01      2.       14.9    ]
# [[0.29752066 0.41333333 0.         ... 0.6124031  0.19101124 0.20289855]
#  [0.33057851 0.53333333 0.         ... 0.37209302 0.25842697 0.26086957]
#  [0.33057851 0.45333333 0.02409639 ... 0.41860465 0.24157303 0.26086957]
#  ...
#  [0.2231405  0.10666667 0.11445783 ... 0.20930233 0.13483146 0.20289855]
#  [0.14049587 0.14       0.18072289 ... 0.48062016 0.08988764 0.69565217]
#  [0.18181818 0.08666667 0.22891566 ... 0.41860465 0.05617978 0.55072464]]

# %%
print("Proporções por classe no dataset em geral:")
print_distribution(y)

kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=199)
fold = 0
for train, test in kf.split(X_normalized, y):
    print("Fold %d" %(fold))
    print_distribution(y[train], print_nl=(fold != 2))
    fold += 1
# Out:
# Proporções por classe no dataset em geral:
# Classe 0: 36.69%
# Classe 1: 43.65%
# Classe 2: 19.66%
#
#
# Fold 0
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 1
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 2
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
# Fold 3
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 4
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 5
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 6
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 7
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 8
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 9
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%

# %%
kf_accuracy = list()
kf_conf_mat = list()
kf_precision = list()
kf_f1 = list()
kf_recall = list()
kf_roc = list()

# %%
# pca = PCA(n_components=5)
# fit = pca.fit(X_normalized)
# # summarize components
# print("Explained Variance: %s" % fit.explained_variance_ratio_)
# print(fit.components_)

# %%
pca = PCA(n_components=5)
enn = EditedNearestNeighbours(sampling_strategy='all', n_neighbors=1, kind_sel='all', n_jobs=-1)

# %% [markdown]
# ## Laço para execução do gridsearch em cada fold

# %%
for train_ix, test_ix in kf.split(X_normalized,y):
    X_train, X_test = X_normalized[train_ix, :], X_normalized[test_ix, :]
    y_train, y_test = y[train_ix], y[test_ix]
    X_train_pca = pca.fit_transform(X_train)
    X_test_pca = pca.transform(X_test)
    X_train_res, y_train_res = enn.fit_resample(X_train_pca, y_train)
    #X_test_res, y_test_res = enn.fit_resample(X_test_pca, y_test)
    model = Sequential()
    model.add(Dense(units=16, activation="linear",input_dim=5))
    model.add(Dropout(0.1))
    model.add(Dense(units=16, activation="linear"))
    model.add(Dropout(0.1))
    model.add(Dense(units=3, activation="softmax"))
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"])
    # execução
    result = model.fit(X_train_res, y_train_res, batch_size=32, epochs=20)
    # teste dos melhores parâmetros
    predicted_y = model.predict(X_test_pca)
    #y_test_transform = [np.argmax(t) for t in y_test]
    predicted_y_transform = [np.argmax(t) for t in predicted_y]
    #transformação de itens para cálculo do ROC
    le = LabelEncoder()
    y_test_dummy = le.fit_transform(y_test)
    predicted_y_dummy = le.fit_transform(predicted_y_transform)
    y_test_dummy = np_utils.to_categorical(y_test)
    predicted_y_dummy = np_utils.to_categorical(predicted_y_dummy)
    # métricas do modelo
    acc = accuracy_score(y_test, predicted_y_transform)
    conf_mat = confusion_matrix(y_test, predicted_y_transform)
    f1 = f1_score(y_test, predicted_y_transform, average = "macro")
    recall = recall_score(y_test, predicted_y_transform, average = "macro")
    roc = roc_auc_score(y_test_dummy,predicted_y_dummy,multi_class="ovo",average = "macro")
    #armazenamento de métricas
    kf_accuracy.append(acc)
    kf_conf_mat.append(conf_mat)
    kf_f1.append(f1)
    kf_recall.append(recall)
    kf_roc.append(roc)
    #métricas
    print(">acc=%.4f,>f1=%.4f,>rec=%.4f,>roc=%.4f" % (acc,f1,recall,roc))
    print(conf_mat)
# Out:
# Epoch 1/20
# 124/124 [==============================] - 1s 2ms/step - loss: 0.9820 - sparse_categorical_accuracy: 0.4937
# Epoch 2/20
# 124/124 [==============================] - 0s 2ms/step - loss: 0.8706 - sparse_categorical_accuracy: 0.5757
# Epoch 3/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8597 - sparse_categorical_accuracy: 0.5782
# Epoch 4/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8570 - sparse_categorical_accuracy: 0.5840
# Epoch 5/20
# 124/124 [==============================] - 0s 2ms/step - loss: 0.8583 - sparse_categorical_accuracy: 0.5789
# Epoch 6/20
# 124/124 [==============================] - 0s 2ms/step - loss: 0.8536 - sparse_categorical_accuracy: 0.5893
# Epoch 7/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8532 - sparse_categorical_accuracy: 0.5896
# Epoch 8/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8525 - sparse_categorical_accuracy: 0.5967
# Epoch 9/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8551 - sparse_categorical_accuracy: 0.5901
# Epoch 10/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8495 - sparse_categorical_accuracy: 0.5901
# Epoch 11/20
# 124/124 [==============================] - 0s 2ms/step - loss: 0.8504 - sparse_categorical_accuracy: 0.5911
# Epoch 12/20
# 124/124 [==============================] - 0s 2ms/step - loss: 0.8494 - sparse_categorical_accuracy: 0.5959
# Epoch 13/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8508 - sparse_categorical_accuracy: 0.5924
# Epoch 14/20
# 124/124 [==============================] - 0s 2ms/step - loss: 0.8533 - sparse_categorical_accuracy: 0.5901
# Epoch 15/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8505 - sparse_categorical_accuracy: 0.5982
# Epoch 16/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8522 - sparse_categorical_accuracy: 0.5891
# Epoch 17/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8523 - sparse_categorical_accuracy: 0.5868
# Epoch 18/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8501 - sparse_categorical_accuracy: 0.5936A: 0s - loss: 0.8328 - sparse_categorical_accuracy: 0.6
# Epoch 19/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8531 - sparse_categorical_accuracy: 0.5939
# Epoch 20/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8486 - sparse_categorical_accuracy: 0.5964
# >acc=0.5477,>f1=0.5083,>rec=0.5014,>roc=0.6263
# [[155  83   1]
#  [ 84 167  32]
#  [ 11  83  34]]
# Epoch 1/20
# 124/124 [==============================] - 1s 2ms/step - loss: 0.9777 - sparse_categorical_accuracy: 0.5277
# Epoch 2/20
# 124/124 [==============================] - 0s 2ms/step - loss: 0.8819 - sparse_categorical_accuracy: 0.5713
# Epoch 3/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8579 - sparse_categorical_accuracy: 0.5792
# Epoch 4/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8540 - sparse_categorical_accuracy: 0.5858
# Epoch 5/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8542 - sparse_categorical_accuracy: 0.5845
# Epoch 6/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8544 - sparse_categorical_accuracy: 0.5789
# Epoch 7/20
# 124/124 [==============================] - 0s 2ms/step - loss: 0.8528 - sparse_categorical_accuracy: 0.5858
# Epoch 8/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8462 - sparse_categorical_accuracy: 0.5875
# Epoch 9/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8509 - sparse_categorical_accuracy: 0.5908
# Epoch 10/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8502 - sparse_categorical_accuracy: 0.5929
# Epoch 11/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8503 - sparse_categorical_accuracy: 0.5873
# Epoch 12/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8528 - sparse_categorical_accuracy: 0.5860
# Epoch 13/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8489 - sparse_categorical_accuracy: 0.5873
# Epoch 14/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8520 - sparse_categorical_accuracy: 0.5858
# Epoch 15/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8504 - sparse_categorical_accuracy: 0.5845
# Epoch 16/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8532 - sparse_categorical_accuracy: 0.5827
# Epoch 17/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8521 - sparse_categorical_accuracy: 0.5934
# Epoch 18/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8480 - sparse_categorical_accuracy: 0.5865
# Epoch 19/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8497 - sparse_categorical_accuracy: 0.5837
# Epoch 20/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8460 - sparse_categorical_accuracy: 0.5804
# >acc=0.5477,>f1=0.5037,>rec=0.4951,>roc=0.6219
# [[139  94   6]
#  [ 79 185  19]
#  [ 13  83  32]]
# Epoch 1/20
# 125/125 [==============================] - 1s 2ms/step - loss: 0.9988 - sparse_categorical_accuracy: 0.5131
# Epoch 2/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8826 - sparse_categorical_accuracy: 0.5842
# Epoch 3/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8543 - sparse_categorical_accuracy: 0.5934
# Epoch 4/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8525 - sparse_categorical_accuracy: 0.5964
# Epoch 5/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8577 - sparse_categorical_accuracy: 0.5887
# Epoch 6/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8558 - sparse_categorical_accuracy: 0.5892
# Epoch 7/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8488 - sparse_categorical_accuracy: 0.5902
# Epoch 8/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8527 - sparse_categorical_accuracy: 0.5947
# Epoch 9/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8530 - sparse_categorical_accuracy: 0.5897
# Epoch 10/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8493 - sparse_categorical_accuracy: 0.5939
# Epoch 11/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8516 - sparse_categorical_accuracy: 0.5922
# Epoch 12/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8506 - sparse_categorical_accuracy: 0.5922
# Epoch 13/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8509 - sparse_categorical_accuracy: 0.5879
# Epoch 14/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8506 - sparse_categorical_accuracy: 0.5857
# Epoch 15/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8497 - sparse_categorical_accuracy: 0.5914
# Epoch 16/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8476 - sparse_categorical_accuracy: 0.5932
# Epoch 17/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8513 - sparse_categorical_accuracy: 0.5897
# Epoch 18/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8526 - sparse_categorical_accuracy: 0.5909
# Epoch 19/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8529 - sparse_categorical_accuracy: 0.5897
# Epoch 20/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8480 - sparse_categorical_accuracy: 0.5929
# >acc=0.5446,>f1=0.5124,>rec=0.5004,>roc=0.6240
# [[135 103   1]
#  [ 73 181  29]
#  [ 12  78  38]]
# Epoch 1/20
# 125/125 [==============================] - 1s 2ms/step - loss: 1.0391 - sparse_categorical_accuracy: 0.4541
# Epoch 2/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8948 - sparse_categorical_accuracy: 0.5726
# Epoch 3/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8589 - sparse_categorical_accuracy: 0.5769
# Epoch 4/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8514 - sparse_categorical_accuracy: 0.5866
# Epoch 5/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8521 - sparse_categorical_accuracy: 0.5841
# Epoch 6/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8538 - sparse_categorical_accuracy: 0.5911
# Epoch 7/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8514 - sparse_categorical_accuracy: 0.5879
# Epoch 8/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8494 - sparse_categorical_accuracy: 0.5834
# Epoch 9/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8528 - sparse_categorical_accuracy: 0.5904
# Epoch 10/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8506 - sparse_categorical_accuracy: 0.5879
# Epoch 11/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8531 - sparse_categorical_accuracy: 0.5896
# Epoch 12/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8506 - sparse_categorical_accuracy: 0.5896
# Epoch 13/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8491 - sparse_categorical_accuracy: 0.5811
# Epoch 14/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8509 - sparse_categorical_accuracy: 0.5871
# Epoch 15/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8505 - sparse_categorical_accuracy: 0.5864
# Epoch 16/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8481 - sparse_categorical_accuracy: 0.5921
# Epoch 17/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8481 - sparse_categorical_accuracy: 0.5824
# Epoch 18/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8516 - sparse_categorical_accuracy: 0.5891
# Epoch 19/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8527 - sparse_categorical_accuracy: 0.5826
# Epoch 20/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8484 - sparse_categorical_accuracy: 0.5879
# >acc=0.5723,>f1=0.5321,>rec=0.5251,>roc=0.6449
# [[164  74   1]
#  [ 83 172  28]
#  [ 13  79  36]]
# Epoch 1/20
# 124/124 [==============================] - 1s 2ms/step - loss: 0.9755 - sparse_categorical_accuracy: 0.5342
# Epoch 2/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8754 - sparse_categorical_accuracy: 0.5803
# Epoch 3/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8542 - sparse_categorical_accuracy: 0.5828
# Epoch 4/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8543 - sparse_categorical_accuracy: 0.5861
# Epoch 5/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8518 - sparse_categorical_accuracy: 0.5863
# Epoch 6/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8520 - sparse_categorical_accuracy: 0.5891
# Epoch 7/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8515 - sparse_categorical_accuracy: 0.5891
# Epoch 8/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8536 - sparse_categorical_accuracy: 0.5866
# Epoch 9/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8536 - sparse_categorical_accuracy: 0.5889
# Epoch 10/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8513 - sparse_categorical_accuracy: 0.5909
# Epoch 11/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8540 - sparse_categorical_accuracy: 0.5911
# Epoch 12/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8513 - sparse_categorical_accuracy: 0.5878
# Epoch 13/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8501 - sparse_categorical_accuracy: 0.5891
# Epoch 14/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8571 - sparse_categorical_accuracy: 0.5894
# Epoch 15/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8534 - sparse_categorical_accuracy: 0.5904
# Epoch 16/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8524 - sparse_categorical_accuracy: 0.5980
# Epoch 17/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8488 - sparse_categorical_accuracy: 0.5914
# Epoch 18/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8534 - sparse_categorical_accuracy: 0.5881
# Epoch 19/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8527 - sparse_categorical_accuracy: 0.5871
# Epoch 20/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8491 - sparse_categorical_accuracy: 0.5939
# >acc=0.5415,>f1=0.5051,>rec=0.4972,>roc=0.6224
# [[150  87   1]
#  [ 84 167  33]
#  [ 11  82  35]]
# Epoch 1/20
# 124/124 [==============================] - 0s 2ms/step - loss: 0.9671 - sparse_categorical_accuracy: 0.5500
# Epoch 2/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8757 - sparse_categorical_accuracy: 0.5863
# Epoch 3/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8634 - sparse_categorical_accuracy: 0.5785
# Epoch 4/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8570 - sparse_categorical_accuracy: 0.5810
# Epoch 5/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8579 - sparse_categorical_accuracy: 0.5846
# Epoch 6/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8587 - sparse_categorical_accuracy: 0.5881
# Epoch 7/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8587 - sparse_categorical_accuracy: 0.5803
# Epoch 8/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8573 - sparse_categorical_accuracy: 0.5901
# Epoch 9/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8563 - sparse_categorical_accuracy: 0.5876
# Epoch 10/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8577 - sparse_categorical_accuracy: 0.5835
# Epoch 11/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8583 - sparse_categorical_accuracy: 0.5909
# Epoch 12/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8569 - sparse_categorical_accuracy: 0.5820
# Epoch 13/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8531 - sparse_categorical_accuracy: 0.5916
# Epoch 14/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8557 - sparse_categorical_accuracy: 0.5843
# Epoch 15/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8571 - sparse_categorical_accuracy: 0.5825
# Epoch 16/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8575 - sparse_categorical_accuracy: 0.5838
# Epoch 17/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8570 - sparse_categorical_accuracy: 0.5888
# Epoch 18/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8580 - sparse_categorical_accuracy: 0.5861
# Epoch 19/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8540 - sparse_categorical_accuracy: 0.5871
# Epoch 20/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8562 - sparse_categorical_accuracy: 0.5886
# >acc=0.5600,>f1=0.5453,>rec=0.5323,>roc=0.6453
# [[148  86   4]
#  [ 91 166  27]
#  [ 10  68  50]]
# Epoch 1/20
# 125/125 [==============================] - 1s 2ms/step - loss: 0.9823 - sparse_categorical_accuracy: 0.5333
# Epoch 2/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8779 - sparse_categorical_accuracy: 0.5872
# Epoch 3/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8576 - sparse_categorical_accuracy: 0.5842
# Epoch 4/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8549 - sparse_categorical_accuracy: 0.5812
# Epoch 5/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8534 - sparse_categorical_accuracy: 0.5807
# Epoch 6/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8579 - sparse_categorical_accuracy: 0.5810
# Epoch 7/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8584 - sparse_categorical_accuracy: 0.5832
# Epoch 8/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8591 - sparse_categorical_accuracy: 0.5857
# Epoch 9/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8543 - sparse_categorical_accuracy: 0.5832
# Epoch 10/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8580 - sparse_categorical_accuracy: 0.5852
# Epoch 11/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8597 - sparse_categorical_accuracy: 0.5888
# Epoch 12/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8573 - sparse_categorical_accuracy: 0.5787
# Epoch 13/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8569 - sparse_categorical_accuracy: 0.5872
# Epoch 14/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8543 - sparse_categorical_accuracy: 0.5840
# Epoch 15/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8543 - sparse_categorical_accuracy: 0.5852
# Epoch 16/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8560 - sparse_categorical_accuracy: 0.5860
# Epoch 17/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8534 - sparse_categorical_accuracy: 0.5877
# Epoch 18/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8569 - sparse_categorical_accuracy: 0.5862
# Epoch 19/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8541 - sparse_categorical_accuracy: 0.5860
# Epoch 20/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8519 - sparse_categorical_accuracy: 0.5852
# >acc=0.5815,>f1=0.5602,>rec=0.5445,>roc=0.6562
# [[142  95   1]
#  [ 72 188  24]
#  [ 15  65  48]]
# Epoch 1/20
# 124/124 [==============================] - 1s 2ms/step - loss: 1.0008 - sparse_categorical_accuracy: 0.4884
# Epoch 2/20
# 124/124 [==============================] - 0s 2ms/step - loss: 0.8799 - sparse_categorical_accuracy: 0.5903
# Epoch 3/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8460 - sparse_categorical_accuracy: 0.6070
# Epoch 4/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8492 - sparse_categorical_accuracy: 0.5974
# Epoch 5/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8453 - sparse_categorical_accuracy: 0.5964
# Epoch 6/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8461 - sparse_categorical_accuracy: 0.6002
# Epoch 7/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8441 - sparse_categorical_accuracy: 0.5987
# Epoch 8/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8464 - sparse_categorical_accuracy: 0.5987
# Epoch 9/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8449 - sparse_categorical_accuracy: 0.5931
# Epoch 10/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8454 - sparse_categorical_accuracy: 0.5926
# Epoch 11/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8475 - sparse_categorical_accuracy: 0.5982
# Epoch 12/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8468 - sparse_categorical_accuracy: 0.5974
# Epoch 13/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8441 - sparse_categorical_accuracy: 0.6035
# Epoch 14/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8420 - sparse_categorical_accuracy: 0.6048
# Epoch 15/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8449 - sparse_categorical_accuracy: 0.5972
# Epoch 16/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8433 - sparse_categorical_accuracy: 0.5956
# Epoch 17/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8450 - sparse_categorical_accuracy: 0.5992
# Epoch 18/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8459 - sparse_categorical_accuracy: 0.5954
# Epoch 19/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8462 - sparse_categorical_accuracy: 0.5969
# Epoch 20/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8422 - sparse_categorical_accuracy: 0.6017
# >acc=0.5008,>f1=0.4759,>rec=0.4662,>roc=0.5958
# [[137  97   4]
#  [104 151  29]
#  [ 15  75  37]]
# Epoch 1/20
# 124/124 [==============================] - 1s 2ms/step - loss: 0.9597 - sparse_categorical_accuracy: 0.5334
# Epoch 2/20
# 124/124 [==============================] - 0s 2ms/step - loss: 0.8732 - sparse_categorical_accuracy: 0.5780
# Epoch 3/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8554 - sparse_categorical_accuracy: 0.5872
# Epoch 4/20
# 124/124 [==============================] - 0s 2ms/step - loss: 0.8503 - sparse_categorical_accuracy: 0.5841
# Epoch 5/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8518 - sparse_categorical_accuracy: 0.5887
# Epoch 6/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8520 - sparse_categorical_accuracy: 0.5945
# Epoch 7/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8497 - sparse_categorical_accuracy: 0.5960
# Epoch 8/20
# 124/124 [==============================] - 0s 2ms/step - loss: 0.8503 - sparse_categorical_accuracy: 0.5902
# Epoch 9/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8480 - sparse_categorical_accuracy: 0.5897
# Epoch 10/20
# 124/124 [==============================] - 0s 2ms/step - loss: 0.8481 - sparse_categorical_accuracy: 0.5930
# Epoch 11/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8474 - sparse_categorical_accuracy: 0.5940
# Epoch 12/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8503 - sparse_categorical_accuracy: 0.5917
# Epoch 13/20
# 124/124 [==============================] - 0s 2ms/step - loss: 0.8512 - sparse_categorical_accuracy: 0.5927
# Epoch 14/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8479 - sparse_categorical_accuracy: 0.5927
# Epoch 15/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8486 - sparse_categorical_accuracy: 0.5925
# Epoch 16/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8465 - sparse_categorical_accuracy: 0.5950
# Epoch 17/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8455 - sparse_categorical_accuracy: 0.5945
# Epoch 18/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8505 - sparse_categorical_accuracy: 0.6026
# Epoch 19/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8483 - sparse_categorical_accuracy: 0.5910
# Epoch 20/20
# 124/124 [==============================] - 0s 1ms/step - loss: 0.8515 - sparse_categorical_accuracy: 0.5950
# >acc=0.5270,>f1=0.4912,>rec=0.4844,>roc=0.6127
# [[142  91   5]
#  [ 86 165  33]
#  [ 20  72  35]]
# Epoch 1/20
# 125/125 [==============================] - 1s 2ms/step - loss: 0.9977 - sparse_categorical_accuracy: 0.4673
# Epoch 2/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8901 - sparse_categorical_accuracy: 0.5792
# Epoch 3/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8631 - sparse_categorical_accuracy: 0.5774
# Epoch 4/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8533 - sparse_categorical_accuracy: 0.5872
# Epoch 5/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8535 - sparse_categorical_accuracy: 0.5749
# Epoch 6/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8545 - sparse_categorical_accuracy: 0.5862
# Epoch 7/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8535 - sparse_categorical_accuracy: 0.5875
# Epoch 8/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8523 - sparse_categorical_accuracy: 0.5839
# Epoch 9/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8543 - sparse_categorical_accuracy: 0.5812
# Epoch 10/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8569 - sparse_categorical_accuracy: 0.5880
# Epoch 11/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8511 - sparse_categorical_accuracy: 0.5897
# Epoch 12/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8490 - sparse_categorical_accuracy: 0.5890
# Epoch 13/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8560 - sparse_categorical_accuracy: 0.5849
# Epoch 14/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8580 - sparse_categorical_accuracy: 0.5829
# Epoch 15/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8520 - sparse_categorical_accuracy: 0.5844
# Epoch 16/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8525 - sparse_categorical_accuracy: 0.5960
# Epoch 17/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8519 - sparse_categorical_accuracy: 0.5852
# Epoch 18/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8526 - sparse_categorical_accuracy: 0.5854
# Epoch 19/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8505 - sparse_categorical_accuracy: 0.5942
# Epoch 20/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8528 - sparse_categorical_accuracy: 0.5882
# >acc=0.5393,>f1=0.5032,>rec=0.4973,>roc=0.6228
# [[151  81   6]
#  [ 87 163  34]
#  [ 15  76  36]]

# %%
print("Accuracy: %.4f (%.4f)" % (np.mean(kf_accuracy), np.std(kf_accuracy)))
print("F1-score: %.4f (%.4f)" % (np.mean(kf_f1), np.std(kf_f1)))
print("Recall: %.4f (%.4f)" % (np.mean(kf_recall), np.std(kf_recall)))
print("ROC: %.4f (%.4f)" % (np.mean(kf_roc), np.std(kf_roc)))
# Out:
# Accuracy: 0.5462 (0.0215)
# F1-score: 0.5137 (0.0240)
# Recall: 0.5044 (0.0221)
# ROC: 0.6272 (0.0166)

# %%
conf_mat_mean = np.mean(kf_conf_mat,axis=0)

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
plot_confusion_matrix(conf_mat_mean,["0-Bad","1-Medium","2-Good"])
plt.savefig('MLP_PCA_ENN.png', transparent=True, dpi=300, bbox_inches="tight")
# Out:
# Confusion matrix, without normalization
# [[146.3  89.1   3. ]
#  [ 84.3 170.5  28.8]
#  [ 13.5  76.1  38.1]]
