# %%
import pandas as pd
import numpy as np
from keras.utils import np_utils
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import roc_auc_score,confusion_matrix, accuracy_score, make_scorer, f1_score,precision_score,recall_score, plot_confusion_matrix
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
from sklearn.decomposition import PCA
from imblearn.under_sampling import EditedNearestNeighbours
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
def print_distribution(arr, print_nl=True):
    arr = np.unique(arr, return_counts=True)[1] / len(arr)
    for i in range(arr.shape[0]):
        print("Classe %d: %.2f%%" %(i, arr[i]*100))

    if print_nl:
        print("\n")

# %%
def taste(quality):
  if quality <= 5:
    return 0
  elif quality == 6:
    return 1
  else:
    return 2

# %%
data = pd.read_csv("wine_quality.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed.acidity         6497 non-null   float64
#  1   volatile.acidity      6497 non-null   float64
#  2   citric.acid           6497 non-null   float64
#  3   residual.sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free.sulfur.dioxide   6497 non-null   float64
#  6   total.sulfur.dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 609.2 KB

# %%
new_data = data
new_data["taste"] = data["quality"].apply(taste)

# %%
new_data
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  taste
# 0         9.4        5      0
# 1         9.8        5      0
# 2         9.8        5      0
# 3         9.8        6      1
# 4         9.4        5      0
# ...       ...      ...    ...
# 6492     11.2        6      1
# 6493      9.6        5      0
# 6494      9.4        6      1
# 6495     12.8        7      2
# 6496     11.8        6      1
#
# [6497 rows x 13 columns]

# %% [markdown]
# ## Divisão de base de dados e separação de base

# %%
X = new_data.iloc[:, 0:11].values
y = new_data.iloc[:, 12].values

# %%
scaler = MinMaxScaler()
scaler.fit(X)
print(scaler.data_max_)
X_normalized = scaler.transform(X)
print(X_normalized)
# Out:
# [ 15.9       1.58      1.66     65.8       0.611   289.      440.
#    1.03898   4.01      2.       14.9    ]
# [[0.29752066 0.41333333 0.         ... 0.6124031  0.19101124 0.20289855]
#  [0.33057851 0.53333333 0.         ... 0.37209302 0.25842697 0.26086957]
#  [0.33057851 0.45333333 0.02409639 ... 0.41860465 0.24157303 0.26086957]
#  ...
#  [0.2231405  0.10666667 0.11445783 ... 0.20930233 0.13483146 0.20289855]
#  [0.14049587 0.14       0.18072289 ... 0.48062016 0.08988764 0.69565217]
#  [0.18181818 0.08666667 0.22891566 ... 0.41860465 0.05617978 0.55072464]]

# %%
print("Proporções por classe no dataset em geral:")
print_distribution(y)

kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=199)
fold = 0
for train, test in kf.split(X_normalized, y):
    print("Fold %d" %(fold))
    print_distribution(y[train], print_nl=(fold != 2))
    fold += 1
# Out:
# Proporções por classe no dataset em geral:
# Classe 0: 36.69%
# Classe 1: 43.65%
# Classe 2: 19.66%
#
#
# Fold 0
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 1
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 2
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
# Fold 3
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 4
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 5
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 6
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 7
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 8
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 9
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%

# %%
kf_accuracy = list()
kf_conf_mat = list()
kf_precision = list()
kf_f1 = list()
kf_recall = list()
kf_roc = list()

# %%
# pca = PCA(n_components=5)
# fit = pca.fit(X_normalized)
# # summarize components
# print("Explained Variance: %s" % fit.explained_variance_ratio_)
# print(fit.components_)

# %%
pca = PCA(n_components=5)
enn = EditedNearestNeighbours()

# %% [markdown]
# ## Laço para execução do gridsearch em cada fold

# %%
for train_ix, test_ix in kf.split(X_normalized,y):
    X_train, X_test = X_normalized[train_ix, :], X_normalized[test_ix, :]
    y_train, y_test = y[train_ix], y[test_ix]
    X_train_pca = pca.fit_transform(X_train)
    X_test_pca = pca.transform(X_test)
    X_train_res, y_train_res = enn.fit_resample(X_train_pca, y_train)
    #X_test_res, y_test_res = enn.fit_resample(X_test_pca, y_test)
    model = Sequential()
    model.add(Dense(units=16, activation="linear",input_dim=5))
    model.add(Dropout(0.1))
    model.add(Dense(units=16, activation="linear"))
    model.add(Dropout(0.1))
    model.add(Dense(units=3, activation="softmax"))
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"])
    # execução
    result = model.fit(X_train_res, y_train_res, batch_size=32, epochs=20)
    # teste dos melhores parâmetros
    predicted_y = model.predict(X_test_pca)
    #y_test_transform = [np.argmax(t) for t in y_test]
    predicted_y_transform = [np.argmax(t) for t in predicted_y]
    #transformação de itens para cálculo do ROC
    le = LabelEncoder()
    y_test_dummy = le.fit_transform(y_test)
    predicted_y_dummy = le.fit_transform(predicted_y_transform)
    y_test_dummy = np_utils.to_categorical(y_test)
    predicted_y_dummy = np_utils.to_categorical(predicted_y_dummy)
    # métricas do modelo
    acc = accuracy_score(y_test, predicted_y_transform)
    conf_mat = confusion_matrix(y_test, predicted_y_transform)
    f1 = f1_score(y_test, predicted_y_transform, average = "macro")
    recall = recall_score(y_test, predicted_y_transform, average = "macro")
    roc = roc_auc_score(y_test_dummy,predicted_y_dummy,multi_class="ovo",average = "macro")
    #armazenamento de métricas
    kf_accuracy.append(acc)
    kf_conf_mat.append(conf_mat)
    kf_f1.append(f1)
    kf_recall.append(recall)
    kf_roc.append(roc)
    #métricas
    print(">acc=%.4f,>f1=%.4f,>rec=%.4f,>roc=%.4f" % (acc,f1,recall,roc))
    print(conf_mat)
# Out:
# Epoch 1/20
# 79/79 [==============================] - 1s 3ms/step - loss: 1.0089 - sparse_categorical_accuracy: 0.5375
# Epoch 2/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.8418 - sparse_categorical_accuracy: 0.6543
# Epoch 3/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7614 - sparse_categorical_accuracy: 0.6687
# Epoch 4/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7476 - sparse_categorical_accuracy: 0.6699
# Epoch 5/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7372 - sparse_categorical_accuracy: 0.6711
# Epoch 6/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7336 - sparse_categorical_accuracy: 0.6715
# Epoch 7/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7301 - sparse_categorical_accuracy: 0.6770
# Epoch 8/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7308 - sparse_categorical_accuracy: 0.6774
# Epoch 9/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7285 - sparse_categorical_accuracy: 0.6826
# Epoch 10/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7301 - sparse_categorical_accuracy: 0.6762
# Epoch 11/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7324 - sparse_categorical_accuracy: 0.6810
# Epoch 12/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7281 - sparse_categorical_accuracy: 0.6786
# Epoch 13/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7323 - sparse_categorical_accuracy: 0.6754
# Epoch 14/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7287 - sparse_categorical_accuracy: 0.6782
# Epoch 15/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7297 - sparse_categorical_accuracy: 0.6782
# Epoch 16/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7289 - sparse_categorical_accuracy: 0.6778
# Epoch 17/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7281 - sparse_categorical_accuracy: 0.6778
# Epoch 18/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7264 - sparse_categorical_accuracy: 0.6746
# Epoch 19/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7261 - sparse_categorical_accuracy: 0.6730
# Epoch 20/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7264 - sparse_categorical_accuracy: 0.6810
# >acc=0.4354,>f1=0.4023,>rec=0.5331,>roc=0.6391
# [[145  20  74]
#  [ 77  20 186]
#  [  9   1 118]]
# Epoch 1/20
# 80/80 [==============================] - 2s 3ms/step - loss: 1.0123 - sparse_categorical_accuracy: 0.5349
# Epoch 2/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.8582 - sparse_categorical_accuracy: 0.6506
# Epoch 3/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7740 - sparse_categorical_accuracy: 0.6639
# Epoch 4/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7505 - sparse_categorical_accuracy: 0.6710
# Epoch 5/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7448 - sparse_categorical_accuracy: 0.6718
# Epoch 6/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7522 - sparse_categorical_accuracy: 0.6757
# Epoch 7/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7439 - sparse_categorical_accuracy: 0.6725
# Epoch 8/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7470 - sparse_categorical_accuracy: 0.6733
# Epoch 9/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7434 - sparse_categorical_accuracy: 0.6839
# Epoch 10/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7472 - sparse_categorical_accuracy: 0.6722
# Epoch 11/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7450 - sparse_categorical_accuracy: 0.6769
# Epoch 12/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7446 - sparse_categorical_accuracy: 0.6769
# Epoch 13/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7412 - sparse_categorical_accuracy: 0.6776
# Epoch 14/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7388 - sparse_categorical_accuracy: 0.6788
# Epoch 15/20
# 80/80 [==============================] - 0s 4ms/step - loss: 0.7421 - sparse_categorical_accuracy: 0.6816
# Epoch 16/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7470 - sparse_categorical_accuracy: 0.6796
# Epoch 17/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7398 - sparse_categorical_accuracy: 0.6741
# Epoch 18/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7454 - sparse_categorical_accuracy: 0.6784
# Epoch 19/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7388 - sparse_categorical_accuracy: 0.6737
# Epoch 20/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7387 - sparse_categorical_accuracy: 0.6769
# >acc=0.4292,>f1=0.4004,>rec=0.5160,>roc=0.6267
# [[147  28  64]
#  [ 83  23 177]
#  [ 13   6 109]]
# Epoch 1/20
# 79/79 [==============================] - 1s 3ms/step - loss: 1.0435 - sparse_categorical_accuracy: 0.4720
# Epoch 2/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.8976 - sparse_categorical_accuracy: 0.6161
# Epoch 3/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7922 - sparse_categorical_accuracy: 0.6617
# Epoch 4/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7575 - sparse_categorical_accuracy: 0.6597
# Epoch 5/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7452 - sparse_categorical_accuracy: 0.6685
# Epoch 6/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7506 - sparse_categorical_accuracy: 0.6681
# Epoch 7/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7401 - sparse_categorical_accuracy: 0.6717
# Epoch 8/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7402 - sparse_categorical_accuracy: 0.6681
# Epoch 9/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7449 - sparse_categorical_accuracy: 0.6713
# Epoch 10/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7437 - sparse_categorical_accuracy: 0.6729
# Epoch 11/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7429 - sparse_categorical_accuracy: 0.6693
# Epoch 12/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7411 - sparse_categorical_accuracy: 0.6665
# Epoch 13/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7388 - sparse_categorical_accuracy: 0.6721
# Epoch 14/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7444 - sparse_categorical_accuracy: 0.6729
# Epoch 15/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7443 - sparse_categorical_accuracy: 0.6709
# Epoch 16/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7432 - sparse_categorical_accuracy: 0.6681
# Epoch 17/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7409 - sparse_categorical_accuracy: 0.6681
# Epoch 18/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7416 - sparse_categorical_accuracy: 0.6713
# Epoch 19/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7390 - sparse_categorical_accuracy: 0.6757
# Epoch 20/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7429 - sparse_categorical_accuracy: 0.6749
# >acc=0.4585,>f1=0.4338,>rec=0.5401,>roc=0.6454
# [[155  27  57]
#  [ 78  34 171]
#  [ 14   5 109]]
# Epoch 1/20
# 80/80 [==============================] - 1s 3ms/step - loss: 0.9243 - sparse_categorical_accuracy: 0.6528
# Epoch 2/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.8000 - sparse_categorical_accuracy: 0.6677
# Epoch 3/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7652 - sparse_categorical_accuracy: 0.6713
# Epoch 4/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7477 - sparse_categorical_accuracy: 0.6705
# Epoch 5/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7415 - sparse_categorical_accuracy: 0.6732
# Epoch 6/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7341 - sparse_categorical_accuracy: 0.6713
# Epoch 7/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7376 - sparse_categorical_accuracy: 0.6732
# Epoch 8/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7409 - sparse_categorical_accuracy: 0.6713
# Epoch 9/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7402 - sparse_categorical_accuracy: 0.6689
# Epoch 10/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7414 - sparse_categorical_accuracy: 0.6693
# Epoch 11/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7367 - sparse_categorical_accuracy: 0.6693
# Epoch 12/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7387 - sparse_categorical_accuracy: 0.6713
# Epoch 13/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7369 - sparse_categorical_accuracy: 0.6681
# Epoch 14/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7377 - sparse_categorical_accuracy: 0.6685
# Epoch 15/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7382 - sparse_categorical_accuracy: 0.6681
# Epoch 16/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7369 - sparse_categorical_accuracy: 0.6697
# Epoch 17/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7349 - sparse_categorical_accuracy: 0.6752
# Epoch 18/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7467 - sparse_categorical_accuracy: 0.6665
# Epoch 19/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7397 - sparse_categorical_accuracy: 0.6685
# Epoch 20/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7455 - sparse_categorical_accuracy: 0.6681
# >acc=0.4785,>f1=0.4527,>rec=0.5610,>roc=0.6614
# [[161  16  62]
#  [ 81  38 164]
#  [ 10   6 112]]
# Epoch 1/20
# 80/80 [==============================] - 1s 3ms/step - loss: 1.0479 - sparse_categorical_accuracy: 0.4349
# Epoch 2/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.8949 - sparse_categorical_accuracy: 0.6295
# Epoch 3/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7941 - sparse_categorical_accuracy: 0.6637
# Epoch 4/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7536 - sparse_categorical_accuracy: 0.6625
# Epoch 5/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7374 - sparse_categorical_accuracy: 0.6652
# Epoch 6/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7344 - sparse_categorical_accuracy: 0.6719
# Epoch 7/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7311 - sparse_categorical_accuracy: 0.6703
# Epoch 8/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7320 - sparse_categorical_accuracy: 0.6719
# Epoch 9/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7333 - sparse_categorical_accuracy: 0.6688
# Epoch 10/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7313 - sparse_categorical_accuracy: 0.6688
# Epoch 11/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7331 - sparse_categorical_accuracy: 0.6727
# Epoch 12/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7293 - sparse_categorical_accuracy: 0.6766
# Epoch 13/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7300 - sparse_categorical_accuracy: 0.6711
# Epoch 14/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7308 - sparse_categorical_accuracy: 0.6688
# Epoch 15/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7284 - sparse_categorical_accuracy: 0.6692
# Epoch 16/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7331 - sparse_categorical_accuracy: 0.6692
# Epoch 17/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7348 - sparse_categorical_accuracy: 0.6680
# Epoch 18/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7250 - sparse_categorical_accuracy: 0.6754
# Epoch 19/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7306 - sparse_categorical_accuracy: 0.6699
# Epoch 20/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7309 - sparse_categorical_accuracy: 0.6668
# >acc=0.4662,>f1=0.4475,>rec=0.5484,>roc=0.6497
# [[150  35  53]
#  [ 85  42 157]
#  [ 12   5 111]]
# Epoch 1/20
# 81/81 [==============================] - 1s 3ms/step - loss: 1.0292 - sparse_categorical_accuracy: 0.4926
# Epoch 2/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8804 - sparse_categorical_accuracy: 0.6382
# Epoch 3/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7894 - sparse_categorical_accuracy: 0.6702
# Epoch 4/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7594 - sparse_categorical_accuracy: 0.6690
# Epoch 5/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7477 - sparse_categorical_accuracy: 0.6702
# Epoch 6/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7481 - sparse_categorical_accuracy: 0.6682
# Epoch 7/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7511 - sparse_categorical_accuracy: 0.6760
# Epoch 8/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7458 - sparse_categorical_accuracy: 0.6682
# Epoch 9/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7462 - sparse_categorical_accuracy: 0.6756
# Epoch 10/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7407 - sparse_categorical_accuracy: 0.6733
# Epoch 11/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7449 - sparse_categorical_accuracy: 0.6717
# Epoch 12/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7455 - sparse_categorical_accuracy: 0.6729
# Epoch 13/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7434 - sparse_categorical_accuracy: 0.6733
# Epoch 14/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7457 - sparse_categorical_accuracy: 0.6710
# Epoch 15/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7444 - sparse_categorical_accuracy: 0.6768
# Epoch 16/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7435 - sparse_categorical_accuracy: 0.6710
# Epoch 17/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7426 - sparse_categorical_accuracy: 0.6725
# Epoch 18/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7431 - sparse_categorical_accuracy: 0.6706
# Epoch 19/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7415 - sparse_categorical_accuracy: 0.6753
# Epoch 20/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7426 - sparse_categorical_accuracy: 0.6682
# >acc=0.4508,>f1=0.4224,>rec=0.5436,>roc=0.6456
# [[149  26  63]
#  [ 89  28 167]
#  [ 10   2 116]]
# Epoch 1/20
# 80/80 [==============================] - 1s 3ms/step - loss: 0.9827 - sparse_categorical_accuracy: 0.5831
# Epoch 2/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.8357 - sparse_categorical_accuracy: 0.6633
# Epoch 3/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7659 - sparse_categorical_accuracy: 0.6747
# Epoch 4/20
# 80/80 [==============================] - 0s 4ms/step - loss: 0.7436 - sparse_categorical_accuracy: 0.6711
# Epoch 5/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7401 - sparse_categorical_accuracy: 0.6750
# Epoch 6/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7375 - sparse_categorical_accuracy: 0.6747
# Epoch 7/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7385 - sparse_categorical_accuracy: 0.6731
# Epoch 8/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7370 - sparse_categorical_accuracy: 0.6782
# Epoch 9/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7346 - sparse_categorical_accuracy: 0.6703
# Epoch 10/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7354 - sparse_categorical_accuracy: 0.6731
# Epoch 11/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7351 - sparse_categorical_accuracy: 0.6743
# Epoch 12/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7340 - sparse_categorical_accuracy: 0.6747
# Epoch 13/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7367 - sparse_categorical_accuracy: 0.6727
# Epoch 14/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7306 - sparse_categorical_accuracy: 0.6750
# Epoch 15/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7338 - sparse_categorical_accuracy: 0.6747
# Epoch 16/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7338 - sparse_categorical_accuracy: 0.6723
# Epoch 17/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7333 - sparse_categorical_accuracy: 0.6750
# Epoch 18/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7355 - sparse_categorical_accuracy: 0.6727
# Epoch 19/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7331 - sparse_categorical_accuracy: 0.6747
# Epoch 20/20
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7351 - sparse_categorical_accuracy: 0.6747
# >acc=0.4508,>f1=0.4263,>rec=0.5331,>roc=0.6398
# [[153  31  54]
#  [ 78  32 174]
#  [ 16   4 108]]
# Epoch 1/20
# 81/81 [==============================] - 1s 3ms/step - loss: 1.0532 - sparse_categorical_accuracy: 0.4639
# Epoch 2/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.9054 - sparse_categorical_accuracy: 0.6301
# Epoch 3/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7809 - sparse_categorical_accuracy: 0.6703
# Epoch 4/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7447 - sparse_categorical_accuracy: 0.6741
# Epoch 5/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7361 - sparse_categorical_accuracy: 0.6796
# Epoch 6/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7302 - sparse_categorical_accuracy: 0.6768
# Epoch 7/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7327 - sparse_categorical_accuracy: 0.6834
# Epoch 8/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7295 - sparse_categorical_accuracy: 0.6788
# Epoch 9/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7329 - sparse_categorical_accuracy: 0.6796
# Epoch 10/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7252 - sparse_categorical_accuracy: 0.6815
# Epoch 11/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7325 - sparse_categorical_accuracy: 0.6772
# Epoch 12/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7326 - sparse_categorical_accuracy: 0.6753
# Epoch 13/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7345 - sparse_categorical_accuracy: 0.6792
# Epoch 14/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7315 - sparse_categorical_accuracy: 0.6765
# Epoch 15/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7320 - sparse_categorical_accuracy: 0.6768
# Epoch 16/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7288 - sparse_categorical_accuracy: 0.6718
# Epoch 17/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7304 - sparse_categorical_accuracy: 0.6753
# Epoch 18/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7331 - sparse_categorical_accuracy: 0.6803
# Epoch 19/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7306 - sparse_categorical_accuracy: 0.6776
# Epoch 20/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7296 - sparse_categorical_accuracy: 0.6811
# >acc=0.4083,>f1=0.3874,>rec=0.4978,>roc=0.6128
# [[126  28  84]
#  [ 91  30 163]
#  [ 14   4 109]]
# Epoch 1/20
# 81/81 [==============================] - 1s 3ms/step - loss: 1.0117 - sparse_categorical_accuracy: 0.5434
# Epoch 2/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.8800 - sparse_categorical_accuracy: 0.6517
# Epoch 3/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7846 - sparse_categorical_accuracy: 0.6685
# Epoch 4/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7486 - sparse_categorical_accuracy: 0.6739
# Epoch 5/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7337 - sparse_categorical_accuracy: 0.6763
# Epoch 6/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7312 - sparse_categorical_accuracy: 0.6735
# Epoch 7/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7258 - sparse_categorical_accuracy: 0.6817
# Epoch 8/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7270 - sparse_categorical_accuracy: 0.6759
# Epoch 9/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7268 - sparse_categorical_accuracy: 0.6763
# Epoch 10/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7250 - sparse_categorical_accuracy: 0.6751
# Epoch 11/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7244 - sparse_categorical_accuracy: 0.6798
# Epoch 12/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7181 - sparse_categorical_accuracy: 0.6829
# Epoch 13/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7267 - sparse_categorical_accuracy: 0.6763
# Epoch 14/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7256 - sparse_categorical_accuracy: 0.6755
# Epoch 15/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7254 - sparse_categorical_accuracy: 0.6802
# Epoch 16/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7289 - sparse_categorical_accuracy: 0.6763
# Epoch 17/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7267 - sparse_categorical_accuracy: 0.6813
# Epoch 18/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7276 - sparse_categorical_accuracy: 0.6790
# Epoch 19/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7215 - sparse_categorical_accuracy: 0.6821
# Epoch 20/20
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7223 - sparse_categorical_accuracy: 0.6841
# >acc=0.4237,>f1=0.3994,>rec=0.5057,>roc=0.6200
# [[141  26  71]
#  [ 89  30 165]
#  [ 20   3 104]]
# Epoch 1/20
# 79/79 [==============================] - 1s 4ms/step - loss: 1.0157 - sparse_categorical_accuracy: 0.5155
# Epoch 2/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.8604 - sparse_categorical_accuracy: 0.6529
# Epoch 3/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7765 - sparse_categorical_accuracy: 0.6732
# Epoch 4/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7496 - sparse_categorical_accuracy: 0.6692
# Epoch 5/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7404 - sparse_categorical_accuracy: 0.6724
# Epoch 6/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7390 - sparse_categorical_accuracy: 0.6716
# Epoch 7/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7355 - sparse_categorical_accuracy: 0.6704
# Epoch 8/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7351 - sparse_categorical_accuracy: 0.6732
# Epoch 9/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7378 - sparse_categorical_accuracy: 0.6763
# Epoch 10/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7422 - sparse_categorical_accuracy: 0.6739
# Epoch 11/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7356 - sparse_categorical_accuracy: 0.6704
# Epoch 12/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7388 - sparse_categorical_accuracy: 0.6724
# Epoch 13/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7352 - sparse_categorical_accuracy: 0.6720
# Epoch 14/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7400 - sparse_categorical_accuracy: 0.6696
# Epoch 15/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7403 - sparse_categorical_accuracy: 0.6743
# Epoch 16/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7370 - sparse_categorical_accuracy: 0.6692
# Epoch 17/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7351 - sparse_categorical_accuracy: 0.6732
# Epoch 18/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7360 - sparse_categorical_accuracy: 0.6716
# Epoch 19/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7358 - sparse_categorical_accuracy: 0.6716
# Epoch 20/20
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7383 - sparse_categorical_accuracy: 0.6767
# >acc=0.4499,>f1=0.4276,>rec=0.5345,>roc=0.6410
# [[148  27  63]
#  [ 79  35 170]
#  [ 14   4 109]]

# %%
print("Accuracy: %.4f (%.4f)" % (np.mean(kf_accuracy), np.std(kf_accuracy)))
print("F1-score: %.4f (%.4f)" % (np.mean(kf_f1), np.std(kf_f1)))
print("Recall: %.4f (%.4f)" % (np.mean(kf_recall), np.std(kf_recall)))
print("ROC: %.4f (%.4f)" % (np.mean(kf_roc), np.std(kf_roc)))
# Out:
# Accuracy: 0.4451 (0.0199)
# F1-score: 0.4200 (0.0207)
# Recall: 0.5313 (0.0185)
# ROC: 0.6382 (0.0138)

# %%
conf_mat_mean = np.mean(kf_conf_mat,axis=0)

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
plot_confusion_matrix(conf_mat_mean,["0-Bad","1-Medium","2-Good"])
plt.savefig('MLP_PCA_ENN.png', transparent=True, dpi=300, bbox_inches="tight")
# Out:
# Confusion matrix, without normalization
# [[147.5  26.4  64.5]
#  [ 83.   31.2 169.4]
#  [ 13.2   4.  110.5]]
