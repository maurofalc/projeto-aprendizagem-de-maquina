# %%
import pandas as pd
import numpy as np
from keras.utils import np_utils
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import roc_auc_score,confusion_matrix, accuracy_score, make_scorer, f1_score,precision_score,recall_score, plot_confusion_matrix
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
from sklearn.decomposition import PCA
from imblearn.under_sampling import EditedNearestNeighbours
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
def print_distribution(arr, print_nl=True):
    arr = np.unique(arr, return_counts=True)[1] / len(arr)
    for i in range(arr.shape[0]):
        print("Classe %d: %.2f%%" %(i, arr[i]*100))

    if print_nl:
        print("\n")

# %%
def taste(quality):
  if quality <= 5:
    return 0
  elif quality == 6:
    return 1
  else:
    return 2

# %%
data = pd.read_csv("wine_quality.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed.acidity         6497 non-null   float64
#  1   volatile.acidity      6497 non-null   float64
#  2   citric.acid           6497 non-null   float64
#  3   residual.sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free.sulfur.dioxide   6497 non-null   float64
#  6   total.sulfur.dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 609.2 KB

# %%
new_data = data
new_data["taste"] = data["quality"].apply(taste)

# %%
new_data
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  taste
# 0         9.4        5      0
# 1         9.8        5      0
# 2         9.8        5      0
# 3         9.8        6      1
# 4         9.4        5      0
# ...       ...      ...    ...
# 6492     11.2        6      1
# 6493      9.6        5      0
# 6494      9.4        6      1
# 6495     12.8        7      2
# 6496     11.8        6      1
#
# [6497 rows x 13 columns]

# %% [markdown]
# ## Divisão de base de dados e separação de base

# %%
X = new_data.iloc[:, 0:11].values
y = new_data.iloc[:, 12].values

# %%
scaler = MinMaxScaler()
scaler.fit(X)
print(scaler.data_max_)
X_normalized = scaler.transform(X)
print(X_normalized)
# Out:
# [ 15.9       1.58      1.66     65.8       0.611   289.      440.
#    1.03898   4.01      2.       14.9    ]
# [[0.29752066 0.41333333 0.         ... 0.6124031  0.19101124 0.20289855]
#  [0.33057851 0.53333333 0.         ... 0.37209302 0.25842697 0.26086957]
#  [0.33057851 0.45333333 0.02409639 ... 0.41860465 0.24157303 0.26086957]
#  ...
#  [0.2231405  0.10666667 0.11445783 ... 0.20930233 0.13483146 0.20289855]
#  [0.14049587 0.14       0.18072289 ... 0.48062016 0.08988764 0.69565217]
#  [0.18181818 0.08666667 0.22891566 ... 0.41860465 0.05617978 0.55072464]]

# %%
print("Proporções por classe no dataset em geral:")
print_distribution(y)

kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=199)
fold = 0
for train, test in kf.split(X_normalized, y):
    print("Fold %d" %(fold))
    print_distribution(y[train], print_nl=(fold != 2))
    fold += 1
# Out:
# Proporções por classe no dataset em geral:
# Classe 0: 36.69%
# Classe 1: 43.65%
# Classe 2: 19.66%
#
#
# Fold 0
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 1
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 2
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
# Fold 3
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 4
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 5
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 6
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 7
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 8
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 9
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%

# %%
kf_accuracy = list()
kf_conf_mat = list()
kf_precision = list()
kf_f1 = list()
kf_recall = list()
kf_roc = list()

# %%
pca = PCA(n_components=10)
enn = EditedNearestNeighbours(sampling_strategy='all', n_neighbors=1, kind_sel='all', n_jobs=-1)

# %% [markdown]
# ## Laço para execução do gridsearch em cada fold

# %%
for train_ix, test_ix in kf.split(X_normalized,y):
    X_train, X_test = X_normalized[train_ix, :], X_normalized[test_ix, :]
    y_train, y_test = y[train_ix], y[test_ix]
    X_train_pca = pca.fit_transform(X_train)
    X_test_pca = pca.transform(X_test)
    X_train_res, y_train_res = enn.fit_resample(X_train_pca, y_train)
    model = Sequential()
    model.add(Dense(units=16, activation="linear",input_dim=10))
    model.add(Dropout(0.1))
    model.add(Dense(units=16, activation="linear"))
    model.add(Dropout(0.1))
    model.add(Dense(units=3, activation="softmax"))
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"])
    # executar treinamento do modelo
    result = model.fit(X_train_res, y_train_res, batch_size=32, epochs=20)
    # teste dos melhores parâmetros
    predicted_y = model.predict(X_test_pca)
    predicted_y_transform = [np.argmax(t) for t in predicted_y]
    #transformação de itens para cálculo do ROC
    le = LabelEncoder()
    y_test_dummy = le.fit_transform(y_test)
    predicted_y_dummy = le.fit_transform(predicted_y_transform)
    y_test_dummy = np_utils.to_categorical(y_test)
    predicted_y_dummy = np_utils.to_categorical(predicted_y_dummy)
    # métricas do modelo
    acc = accuracy_score(y_test, predicted_y_transform)
    conf_mat = confusion_matrix(y_test, predicted_y_transform)
    f1 = f1_score(y_test, predicted_y_transform, average = "macro")
    recall = recall_score(y_test, predicted_y_transform, average = "macro")
    roc = roc_auc_score(y_test_dummy,predicted_y_dummy,multi_class="ovo",average = "macro")
    #armazenamento de métricas
    kf_accuracy.append(acc)
    kf_conf_mat.append(conf_mat)
    kf_f1.append(f1)
    kf_recall.append(recall)
    kf_roc.append(roc)
    #métricas
    print(">acc=%.4f,>f1=%.4f,>rec=%.4f,>roc=%.4f" % (acc,f1,recall,roc))
    print(conf_mat)
# Out:
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 1.0105 - sparse_categorical_accuracy: 0.5365
# Epoch 2/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8755 - sparse_categorical_accuracy: 0.5851
# Epoch 3/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8277 - sparse_categorical_accuracy: 0.6083
# Epoch 4/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8092 - sparse_categorical_accuracy: 0.6233
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8067 - sparse_categorical_accuracy: 0.6263
# Epoch 6/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8043 - sparse_categorical_accuracy: 0.6303
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8039 - sparse_categorical_accuracy: 0.6278
# Epoch 8/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8004 - sparse_categorical_accuracy: 0.6240
# Epoch 9/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8019 - sparse_categorical_accuracy: 0.6190
# Epoch 10/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7980 - sparse_categorical_accuracy: 0.6273
# Epoch 11/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8002 - sparse_categorical_accuracy: 0.6295
# Epoch 12/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8004 - sparse_categorical_accuracy: 0.6268
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7994 - sparse_categorical_accuracy: 0.6233
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7977 - sparse_categorical_accuracy: 0.6285
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8003 - sparse_categorical_accuracy: 0.6303
# Epoch 16/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7970 - sparse_categorical_accuracy: 0.6258
# Epoch 17/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8028 - sparse_categorical_accuracy: 0.6273
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7986 - sparse_categorical_accuracy: 0.6283
# Epoch 19/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8004 - sparse_categorical_accuracy: 0.6238
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7994 - sparse_categorical_accuracy: 0.6280
# >acc=0.5585,>f1=0.5340,>rec=0.5249,>roc=0.6421
# [[153  84   2]
#  [ 74 165  44]
#  [  4  79  45]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 0.9864 - sparse_categorical_accuracy: 0.5293
# Epoch 2/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8612 - sparse_categorical_accuracy: 0.5880
# Epoch 3/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8194 - sparse_categorical_accuracy: 0.6051
# Epoch 4/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8086 - sparse_categorical_accuracy: 0.6185
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8089 - sparse_categorical_accuracy: 0.6106
# Epoch 6/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8039 - sparse_categorical_accuracy: 0.6200
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8133 - sparse_categorical_accuracy: 0.6106
# Epoch 8/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8038 - sparse_categorical_accuracy: 0.6255
# Epoch 9/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8049 - sparse_categorical_accuracy: 0.6146
# Epoch 10/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8046 - sparse_categorical_accuracy: 0.6190
# Epoch 11/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8043 - sparse_categorical_accuracy: 0.6233
# Epoch 12/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8012 - sparse_categorical_accuracy: 0.6166
# Epoch 13/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8035 - sparse_categorical_accuracy: 0.6188
# Epoch 14/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8024 - sparse_categorical_accuracy: 0.6193
# Epoch 15/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8044 - sparse_categorical_accuracy: 0.6225
# Epoch 16/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7996 - sparse_categorical_accuracy: 0.6173
# Epoch 17/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8014 - sparse_categorical_accuracy: 0.6282
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8024 - sparse_categorical_accuracy: 0.6141
# Epoch 19/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7998 - sparse_categorical_accuracy: 0.6168
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7999 - sparse_categorical_accuracy: 0.6223
# >acc=0.5815,>f1=0.5467,>rec=0.5352,>roc=0.6520
# [[145  88   6]
#  [ 64 192  27]
#  [  8  79  41]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 1.0217 - sparse_categorical_accuracy: 0.4993
# Epoch 2/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8873 - sparse_categorical_accuracy: 0.5941
# Epoch 3/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8233 - sparse_categorical_accuracy: 0.6145
# Epoch 4/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8124 - sparse_categorical_accuracy: 0.6175
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8012 - sparse_categorical_accuracy: 0.6274
# Epoch 6/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8008 - sparse_categorical_accuracy: 0.6244
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7957 - sparse_categorical_accuracy: 0.6302
# Epoch 8/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8034 - sparse_categorical_accuracy: 0.6160
# Epoch 9/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7999 - sparse_categorical_accuracy: 0.6239
# Epoch 10/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7993 - sparse_categorical_accuracy: 0.6215
# Epoch 11/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7969 - sparse_categorical_accuracy: 0.6277
# Epoch 12/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7976 - sparse_categorical_accuracy: 0.6252
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8033 - sparse_categorical_accuracy: 0.6222
# Epoch 14/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7990 - sparse_categorical_accuracy: 0.6302
# Epoch 15/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7975 - sparse_categorical_accuracy: 0.6294
# Epoch 16/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7995 - sparse_categorical_accuracy: 0.6242
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7961 - sparse_categorical_accuracy: 0.6262
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7979 - sparse_categorical_accuracy: 0.6234
# Epoch 19/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7971 - sparse_categorical_accuracy: 0.6309
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7985 - sparse_categorical_accuracy: 0.6259
# >acc=0.5877,>f1=0.5633,>rec=0.5510,>roc=0.6621
# [[157  80   2]
#  [ 77 178  28]
#  [ 11  70  47]]
# Epoch 1/20
# 127/127 [==============================] - 1s 2ms/step - loss: 1.0153 - sparse_categorical_accuracy: 0.5046
# Epoch 2/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8632 - sparse_categorical_accuracy: 0.5982
# Epoch 3/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8201 - sparse_categorical_accuracy: 0.6138
# Epoch 4/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8082 - sparse_categorical_accuracy: 0.6195
# Epoch 5/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8031 - sparse_categorical_accuracy: 0.6093
# Epoch 6/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8028 - sparse_categorical_accuracy: 0.6247
# Epoch 7/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.7998 - sparse_categorical_accuracy: 0.6214
# Epoch 8/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8041 - sparse_categorical_accuracy: 0.6182
# Epoch 9/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.7997 - sparse_categorical_accuracy: 0.6148
# Epoch 10/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8030 - sparse_categorical_accuracy: 0.6187
# Epoch 11/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8024 - sparse_categorical_accuracy: 0.6207
# Epoch 12/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8030 - sparse_categorical_accuracy: 0.6185
# Epoch 13/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8046 - sparse_categorical_accuracy: 0.6214
# Epoch 14/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8039 - sparse_categorical_accuracy: 0.6210
# Epoch 15/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8016 - sparse_categorical_accuracy: 0.6182
# Epoch 16/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8043 - sparse_categorical_accuracy: 0.6180
# Epoch 17/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8065 - sparse_categorical_accuracy: 0.6170
# Epoch 18/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.7993 - sparse_categorical_accuracy: 0.6242
# Epoch 19/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8025 - sparse_categorical_accuracy: 0.6168
# Epoch 20/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8037 - sparse_categorical_accuracy: 0.6177
# >acc=0.5815,>f1=0.5480,>rec=0.5373,>roc=0.6535
# [[155  82   2]
#  [ 68 182  33]
#  [  6  81  41]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 1.0194 - sparse_categorical_accuracy: 0.4703
# Epoch 2/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8800 - sparse_categorical_accuracy: 0.6031
# Epoch 3/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8237 - sparse_categorical_accuracy: 0.6184
# Epoch 4/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8056 - sparse_categorical_accuracy: 0.6159
# Epoch 5/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8105 - sparse_categorical_accuracy: 0.6204
# Epoch 6/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8084 - sparse_categorical_accuracy: 0.6256
# Epoch 7/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8043 - sparse_categorical_accuracy: 0.6249
# Epoch 8/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8076 - sparse_categorical_accuracy: 0.6246
# Epoch 9/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8067 - sparse_categorical_accuracy: 0.6241
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8045 - sparse_categorical_accuracy: 0.6194
# Epoch 11/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8013 - sparse_categorical_accuracy: 0.6259
# Epoch 12/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8041 - sparse_categorical_accuracy: 0.6204
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8023 - sparse_categorical_accuracy: 0.6274
# Epoch 14/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8074 - sparse_categorical_accuracy: 0.6174
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8042 - sparse_categorical_accuracy: 0.6251
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8074 - sparse_categorical_accuracy: 0.6199
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8002 - sparse_categorical_accuracy: 0.6269
# Epoch 18/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8054 - sparse_categorical_accuracy: 0.6244
# Epoch 19/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8029 - sparse_categorical_accuracy: 0.6256
# Epoch 20/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8046 - sparse_categorical_accuracy: 0.6234
# >acc=0.5754,>f1=0.5320,>rec=0.5242,>roc=0.6451
# [[155  81   2]
#  [ 66 184  34]
#  [  8  85  35]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 0.9695 - sparse_categorical_accuracy: 0.5468
# Epoch 2/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8632 - sparse_categorical_accuracy: 0.5918
# Epoch 3/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8283 - sparse_categorical_accuracy: 0.6210
# Epoch 4/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8194 - sparse_categorical_accuracy: 0.6195
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8159 - sparse_categorical_accuracy: 0.6167
# Epoch 6/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8159 - sparse_categorical_accuracy: 0.6125
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8140 - sparse_categorical_accuracy: 0.6112
# Epoch 8/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8100 - sparse_categorical_accuracy: 0.6180
# Epoch 9/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8137 - sparse_categorical_accuracy: 0.6192
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8133 - sparse_categorical_accuracy: 0.6142
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8121 - sparse_categorical_accuracy: 0.6175
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8128 - sparse_categorical_accuracy: 0.6180
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8122 - sparse_categorical_accuracy: 0.6152
# Epoch 14/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8093 - sparse_categorical_accuracy: 0.6157
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8095 - sparse_categorical_accuracy: 0.6185
# Epoch 16/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8112 - sparse_categorical_accuracy: 0.6122
# Epoch 17/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8118 - sparse_categorical_accuracy: 0.6122
# Epoch 18/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8112 - sparse_categorical_accuracy: 0.6155
# Epoch 19/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8091 - sparse_categorical_accuracy: 0.6212
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8130 - sparse_categorical_accuracy: 0.6195
# >acc=0.5908,>f1=0.5737,>rec=0.5584,>roc=0.6660
# [[147  88   3]
#  [ 72 185  27]
#  [  4  72  52]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 1.0064 - sparse_categorical_accuracy: 0.5174
# Epoch 2/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8726 - sparse_categorical_accuracy: 0.5898
# Epoch 3/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8291 - sparse_categorical_accuracy: 0.6141
# Epoch 4/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8169 - sparse_categorical_accuracy: 0.6136
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8125 - sparse_categorical_accuracy: 0.6223
# Epoch 6/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8051 - sparse_categorical_accuracy: 0.6181
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8040 - sparse_categorical_accuracy: 0.6148
# Epoch 8/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8083 - sparse_categorical_accuracy: 0.6205
# Epoch 9/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8078 - sparse_categorical_accuracy: 0.6188
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8036 - sparse_categorical_accuracy: 0.6220
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8032 - sparse_categorical_accuracy: 0.6310
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8050 - sparse_categorical_accuracy: 0.6243
# Epoch 13/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8075 - sparse_categorical_accuracy: 0.6205
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8023 - sparse_categorical_accuracy: 0.6243
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8025 - sparse_categorical_accuracy: 0.6257
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8045 - sparse_categorical_accuracy: 0.6210
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8028 - sparse_categorical_accuracy: 0.6260
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8023 - sparse_categorical_accuracy: 0.6225
# Epoch 19/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8045 - sparse_categorical_accuracy: 0.6193
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7998 - sparse_categorical_accuracy: 0.6252
# >acc=0.5877,>f1=0.5694,>rec=0.5567,>roc=0.6650
# [[156  82   0]
#  [ 76 175  33]
#  [  7  70  51]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 0.9682 - sparse_categorical_accuracy: 0.5567
# Epoch 2/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8433 - sparse_categorical_accuracy: 0.6156
# Epoch 3/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8087 - sparse_categorical_accuracy: 0.6243
# Epoch 4/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8049 - sparse_categorical_accuracy: 0.6293
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7987 - sparse_categorical_accuracy: 0.6295
# Epoch 6/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7936 - sparse_categorical_accuracy: 0.6288
# Epoch 7/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7951 - sparse_categorical_accuracy: 0.6303
# Epoch 8/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7925 - sparse_categorical_accuracy: 0.6293
# Epoch 9/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7960 - sparse_categorical_accuracy: 0.6263
# Epoch 10/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7949 - sparse_categorical_accuracy: 0.6323
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7922 - sparse_categorical_accuracy: 0.6288
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7895 - sparse_categorical_accuracy: 0.6328
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7876 - sparse_categorical_accuracy: 0.6340
# Epoch 14/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7915 - sparse_categorical_accuracy: 0.6320
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7909 - sparse_categorical_accuracy: 0.6363
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7934 - sparse_categorical_accuracy: 0.6333
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7899 - sparse_categorical_accuracy: 0.6318
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7925 - sparse_categorical_accuracy: 0.6343
# Epoch 19/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7902 - sparse_categorical_accuracy: 0.6353
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7875 - sparse_categorical_accuracy: 0.6365
# >acc=0.5362,>f1=0.5083,>rec=0.4954,>roc=0.6190
# [[134  99   5]
#  [ 86 175  23]
#  [ 10  78  39]]
# Epoch 1/20
# 125/125 [==============================] - 1s 2ms/step - loss: 0.9501 - sparse_categorical_accuracy: 0.5510
# Epoch 2/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8385 - sparse_categorical_accuracy: 0.6150
# Epoch 3/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8150 - sparse_categorical_accuracy: 0.6173
# Epoch 4/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8067 - sparse_categorical_accuracy: 0.6215
# Epoch 5/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8032 - sparse_categorical_accuracy: 0.6255
# Epoch 6/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.7999 - sparse_categorical_accuracy: 0.6233
# Epoch 7/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8029 - sparse_categorical_accuracy: 0.6223
# Epoch 8/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.7972 - sparse_categorical_accuracy: 0.6208
# Epoch 9/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8016 - sparse_categorical_accuracy: 0.6273
# Epoch 10/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8009 - sparse_categorical_accuracy: 0.6255
# Epoch 11/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8024 - sparse_categorical_accuracy: 0.6220
# Epoch 12/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8017 - sparse_categorical_accuracy: 0.6202
# Epoch 13/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8002 - sparse_categorical_accuracy: 0.6260A: 0s - loss: 0.7984 - sparse_categorical_accuracy: 0.62
# Epoch 14/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8013 - sparse_categorical_accuracy: 0.6177
# Epoch 15/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8018 - sparse_categorical_accuracy: 0.6168
# Epoch 16/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.7991 - sparse_categorical_accuracy: 0.6273
# Epoch 17/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.7968 - sparse_categorical_accuracy: 0.6265
# Epoch 18/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.7980 - sparse_categorical_accuracy: 0.6235
# Epoch 19/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.7967 - sparse_categorical_accuracy: 0.6315
# Epoch 20/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8003 - sparse_categorical_accuracy: 0.6298
# >acc=0.5578,>f1=0.5219,>rec=0.5128,>roc=0.6350
# [[138  96   4]
#  [ 60 185  39]
#  [ 14  74  39]]
# Epoch 1/20
# 127/127 [==============================] - 1s 2ms/step - loss: 0.9938 - sparse_categorical_accuracy: 0.5240
# Epoch 2/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8561 - sparse_categorical_accuracy: 0.5893
# Epoch 3/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8227 - sparse_categorical_accuracy: 0.6051
# Epoch 4/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8126 - sparse_categorical_accuracy: 0.6131
# Epoch 5/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8137 - sparse_categorical_accuracy: 0.6131
# Epoch 6/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8099 - sparse_categorical_accuracy: 0.6138
# Epoch 7/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8121 - sparse_categorical_accuracy: 0.6126
# Epoch 8/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8103 - sparse_categorical_accuracy: 0.6143
# Epoch 9/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8112 - sparse_categorical_accuracy: 0.6098
# Epoch 10/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8056 - sparse_categorical_accuracy: 0.6185
# Epoch 11/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8122 - sparse_categorical_accuracy: 0.6138
# Epoch 12/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8118 - sparse_categorical_accuracy: 0.6123
# Epoch 13/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8086 - sparse_categorical_accuracy: 0.6200
# Epoch 14/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8075 - sparse_categorical_accuracy: 0.6190
# Epoch 15/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8086 - sparse_categorical_accuracy: 0.6183
# Epoch 16/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8075 - sparse_categorical_accuracy: 0.6141
# Epoch 17/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8095 - sparse_categorical_accuracy: 0.6145
# Epoch 18/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8085 - sparse_categorical_accuracy: 0.6202
# Epoch 19/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8039 - sparse_categorical_accuracy: 0.6200
# Epoch 20/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8049 - sparse_categorical_accuracy: 0.6143
# >acc=0.5932,>f1=0.5583,>rec=0.5522,>roc=0.6662
# [[161  69   8]
#  [ 62 180  42]
#  [ 12  71  44]]

# %%
print("Accuracy: %.4f (%.4f)" % (np.mean(kf_accuracy), np.std(kf_accuracy)))
print("F1-score: %.4f (%.4f)" % (np.mean(kf_f1), np.std(kf_f1)))
print("Recall: %.4f (%.4f)" % (np.mean(kf_recall), np.std(kf_recall)))
print("ROC: %.4f (%.4f)" % (np.mean(kf_roc), np.std(kf_roc)))
# Out:
# Accuracy: 0.5750 (0.0175)
# F1-score: 0.5456 (0.0203)
# Recall: 0.5348 (0.0196)
# ROC: 0.6506 (0.0147)

# %%
kf_accuracy
# Out:
# [0.5584615384615385,
#  0.5815384615384616,
#  0.5876923076923077,
#  0.5815384615384616,
#  0.5753846153846154,
#  0.5907692307692308,
#  0.5876923076923077,
#  0.5362095531587057,
#  0.5577812018489985,
#  0.5932203389830508]

# %%
conf_mat_mean = np.mean(kf_conf_mat,axis=0)

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
plot_confusion_matrix(conf_mat_mean,["0-Bad","1-Medium","2-Good"])
plt.savefig('MLP_PCA_ENN.png', transparent=True, dpi=300, bbox_inches="tight")
# Out:
# Confusion matrix, without normalization
# [[150.1  84.9   3.4]
#  [ 70.5 180.1  33. ]
#  [  8.4  75.9  43.4]]
