# %%
import pandas as pd
import numpy as np
from keras.utils import np_utils
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import roc_auc_score,confusion_matrix, accuracy_score, make_scorer, f1_score,precision_score,recall_score, plot_confusion_matrix
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
from sklearn.decomposition import PCA
from imblearn.under_sampling import EditedNearestNeighbours
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
def print_distribution(arr, print_nl=True):
    arr = np.unique(arr, return_counts=True)[1] / len(arr)
    for i in range(arr.shape[0]):
        print("Classe %d: %.2f%%" %(i, arr[i]*100))

    if print_nl:
        print("\n")

# %%
def taste(quality):
  if quality <= 5:
    return 0
  elif quality == 6:
    return 1
  else:
    return 2

# %%
data = pd.read_csv("wine_quality.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed.acidity         6497 non-null   float64
#  1   volatile.acidity      6497 non-null   float64
#  2   citric.acid           6497 non-null   float64
#  3   residual.sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free.sulfur.dioxide   6497 non-null   float64
#  6   total.sulfur.dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 609.2 KB

# %%
new_data = data
new_data["taste"] = data["quality"].apply(taste)

# %%
new_data
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  taste
# 0         9.4        5      0
# 1         9.8        5      0
# 2         9.8        5      0
# 3         9.8        6      1
# 4         9.4        5      0
# ...       ...      ...    ...
# 6492     11.2        6      1
# 6493      9.6        5      0
# 6494      9.4        6      1
# 6495     12.8        7      2
# 6496     11.8        6      1
#
# [6497 rows x 13 columns]

# %% [markdown]
# ## Divisão de base de dados e separação de base

# %%
X = new_data.iloc[:, 0:11].values
y = new_data.iloc[:, 12].values

# %%
scaler = MinMaxScaler()
scaler.fit(X)
print(scaler.data_max_)
X_normalized = scaler.transform(X)
print(X_normalized)
# Out:
# [ 15.9       1.58      1.66     65.8       0.611   289.      440.
#    1.03898   4.01      2.       14.9    ]
# [[0.29752066 0.41333333 0.         ... 0.6124031  0.19101124 0.20289855]
#  [0.33057851 0.53333333 0.         ... 0.37209302 0.25842697 0.26086957]
#  [0.33057851 0.45333333 0.02409639 ... 0.41860465 0.24157303 0.26086957]
#  ...
#  [0.2231405  0.10666667 0.11445783 ... 0.20930233 0.13483146 0.20289855]
#  [0.14049587 0.14       0.18072289 ... 0.48062016 0.08988764 0.69565217]
#  [0.18181818 0.08666667 0.22891566 ... 0.41860465 0.05617978 0.55072464]]

# %%
print("Proporções por classe no dataset em geral:")
print_distribution(y)

kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=199)
fold = 0
for train, test in kf.split(X_normalized, y):
    print("Fold %d" %(fold))
    print_distribution(y[train], print_nl=(fold != 2))
    fold += 1
# Out:
# Proporções por classe no dataset em geral:
# Classe 0: 36.69%
# Classe 1: 43.65%
# Classe 2: 19.66%
#
#
# Fold 0
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 1
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 2
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
# Fold 3
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 4
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 5
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 6
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 7
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 8
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 9
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%

# %%
kf_accuracy = list()
kf_conf_mat = list()
kf_precision = list()
kf_f1 = list()
kf_recall = list()
kf_roc = list()

# %%
# pca = PCA(n_components=5)
# fit = pca.fit(X_normalized)
# # summarize components
# print("Explained Variance: %s" % fit.explained_variance_ratio_)
# print(fit.components_)

# %%
pca = PCA(n_components=5)
enn = EditedNearestNeighbours()

# %% [markdown]
# ## Laço para execução do gridsearch em cada fold

# %%
for train_ix, test_ix in kf.split(X_normalized,y):
    X_train, X_test = X_normalized[train_ix, :], X_normalized[test_ix, :]
    y_train, y_test = y[train_ix], y[test_ix]
    X_train_res, y_train_res = enn.fit_resample(X_train, y_train)
    #X_test_res, y_test_res = enn.fit_resample(X_test, y_test)
    X_train_pca = pca.fit_transform(X_train_res)
    X_test_pca = pca.transform(X_test)  
    model = Sequential()
    model.add(Dense(units=16, activation="linear",input_dim=5))
    model.add(Dropout(0.1))
    model.add(Dense(units=16, activation="linear"))
    model.add(Dropout(0.1))
    model.add(Dense(units=3, activation="softmax"))
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"])
    # executar e salvar melhores parâmetros do grisearch
    result = model.fit(X_train_pca, y_train_res, batch_size=32, epochs=20)
    #best_model = result.best_estimator_
    # teste dos melhores parâmetros
    predicted_y = model.predict(X_test_pca)
    #y_test_transform = [np.argmax(t) for t in y_test]
    predicted_y_transform = [np.argmax(t) for t in predicted_y]
    #transformação de itens para cálculo do ROC
    le = LabelEncoder()
    y_test_dummy = le.fit_transform(y_test)
    predicted_y_dummy = le.fit_transform(predicted_y_transform)
    y_test_dummy = np_utils.to_categorical(y_test)
    predicted_y_dummy = np_utils.to_categorical(predicted_y_dummy)
    # métricas do modelo
    acc = accuracy_score(y_test, predicted_y_transform)
    conf_mat = confusion_matrix(y_test, predicted_y_transform)
    f1 = f1_score(y_test, predicted_y_transform, average = "macro")
    recall = recall_score(y_test, predicted_y_transform, average = "macro")
    roc = roc_auc_score(y_test_dummy,predicted_y_dummy,multi_class="ovo",average = "macro")
    #armazenamento de métricas
    kf_accuracy.append(acc)
    kf_conf_mat.append(conf_mat)
    kf_f1.append(f1)
    kf_recall.append(recall)
    kf_roc.append(roc)
    #métricas
    print(">acc=%.4f,>f1=%.4f,>rec=%.4f,>roc=%.4f" % (acc,f1,recall,roc))
    print(conf_mat)
# Out:
# Epoch 1/20
# 82/82 [==============================] - 1s 3ms/step - loss: 0.9941 - sparse_categorical_accuracy: 0.5434
# Epoch 2/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.8565 - sparse_categorical_accuracy: 0.6167
# Epoch 3/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7995 - sparse_categorical_accuracy: 0.6378
# Epoch 4/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7862 - sparse_categorical_accuracy: 0.6404
# Epoch 5/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7871 - sparse_categorical_accuracy: 0.6454
# Epoch 6/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7772 - sparse_categorical_accuracy: 0.6485
# Epoch 7/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7760 - sparse_categorical_accuracy: 0.6511
# Epoch 8/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7812 - sparse_categorical_accuracy: 0.6477
# Epoch 9/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7754 - sparse_categorical_accuracy: 0.6423
# Epoch 10/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7753 - sparse_categorical_accuracy: 0.6507
# Epoch 11/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7770 - sparse_categorical_accuracy: 0.6469
# Epoch 12/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7762 - sparse_categorical_accuracy: 0.6465
# Epoch 13/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7759 - sparse_categorical_accuracy: 0.6473
# Epoch 14/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7769 - sparse_categorical_accuracy: 0.6465
# Epoch 15/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7731 - sparse_categorical_accuracy: 0.6488
# Epoch 16/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7750 - sparse_categorical_accuracy: 0.6462
# Epoch 17/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7713 - sparse_categorical_accuracy: 0.6469
# Epoch 18/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7771 - sparse_categorical_accuracy: 0.6408
# Epoch 19/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7758 - sparse_categorical_accuracy: 0.6446
# Epoch 20/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7760 - sparse_categorical_accuracy: 0.6485
# >acc=0.4600,>f1=0.4423,>rec=0.5438,>roc=0.6459
# [[147  39  53]
#  [ 81  40 162]
#  [  9   7 112]]
# Epoch 1/20
# 83/83 [==============================] - 1s 3ms/step - loss: 0.9853 - sparse_categorical_accuracy: 0.5798
# Epoch 2/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.8553 - sparse_categorical_accuracy: 0.6359
# Epoch 3/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7956 - sparse_categorical_accuracy: 0.6457
# Epoch 4/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7854 - sparse_categorical_accuracy: 0.6517
# Epoch 5/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7765 - sparse_categorical_accuracy: 0.6517
# Epoch 6/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7737 - sparse_categorical_accuracy: 0.6525
# Epoch 7/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7716 - sparse_categorical_accuracy: 0.6540
# Epoch 8/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7734 - sparse_categorical_accuracy: 0.6544
# Epoch 9/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7796 - sparse_categorical_accuracy: 0.6585
# Epoch 10/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7721 - sparse_categorical_accuracy: 0.6532
# Epoch 11/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7750 - sparse_categorical_accuracy: 0.6487
# Epoch 12/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7729 - sparse_categorical_accuracy: 0.6521
# Epoch 13/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7741 - sparse_categorical_accuracy: 0.6611
# Epoch 14/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7763 - sparse_categorical_accuracy: 0.6555
# Epoch 15/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7725 - sparse_categorical_accuracy: 0.6551
# Epoch 16/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7738 - sparse_categorical_accuracy: 0.6585
# Epoch 17/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7719 - sparse_categorical_accuracy: 0.6506
# Epoch 18/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7730 - sparse_categorical_accuracy: 0.6578
# Epoch 19/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7751 - sparse_categorical_accuracy: 0.6551
# Epoch 20/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7666 - sparse_categorical_accuracy: 0.6547
# >acc=0.4369,>f1=0.4173,>rec=0.5169,>roc=0.6273
# [[144  37  58]
#  [ 81  34 168]
#  [ 13   9 106]]
# Epoch 1/20
# 82/82 [==============================] - 1s 4ms/step - loss: 0.9749 - sparse_categorical_accuracy: 0.5645
# Epoch 2/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.8529 - sparse_categorical_accuracy: 0.6381
# Epoch 3/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.8002 - sparse_categorical_accuracy: 0.6453
# Epoch 4/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7813 - sparse_categorical_accuracy: 0.6541
# Epoch 5/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7772 - sparse_categorical_accuracy: 0.6571
# Epoch 6/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7716 - sparse_categorical_accuracy: 0.6598
# Epoch 7/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7743 - sparse_categorical_accuracy: 0.6594
# Epoch 8/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7741 - sparse_categorical_accuracy: 0.6545
# Epoch 9/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7767 - sparse_categorical_accuracy: 0.6606
# Epoch 10/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7780 - sparse_categorical_accuracy: 0.6571
# Epoch 11/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7746 - sparse_categorical_accuracy: 0.6556
# Epoch 12/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7686 - sparse_categorical_accuracy: 0.6564A: 0s - loss: 0.7535 - sparse_categorical_accuracy: 0.66
# Epoch 13/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7732 - sparse_categorical_accuracy: 0.6590
# Epoch 14/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7757 - sparse_categorical_accuracy: 0.6522
# Epoch 15/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7719 - sparse_categorical_accuracy: 0.6499
# Epoch 16/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7743 - sparse_categorical_accuracy: 0.6579
# Epoch 17/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7731 - sparse_categorical_accuracy: 0.6526
# Epoch 18/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7689 - sparse_categorical_accuracy: 0.6503
# Epoch 19/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7708 - sparse_categorical_accuracy: 0.6568
# Epoch 20/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7749 - sparse_categorical_accuracy: 0.6598
# >acc=0.4769,>f1=0.4473,>rec=0.5568,>roc=0.6567
# [[167  26  46]
#  [ 91  34 158]
#  [ 16   3 109]]
# Epoch 1/20
# 83/83 [==============================] - 1s 3ms/step - loss: 1.0143 - sparse_categorical_accuracy: 0.5344
# Epoch 2/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.8926 - sparse_categorical_accuracy: 0.6269
# Epoch 3/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.8115 - sparse_categorical_accuracy: 0.6451
# Epoch 4/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7877 - sparse_categorical_accuracy: 0.6470
# Epoch 5/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7806 - sparse_categorical_accuracy: 0.6455
# Epoch 6/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7772 - sparse_categorical_accuracy: 0.6504
# Epoch 7/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7747 - sparse_categorical_accuracy: 0.6497
# Epoch 8/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7810 - sparse_categorical_accuracy: 0.6474
# Epoch 9/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7777 - sparse_categorical_accuracy: 0.6482
# Epoch 10/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7797 - sparse_categorical_accuracy: 0.6466
# Epoch 11/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7780 - sparse_categorical_accuracy: 0.6504
# Epoch 12/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7805 - sparse_categorical_accuracy: 0.6463
# Epoch 13/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7784 - sparse_categorical_accuracy: 0.6466
# Epoch 14/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7808 - sparse_categorical_accuracy: 0.6413
# Epoch 15/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7763 - sparse_categorical_accuracy: 0.6523
# Epoch 16/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7759 - sparse_categorical_accuracy: 0.6489
# Epoch 17/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7762 - sparse_categorical_accuracy: 0.6554
# Epoch 18/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7715 - sparse_categorical_accuracy: 0.6489
# Epoch 19/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7793 - sparse_categorical_accuracy: 0.6444
# Epoch 20/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7787 - sparse_categorical_accuracy: 0.6474
# >acc=0.5000,>f1=0.4851,>rec=0.5742,>roc=0.6706
# [[159  32  48]
#  [ 76  56 151]
#  [ 11   7 110]]
# Epoch 1/20
# 82/82 [==============================] - 1s 3ms/step - loss: 1.0037 - sparse_categorical_accuracy: 0.5509
# Epoch 2/20
# 82/82 [==============================] - 0s 4ms/step - loss: 0.8456 - sparse_categorical_accuracy: 0.6457
# Epoch 3/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7838 - sparse_categorical_accuracy: 0.6476
# Epoch 4/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7729 - sparse_categorical_accuracy: 0.6527
# Epoch 5/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7654 - sparse_categorical_accuracy: 0.6573
# Epoch 6/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7654 - sparse_categorical_accuracy: 0.6577
# Epoch 7/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7658 - sparse_categorical_accuracy: 0.6523
# Epoch 8/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7641 - sparse_categorical_accuracy: 0.6600
# Epoch 9/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7714 - sparse_categorical_accuracy: 0.6588
# Epoch 10/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7641 - sparse_categorical_accuracy: 0.6550
# Epoch 11/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7642 - sparse_categorical_accuracy: 0.6546
# Epoch 12/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7657 - sparse_categorical_accuracy: 0.6565
# Epoch 13/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7610 - sparse_categorical_accuracy: 0.6550
# Epoch 14/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7654 - sparse_categorical_accuracy: 0.6588
# Epoch 15/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7658 - sparse_categorical_accuracy: 0.6600
# Epoch 16/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7673 - sparse_categorical_accuracy: 0.6550
# Epoch 17/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7650 - sparse_categorical_accuracy: 0.6538
# Epoch 18/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7596 - sparse_categorical_accuracy: 0.6561
# Epoch 19/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7610 - sparse_categorical_accuracy: 0.6588
# Epoch 20/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7639 - sparse_categorical_accuracy: 0.6592
# >acc=0.4754,>f1=0.4499,>rec=0.5580,>roc=0.6568
# [[161  27  50]
#  [ 93  37 154]
#  [ 12   5 111]]
# Epoch 1/20
# 84/84 [==============================] - 1s 4ms/step - loss: 1.0151 - sparse_categorical_accuracy: 0.5730
# Epoch 2/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.8875 - sparse_categorical_accuracy: 0.6395
# Epoch 3/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.8077 - sparse_categorical_accuracy: 0.6504
# Epoch 4/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7833 - sparse_categorical_accuracy: 0.6519
# Epoch 5/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7775 - sparse_categorical_accuracy: 0.6538
# Epoch 6/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7771 - sparse_categorical_accuracy: 0.6459
# Epoch 7/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7741 - sparse_categorical_accuracy: 0.6519
# Epoch 8/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7749 - sparse_categorical_accuracy: 0.6549
# Epoch 9/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7769 - sparse_categorical_accuracy: 0.6504
# Epoch 10/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7738 - sparse_categorical_accuracy: 0.6459
# Epoch 11/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7775 - sparse_categorical_accuracy: 0.6538
# Epoch 12/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7784 - sparse_categorical_accuracy: 0.6515
# Epoch 13/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7731 - sparse_categorical_accuracy: 0.6549
# Epoch 14/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7758 - sparse_categorical_accuracy: 0.6511
# Epoch 15/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7765 - sparse_categorical_accuracy: 0.6485
# Epoch 16/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7768 - sparse_categorical_accuracy: 0.6538
# Epoch 17/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7747 - sparse_categorical_accuracy: 0.6519
# Epoch 18/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7737 - sparse_categorical_accuracy: 0.6545
# Epoch 19/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7695 - sparse_categorical_accuracy: 0.6553
# Epoch 20/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7718 - sparse_categorical_accuracy: 0.6511
# >acc=0.4862,>f1=0.4613,>rec=0.5695,>roc=0.6652
# [[163  24  51]
#  [ 95  40 149]
#  [  9   6 113]]
# Epoch 1/20
# 83/83 [==============================] - 1s 3ms/step - loss: 1.0272 - sparse_categorical_accuracy: 0.5046
# Epoch 2/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.9112 - sparse_categorical_accuracy: 0.6166
# Epoch 3/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.8158 - sparse_categorical_accuracy: 0.6420
# Epoch 4/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7817 - sparse_categorical_accuracy: 0.6420
# Epoch 5/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7740 - sparse_categorical_accuracy: 0.6458
# Epoch 6/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7682 - sparse_categorical_accuracy: 0.6458
# Epoch 7/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7702 - sparse_categorical_accuracy: 0.6469
# Epoch 8/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7663 - sparse_categorical_accuracy: 0.6450
# Epoch 9/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7706 - sparse_categorical_accuracy: 0.6431
# Epoch 10/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7706 - sparse_categorical_accuracy: 0.6386
# Epoch 11/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7687 - sparse_categorical_accuracy: 0.6446
# Epoch 12/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7665 - sparse_categorical_accuracy: 0.6458
# Epoch 13/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7701 - sparse_categorical_accuracy: 0.6492
# Epoch 14/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7653 - sparse_categorical_accuracy: 0.6473
# Epoch 15/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7656 - sparse_categorical_accuracy: 0.6435
# Epoch 16/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7688 - sparse_categorical_accuracy: 0.6496
# Epoch 17/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7706 - sparse_categorical_accuracy: 0.6465
# Epoch 18/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7677 - sparse_categorical_accuracy: 0.6507
# Epoch 19/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7663 - sparse_categorical_accuracy: 0.6515
# Epoch 20/20
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7651 - sparse_categorical_accuracy: 0.6488
# >acc=0.4831,>f1=0.4686,>rec=0.5553,>roc=0.6566
# [[155  38  45]
#  [ 76  53 155]
#  [ 16   6 106]]
# Epoch 1/20
# 84/84 [==============================] - 1s 3ms/step - loss: 1.0354 - sparse_categorical_accuracy: 0.4716
# Epoch 2/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.8886 - sparse_categorical_accuracy: 0.6357
# Epoch 3/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.8065 - sparse_categorical_accuracy: 0.6526
# Epoch 4/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7845 - sparse_categorical_accuracy: 0.6481
# Epoch 5/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7767 - sparse_categorical_accuracy: 0.6549
# Epoch 6/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7707 - sparse_categorical_accuracy: 0.6541
# Epoch 7/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7682 - sparse_categorical_accuracy: 0.6500
# Epoch 8/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7695 - sparse_categorical_accuracy: 0.6557
# Epoch 9/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7672 - sparse_categorical_accuracy: 0.6575
# Epoch 10/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7740 - sparse_categorical_accuracy: 0.6632
# Epoch 11/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7702 - sparse_categorical_accuracy: 0.6489
# Epoch 12/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7679 - sparse_categorical_accuracy: 0.6526
# Epoch 13/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7685 - sparse_categorical_accuracy: 0.6538
# Epoch 14/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7690 - sparse_categorical_accuracy: 0.6553
# Epoch 15/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7707 - sparse_categorical_accuracy: 0.6530
# Epoch 16/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7706 - sparse_categorical_accuracy: 0.6553
# Epoch 17/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7673 - sparse_categorical_accuracy: 0.6545
# Epoch 18/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7711 - sparse_categorical_accuracy: 0.6560
# Epoch 19/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7708 - sparse_categorical_accuracy: 0.6519
# Epoch 20/20
# 84/84 [==============================] - 0s 3ms/step - loss: 0.7688 - sparse_categorical_accuracy: 0.6579
# >acc=0.4330,>f1=0.4196,>rec=0.5119,>roc=0.6225
# [[131  37  70]
#  [100  45 139]
#  [ 15   7 105]]
# Epoch 1/20
# 82/82 [==============================] - 1s 3ms/step - loss: 0.9880 - sparse_categorical_accuracy: 0.5780
# Epoch 2/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.8563 - sparse_categorical_accuracy: 0.6465
# Epoch 3/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7862 - sparse_categorical_accuracy: 0.6592
# Epoch 4/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7660 - sparse_categorical_accuracy: 0.6623
# Epoch 5/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7576 - sparse_categorical_accuracy: 0.6585
# Epoch 6/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7492 - sparse_categorical_accuracy: 0.6662
# Epoch 7/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7522 - sparse_categorical_accuracy: 0.6627
# Epoch 8/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7481 - sparse_categorical_accuracy: 0.6638
# Epoch 9/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7471 - sparse_categorical_accuracy: 0.6585
# Epoch 10/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7539 - sparse_categorical_accuracy: 0.6569
# Epoch 11/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7476 - sparse_categorical_accuracy: 0.6615
# Epoch 12/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7513 - sparse_categorical_accuracy: 0.6600
# Epoch 13/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7432 - sparse_categorical_accuracy: 0.6638
# Epoch 14/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7479 - sparse_categorical_accuracy: 0.6615
# Epoch 15/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7469 - sparse_categorical_accuracy: 0.6615
# Epoch 16/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7517 - sparse_categorical_accuracy: 0.6608
# Epoch 17/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7527 - sparse_categorical_accuracy: 0.6627
# Epoch 18/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7465 - sparse_categorical_accuracy: 0.6627
# Epoch 19/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7475 - sparse_categorical_accuracy: 0.6585
# Epoch 20/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7497 - sparse_categorical_accuracy: 0.6596
# >acc=0.4561,>f1=0.4396,>rec=0.5312,>roc=0.6393
# [[145  31  62]
#  [ 84  47 153]
#  [ 21   2 104]]
# Epoch 1/20
# 82/82 [==============================] - 1s 4ms/step - loss: 1.0050 - sparse_categorical_accuracy: 0.5716
# Epoch 2/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.8610 - sparse_categorical_accuracy: 0.6397
# Epoch 3/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7953 - sparse_categorical_accuracy: 0.6501
# Epoch 4/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7763 - sparse_categorical_accuracy: 0.6532
# Epoch 5/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7756 - sparse_categorical_accuracy: 0.6520
# Epoch 6/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7737 - sparse_categorical_accuracy: 0.6513
# Epoch 7/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7689 - sparse_categorical_accuracy: 0.6563
# Epoch 8/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7697 - sparse_categorical_accuracy: 0.6620
# Epoch 9/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7731 - sparse_categorical_accuracy: 0.6620
# Epoch 10/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7687 - sparse_categorical_accuracy: 0.6597
# Epoch 11/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7721 - sparse_categorical_accuracy: 0.6536
# Epoch 12/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7723 - sparse_categorical_accuracy: 0.6559
# Epoch 13/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7700 - sparse_categorical_accuracy: 0.6574
# Epoch 14/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7704 - sparse_categorical_accuracy: 0.6547
# Epoch 15/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7710 - sparse_categorical_accuracy: 0.6597
# Epoch 16/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7722 - sparse_categorical_accuracy: 0.6547
# Epoch 17/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7721 - sparse_categorical_accuracy: 0.6482
# Epoch 18/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7739 - sparse_categorical_accuracy: 0.6543
# Epoch 19/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7703 - sparse_categorical_accuracy: 0.6570
# Epoch 20/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.7701 - sparse_categorical_accuracy: 0.6563
# >acc=0.4684,>f1=0.4438,>rec=0.5481,>roc=0.6525
# [[159  18  61]
#  [ 80  38 166]
#  [ 14   6 107]]

# %%
print("Accuracy: %.4f (%.4f)" % (np.mean(kf_accuracy), np.std(kf_accuracy)))
print("F1-score: %.4f (%.4f)" % (np.mean(kf_f1), np.std(kf_f1)))
print("Recall: %.4f (%.4f)" % (np.mean(kf_recall), np.std(kf_recall)))
print("ROC: %.4f (%.4f)" % (np.mean(kf_roc), np.std(kf_roc)))
# Out:
# Accuracy: 0.4676 (0.0203)
# F1-score: 0.4475 (0.0196)
# Recall: 0.5466 (0.0198)
# ROC: 0.6493 (0.0148)

# %%
conf_mat_mean = np.mean(kf_conf_mat,axis=0)

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
plot_confusion_matrix(conf_mat_mean,["0-Bad","1-Medium","2-Good"])
plt.savefig('MLP_ENN_PCA.png', transparent=True, dpi=300, bbox_inches="tight")
# Out:
# Confusion matrix, without normalization
# [[153.1  30.9  54.4]
#  [ 85.7  42.4 155.5]
#  [ 13.6   5.8 108.3]]
