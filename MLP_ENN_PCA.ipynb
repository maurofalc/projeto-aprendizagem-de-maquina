# %%
import pandas as pd
import numpy as np
from keras.utils import np_utils
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import roc_auc_score,confusion_matrix, accuracy_score, make_scorer, f1_score,precision_score,recall_score, plot_confusion_matrix
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
from sklearn.decomposition import PCA
from imblearn.under_sampling import EditedNearestNeighbours
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
def print_distribution(arr, print_nl=True):
    arr = np.unique(arr, return_counts=True)[1] / len(arr)
    for i in range(arr.shape[0]):
        print("Classe %d: %.2f%%" %(i, arr[i]*100))

    if print_nl:
        print("\n")

# %%
def taste(quality):
  if quality <= 5:
    return 0
  elif quality == 6:
    return 1
  else:
    return 2

# %%
data = pd.read_csv("wine_quality.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed.acidity         6497 non-null   float64
#  1   volatile.acidity      6497 non-null   float64
#  2   citric.acid           6497 non-null   float64
#  3   residual.sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free.sulfur.dioxide   6497 non-null   float64
#  6   total.sulfur.dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 609.2 KB

# %%
new_data = data
new_data["taste"] = data["quality"].apply(taste)

# %%
new_data
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  taste
# 0         9.4        5      0
# 1         9.8        5      0
# 2         9.8        5      0
# 3         9.8        6      1
# 4         9.4        5      0
# ...       ...      ...    ...
# 6492     11.2        6      1
# 6493      9.6        5      0
# 6494      9.4        6      1
# 6495     12.8        7      2
# 6496     11.8        6      1
#
# [6497 rows x 13 columns]

# %% [markdown]
# ## Divisão de base de dados e separação de base

# %%
X = new_data.iloc[:, 0:11].values
y = new_data.iloc[:, 12].values

# %%
scaler = MinMaxScaler()
scaler.fit(X)
print(scaler.data_max_)
X_normalized = scaler.transform(X)
print(X_normalized)
# Out:
# [ 15.9       1.58      1.66     65.8       0.611   289.      440.
#    1.03898   4.01      2.       14.9    ]
# [[0.29752066 0.41333333 0.         ... 0.6124031  0.19101124 0.20289855]
#  [0.33057851 0.53333333 0.         ... 0.37209302 0.25842697 0.26086957]
#  [0.33057851 0.45333333 0.02409639 ... 0.41860465 0.24157303 0.26086957]
#  ...
#  [0.2231405  0.10666667 0.11445783 ... 0.20930233 0.13483146 0.20289855]
#  [0.14049587 0.14       0.18072289 ... 0.48062016 0.08988764 0.69565217]
#  [0.18181818 0.08666667 0.22891566 ... 0.41860465 0.05617978 0.55072464]]

# %%
print("Proporções por classe no dataset em geral:")
print_distribution(y)

kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=199)
fold = 0
for train, test in kf.split(X_normalized, y):
    print("Fold %d" %(fold))
    print_distribution(y[train], print_nl=(fold != 2))
    fold += 1
# Out:
# Proporções por classe no dataset em geral:
# Classe 0: 36.69%
# Classe 1: 43.65%
# Classe 2: 19.66%
#
#
# Fold 0
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 1
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 2
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
# Fold 3
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 4
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 5
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 6
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 7
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 8
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 9
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%

# %%
kf_accuracy = list()
kf_conf_mat = list()
kf_precision = list()
kf_f1 = list()
kf_recall = list()
kf_roc = list()

# %%
pca = PCA(n_components=5)
enn = EditedNearestNeighbours(sampling_strategy='all', n_neighbors=1, kind_sel='all', n_jobs=-1)

# %% [markdown]
# ## Laço para execução do gridsearch em cada fold

# %%
for train_ix, test_ix in kf.split(X_normalized,y):
    X_train, X_test = X_normalized[train_ix, :], X_normalized[test_ix, :]
    y_train, y_test = y[train_ix], y[test_ix]
    X_train_res, y_train_res = enn.fit_resample(X_train, y_train)
    X_train_pca = pca.fit_transform(X_train_res)
    X_test_pca = pca.transform(X_test)  
    model = Sequential()
    model.add(Dense(units=16, activation="linear",input_dim=5))
    model.add(Dropout(0.1))
    model.add(Dense(units=16, activation="linear"))
    model.add(Dropout(0.1))
    model.add(Dense(units=3, activation="softmax"))
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"])
    # executar treinamento do modelo
    result = model.fit(X_train_pca, y_train_res, batch_size=32, epochs=20)
    # teste dos melhores parâmetros
    predicted_y = model.predict(X_test_pca)
    predicted_y_transform = [np.argmax(t) for t in predicted_y]
    #transformação de itens para cálculo do ROC
    le = LabelEncoder()
    y_test_dummy = le.fit_transform(y_test)
    predicted_y_dummy = le.fit_transform(predicted_y_transform)
    y_test_dummy = np_utils.to_categorical(y_test)
    predicted_y_dummy = np_utils.to_categorical(predicted_y_dummy)
    # métricas do modelo
    acc = accuracy_score(y_test, predicted_y_transform)
    conf_mat = confusion_matrix(y_test, predicted_y_transform)
    f1 = f1_score(y_test, predicted_y_transform, average = "macro")
    recall = recall_score(y_test, predicted_y_transform, average = "macro")
    roc = roc_auc_score(y_test_dummy,predicted_y_dummy,multi_class="ovo",average = "macro")
    #armazenamento de métricas
    kf_accuracy.append(acc)
    kf_conf_mat.append(conf_mat)
    kf_f1.append(f1)
    kf_recall.append(recall)
    kf_roc.append(roc)
    #métricas
    print(">acc=%.4f,>f1=%.4f,>rec=%.4f,>roc=%.4f" % (acc,f1,recall,roc))
    print(conf_mat)
# Out:
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 0.9764 - sparse_categorical_accuracy: 0.5434
# Epoch 2/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8753 - sparse_categorical_accuracy: 0.5763
# Epoch 3/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8566 - sparse_categorical_accuracy: 0.5793
# Epoch 4/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8525 - sparse_categorical_accuracy: 0.5908
# Epoch 5/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8525 - sparse_categorical_accuracy: 0.5863
# Epoch 6/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8505 - sparse_categorical_accuracy: 0.5933
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8476 - sparse_categorical_accuracy: 0.5898
# Epoch 8/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8521 - sparse_categorical_accuracy: 0.5933
# Epoch 9/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8488 - sparse_categorical_accuracy: 0.5955
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8517 - sparse_categorical_accuracy: 0.5938
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8517 - sparse_categorical_accuracy: 0.5875
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8519 - sparse_categorical_accuracy: 0.5885
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8494 - sparse_categorical_accuracy: 0.5953
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8475 - sparse_categorical_accuracy: 0.5928
# Epoch 15/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8519 - sparse_categorical_accuracy: 0.5925
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8515 - sparse_categorical_accuracy: 0.5918
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8505 - sparse_categorical_accuracy: 0.5935
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8492 - sparse_categorical_accuracy: 0.5915
# Epoch 19/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8524 - sparse_categorical_accuracy: 0.5940
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8486 - sparse_categorical_accuracy: 0.5910
# >acc=0.5431,>f1=0.5123,>rec=0.5044,>roc=0.6273
# [[152  86   1]
#  [ 81 162  40]
#  [ 10  79  39]]
# Epoch 1/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.9944 - sparse_categorical_accuracy: 0.5278
# Epoch 2/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8854 - sparse_categorical_accuracy: 0.5681
# Epoch 3/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8588 - sparse_categorical_accuracy: 0.5743
# Epoch 4/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8552 - sparse_categorical_accuracy: 0.5798
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8493 - sparse_categorical_accuracy: 0.5845
# Epoch 6/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8527 - sparse_categorical_accuracy: 0.5795
# Epoch 7/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8523 - sparse_categorical_accuracy: 0.5795
# Epoch 8/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8508 - sparse_categorical_accuracy: 0.5813
# Epoch 9/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8477 - sparse_categorical_accuracy: 0.5892
# Epoch 10/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8514 - sparse_categorical_accuracy: 0.5855
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8501 - sparse_categorical_accuracy: 0.5833
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8515 - sparse_categorical_accuracy: 0.5845
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8519 - sparse_categorical_accuracy: 0.5833
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8478 - sparse_categorical_accuracy: 0.5842
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8494 - sparse_categorical_accuracy: 0.5870
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8529 - sparse_categorical_accuracy: 0.5783
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8525 - sparse_categorical_accuracy: 0.5875
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8481 - sparse_categorical_accuracy: 0.5900
# Epoch 19/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8510 - sparse_categorical_accuracy: 0.5800
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8508 - sparse_categorical_accuracy: 0.5887
# >acc=0.5477,>f1=0.5196,>rec=0.5096,>roc=0.6309
# [[140  92   7]
#  [ 77 174  32]
#  [ 12  74  42]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 0.9840 - sparse_categorical_accuracy: 0.5401
# Epoch 2/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8760 - sparse_categorical_accuracy: 0.5807
# Epoch 3/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8555 - sparse_categorical_accuracy: 0.5826
# Epoch 4/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8550 - sparse_categorical_accuracy: 0.5851
# Epoch 5/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8501 - sparse_categorical_accuracy: 0.5933
# Epoch 6/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8504 - sparse_categorical_accuracy: 0.5864
# Epoch 7/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8481 - sparse_categorical_accuracy: 0.5866
# Epoch 8/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8493 - sparse_categorical_accuracy: 0.5881
# Epoch 9/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8492 - sparse_categorical_accuracy: 0.5933
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8509 - sparse_categorical_accuracy: 0.5916
# Epoch 11/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8463 - sparse_categorical_accuracy: 0.5923
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8488 - sparse_categorical_accuracy: 0.5876
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8507 - sparse_categorical_accuracy: 0.5869
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8488 - sparse_categorical_accuracy: 0.5881
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8473 - sparse_categorical_accuracy: 0.5976
# Epoch 16/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8473 - sparse_categorical_accuracy: 0.5931
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8481 - sparse_categorical_accuracy: 0.5928
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8443 - sparse_categorical_accuracy: 0.5936
# Epoch 19/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8465 - sparse_categorical_accuracy: 0.5963
# Epoch 20/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8480 - sparse_categorical_accuracy: 0.5978
# >acc=0.5631,>f1=0.5296,>rec=0.5212,>roc=0.6407
# [[159  79   1]
#  [ 85 168  30]
#  [ 15  74  39]]
# Epoch 1/20
# 127/127 [==============================] - 1s 2ms/step - loss: 0.9797 - sparse_categorical_accuracy: 0.5332
# Epoch 2/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8782 - sparse_categorical_accuracy: 0.5685
# Epoch 3/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8554 - sparse_categorical_accuracy: 0.5811
# Epoch 4/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8530 - sparse_categorical_accuracy: 0.5835
# Epoch 5/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8537 - sparse_categorical_accuracy: 0.5833
# Epoch 6/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8505 - sparse_categorical_accuracy: 0.5801
# Epoch 7/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8506 - sparse_categorical_accuracy: 0.5875
# Epoch 8/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8468 - sparse_categorical_accuracy: 0.5818
# Epoch 9/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8483 - sparse_categorical_accuracy: 0.5892
# Epoch 10/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8492 - sparse_categorical_accuracy: 0.5877
# Epoch 11/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8517 - sparse_categorical_accuracy: 0.5815
# Epoch 12/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8478 - sparse_categorical_accuracy: 0.5848
# Epoch 13/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8488 - sparse_categorical_accuracy: 0.5897
# Epoch 14/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8527 - sparse_categorical_accuracy: 0.5813
# Epoch 15/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8507 - sparse_categorical_accuracy: 0.5850
# Epoch 16/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8520 - sparse_categorical_accuracy: 0.5867
# Epoch 17/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8499 - sparse_categorical_accuracy: 0.5820
# Epoch 18/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8500 - sparse_categorical_accuracy: 0.5828
# Epoch 19/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8487 - sparse_categorical_accuracy: 0.5808A: 0s - loss: 0.8529 - sparse_categorical_accuracy: 0.575
# Epoch 20/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8503 - sparse_categorical_accuracy: 0.5894
# >acc=0.5708,>f1=0.5286,>rec=0.5179,>roc=0.6395
# [[143  95   1]
#  [ 63 193  27]
#  [  9  84  35]]
# Epoch 1/20
# 125/125 [==============================] - 1s 2ms/step - loss: 1.0058 - sparse_categorical_accuracy: 0.4662
# Epoch 2/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8869 - sparse_categorical_accuracy: 0.5700
# Epoch 3/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8605 - sparse_categorical_accuracy: 0.5810
# Epoch 4/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8562 - sparse_categorical_accuracy: 0.5778
# Epoch 5/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8516 - sparse_categorical_accuracy: 0.5868
# Epoch 6/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8518 - sparse_categorical_accuracy: 0.5928
# Epoch 7/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8511 - sparse_categorical_accuracy: 0.5920
# Epoch 8/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8522 - sparse_categorical_accuracy: 0.5875
# Epoch 9/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8522 - sparse_categorical_accuracy: 0.5860
# Epoch 10/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8526 - sparse_categorical_accuracy: 0.5878
# Epoch 11/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8504 - sparse_categorical_accuracy: 0.5895
# Epoch 12/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8518 - sparse_categorical_accuracy: 0.5890
# Epoch 13/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8500 - sparse_categorical_accuracy: 0.5920
# Epoch 14/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8482 - sparse_categorical_accuracy: 0.5903
# Epoch 15/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8493 - sparse_categorical_accuracy: 0.5928
# Epoch 16/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8490 - sparse_categorical_accuracy: 0.5863
# Epoch 17/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8512 - sparse_categorical_accuracy: 0.5920
# Epoch 18/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8504 - sparse_categorical_accuracy: 0.5908
# Epoch 19/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8484 - sparse_categorical_accuracy: 0.5950
# Epoch 20/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8495 - sparse_categorical_accuracy: 0.5955
# >acc=0.5338,>f1=0.4937,>rec=0.4871,>roc=0.6149
# [[150  88   0]
#  [ 87 165  32]
#  [ 11  85  32]]
# Epoch 1/20
# 126/126 [==============================] - 0s 2ms/step - loss: 1.0178 - sparse_categorical_accuracy: 0.5066
# Epoch 2/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8992 - sparse_categorical_accuracy: 0.5689
# Epoch 3/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8670 - sparse_categorical_accuracy: 0.5769
# Epoch 4/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8626 - sparse_categorical_accuracy: 0.5831
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8573 - sparse_categorical_accuracy: 0.5854
# Epoch 6/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8598 - sparse_categorical_accuracy: 0.5856
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8602 - sparse_categorical_accuracy: 0.5854
# Epoch 8/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8593 - sparse_categorical_accuracy: 0.5839
# Epoch 9/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8612 - sparse_categorical_accuracy: 0.5824
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8569 - sparse_categorical_accuracy: 0.5884
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8590 - sparse_categorical_accuracy: 0.5804
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8584 - sparse_categorical_accuracy: 0.5807
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8576 - sparse_categorical_accuracy: 0.5859
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8592 - sparse_categorical_accuracy: 0.5817
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8574 - sparse_categorical_accuracy: 0.5864
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8589 - sparse_categorical_accuracy: 0.5824
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8571 - sparse_categorical_accuracy: 0.5921
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8577 - sparse_categorical_accuracy: 0.5831A: 0s - loss: 0.8616 - sparse_categorical_accuracy: 0.58
# Epoch 19/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8601 - sparse_categorical_accuracy: 0.5846
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8573 - sparse_categorical_accuracy: 0.5876
# >acc=0.5738,>f1=0.5485,>rec=0.5330,>roc=0.6478
# [[155  82   1]
#  [ 92 176  16]
#  [  9  77  42]]
# Epoch 1/20
# 127/127 [==============================] - 1s 2ms/step - loss: 1.0278 - sparse_categorical_accuracy: 0.4745
# Epoch 2/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.9234 - sparse_categorical_accuracy: 0.5426
# Epoch 3/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8718 - sparse_categorical_accuracy: 0.5716
# Epoch 4/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8585 - sparse_categorical_accuracy: 0.5803
# Epoch 5/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8590 - sparse_categorical_accuracy: 0.5857
# Epoch 6/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8596 - sparse_categorical_accuracy: 0.5795
# Epoch 7/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8583 - sparse_categorical_accuracy: 0.5815
# Epoch 8/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8552 - sparse_categorical_accuracy: 0.5798
# Epoch 9/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8599 - sparse_categorical_accuracy: 0.5803
# Epoch 10/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8543 - sparse_categorical_accuracy: 0.5825
# Epoch 11/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8571 - sparse_categorical_accuracy: 0.5815
# Epoch 12/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8577 - sparse_categorical_accuracy: 0.5810
# Epoch 13/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8575 - sparse_categorical_accuracy: 0.5870
# Epoch 14/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8581 - sparse_categorical_accuracy: 0.5892
# Epoch 15/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8591 - sparse_categorical_accuracy: 0.5818
# Epoch 16/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8571 - sparse_categorical_accuracy: 0.5865
# Epoch 17/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8603 - sparse_categorical_accuracy: 0.5815
# Epoch 18/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8568 - sparse_categorical_accuracy: 0.5783
# Epoch 19/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8532 - sparse_categorical_accuracy: 0.5862
# Epoch 20/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8525 - sparse_categorical_accuracy: 0.5937
# >acc=0.5877,>f1=0.5567,>rec=0.5456,>roc=0.6590
# [[164  74   0]
#  [ 85 176  23]
#  [ 16  70  42]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 1.0353 - sparse_categorical_accuracy: 0.4117
# Epoch 2/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.9100 - sparse_categorical_accuracy: 0.5766
# Epoch 3/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8606 - sparse_categorical_accuracy: 0.5963
# Epoch 4/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8491 - sparse_categorical_accuracy: 0.5930
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8470 - sparse_categorical_accuracy: 0.5993
# Epoch 6/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8435 - sparse_categorical_accuracy: 0.5975
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8402 - sparse_categorical_accuracy: 0.6010
# Epoch 8/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8391 - sparse_categorical_accuracy: 0.6022
# Epoch 9/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8431 - sparse_categorical_accuracy: 0.5960
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8447 - sparse_categorical_accuracy: 0.5910
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8432 - sparse_categorical_accuracy: 0.6012
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8369 - sparse_categorical_accuracy: 0.6050
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8395 - sparse_categorical_accuracy: 0.6002
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8416 - sparse_categorical_accuracy: 0.5998
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8381 - sparse_categorical_accuracy: 0.6025
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8388 - sparse_categorical_accuracy: 0.6007
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8394 - sparse_categorical_accuracy: 0.6012
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8381 - sparse_categorical_accuracy: 0.6002
# Epoch 19/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8431 - sparse_categorical_accuracy: 0.6027
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8418 - sparse_categorical_accuracy: 0.6040
# >acc=0.5116,>f1=0.4994,>rec=0.4886,>roc=0.6107
# [[129 104   5]
#  [ 93 155  36]
#  [ 15  64  48]]
# Epoch 1/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.9806 - sparse_categorical_accuracy: 0.5329
# Epoch 2/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8753 - sparse_categorical_accuracy: 0.5861
# Epoch 3/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8515 - sparse_categorical_accuracy: 0.5894
# Epoch 4/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8474 - sparse_categorical_accuracy: 0.5936
# Epoch 5/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8466 - sparse_categorical_accuracy: 0.5924
# Epoch 6/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8499 - sparse_categorical_accuracy: 0.5901
# Epoch 7/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8496 - sparse_categorical_accuracy: 0.5981
# Epoch 8/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8475 - sparse_categorical_accuracy: 0.5979
# Epoch 9/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8483 - sparse_categorical_accuracy: 0.5954
# Epoch 10/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8462 - sparse_categorical_accuracy: 0.6024
# Epoch 11/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8447 - sparse_categorical_accuracy: 0.5999
# Epoch 12/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8508 - sparse_categorical_accuracy: 0.5926
# Epoch 13/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8469 - sparse_categorical_accuracy: 0.5971
# Epoch 14/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8448 - sparse_categorical_accuracy: 0.6017
# Epoch 15/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8511 - sparse_categorical_accuracy: 0.5941
# Epoch 16/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8470 - sparse_categorical_accuracy: 0.5976
# Epoch 17/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8480 - sparse_categorical_accuracy: 0.5951
# Epoch 18/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8480 - sparse_categorical_accuracy: 0.5984
# Epoch 19/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8493 - sparse_categorical_accuracy: 0.5989
# Epoch 20/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8474 - sparse_categorical_accuracy: 0.5966
# >acc=0.5331,>f1=0.4941,>rec=0.4870,>roc=0.6152
# [[139  94   5]
#  [ 79 173  32]
#  [ 19  74  34]]
# Epoch 1/20
# 127/127 [==============================] - 1s 2ms/step - loss: 1.0008 - sparse_categorical_accuracy: 0.4942
# Epoch 2/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8853 - sparse_categorical_accuracy: 0.5747
# Epoch 3/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8640 - sparse_categorical_accuracy: 0.5838
# Epoch 4/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8570 - sparse_categorical_accuracy: 0.5886
# Epoch 5/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8574 - sparse_categorical_accuracy: 0.5856
# Epoch 6/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8541 - sparse_categorical_accuracy: 0.5809
# Epoch 7/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8540 - sparse_categorical_accuracy: 0.5814
# Epoch 8/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8535 - sparse_categorical_accuracy: 0.5856
# Epoch 9/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8548 - sparse_categorical_accuracy: 0.5821
# Epoch 10/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8524 - sparse_categorical_accuracy: 0.5863
# Epoch 11/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8546 - sparse_categorical_accuracy: 0.5903
# Epoch 12/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8575 - sparse_categorical_accuracy: 0.5801
# Epoch 13/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8555 - sparse_categorical_accuracy: 0.5789
# Epoch 14/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8528 - sparse_categorical_accuracy: 0.5903
# Epoch 15/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8535 - sparse_categorical_accuracy: 0.5829
# Epoch 16/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8524 - sparse_categorical_accuracy: 0.5819
# Epoch 17/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8536 - sparse_categorical_accuracy: 0.5866
# Epoch 18/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8522 - sparse_categorical_accuracy: 0.5834
# Epoch 19/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8504 - sparse_categorical_accuracy: 0.5933
# Epoch 20/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8528 - sparse_categorical_accuracy: 0.5799
# >acc=0.5408,>f1=0.5087,>rec=0.5005,>roc=0.6247
# [[141  90   7]
#  [ 78 171  35]
#  [ 14  74  39]]

# %%
print("Accuracy: %.4f (%.4f)" % (np.mean(kf_accuracy), np.std(kf_accuracy)))
print("F1-score: %.4f (%.4f)" % (np.mean(kf_f1), np.std(kf_f1)))
print("Recall: %.4f (%.4f)" % (np.mean(kf_recall), np.std(kf_recall)))
print("ROC: %.4f (%.4f)" % (np.mean(kf_roc), np.std(kf_roc)))
# Out:
# Accuracy: 0.5506 (0.0218)
# F1-score: 0.5191 (0.0207)
# Recall: 0.5095 (0.0190)
# ROC: 0.6311 (0.0149)

# %%
conf_mat_mean = np.mean(kf_conf_mat,axis=0)

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
plot_confusion_matrix(conf_mat_mean,["0-Bad","1-Medium","2-Good"])
plt.savefig('MLP_ENN_PCA.png', transparent=True, dpi=300, bbox_inches="tight")
# Out:
# Confusion matrix, without normalization
# [[147.2  88.4   2.8]
#  [ 82.  171.3  30.3]
#  [ 13.   75.5  39.2]]
