# %%
import pandas as pd
import numpy as np
from keras.utils import np_utils
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import roc_auc_score,confusion_matrix, accuracy_score, make_scorer, f1_score,precision_score,recall_score, plot_confusion_matrix
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
from sklearn.decomposition import PCA
from imblearn.under_sampling import EditedNearestNeighbours
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
def print_distribution(arr, print_nl=True):
    arr = np.unique(arr, return_counts=True)[1] / len(arr)
    for i in range(arr.shape[0]):
        print("Classe %d: %.2f%%" %(i, arr[i]*100))

    if print_nl:
        print("\n")

# %%
def taste(quality):
  if quality <= 5:
    return 0
  elif quality == 6:
    return 1
  else:
    return 2

# %%
data = pd.read_csv("wine_quality.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed.acidity         6497 non-null   float64
#  1   volatile.acidity      6497 non-null   float64
#  2   citric.acid           6497 non-null   float64
#  3   residual.sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free.sulfur.dioxide   6497 non-null   float64
#  6   total.sulfur.dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 609.2 KB

# %%
new_data = data
new_data["taste"] = data["quality"].apply(taste)

# %%
new_data
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  taste
# 0         9.4        5      0
# 1         9.8        5      0
# 2         9.8        5      0
# 3         9.8        6      1
# 4         9.4        5      0
# ...       ...      ...    ...
# 6492     11.2        6      1
# 6493      9.6        5      0
# 6494      9.4        6      1
# 6495     12.8        7      2
# 6496     11.8        6      1
#
# [6497 rows x 13 columns]

# %% [markdown]
# ## Divisão de base de dados e separação de base

# %%
X = new_data.iloc[:, 0:11].values
y = new_data.iloc[:, 12].values

# %%
scaler = MinMaxScaler()
scaler.fit(X)
print(scaler.data_max_)
X_normalized = scaler.transform(X)
print(X_normalized)
# Out:
# [ 15.9       1.58      1.66     65.8       0.611   289.      440.
#    1.03898   4.01      2.       14.9    ]
# [[0.29752066 0.41333333 0.         ... 0.6124031  0.19101124 0.20289855]
#  [0.33057851 0.53333333 0.         ... 0.37209302 0.25842697 0.26086957]
#  [0.33057851 0.45333333 0.02409639 ... 0.41860465 0.24157303 0.26086957]
#  ...
#  [0.2231405  0.10666667 0.11445783 ... 0.20930233 0.13483146 0.20289855]
#  [0.14049587 0.14       0.18072289 ... 0.48062016 0.08988764 0.69565217]
#  [0.18181818 0.08666667 0.22891566 ... 0.41860465 0.05617978 0.55072464]]

# %%
print("Proporções por classe no dataset em geral:")
print_distribution(y)

kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=199)
fold = 0
for train, test in kf.split(X_normalized, y):
    print("Fold %d" %(fold))
    print_distribution(y[train], print_nl=(fold != 2))
    fold += 1
# Out:
# Proporções por classe no dataset em geral:
# Classe 0: 36.69%
# Classe 1: 43.65%
# Classe 2: 19.66%
#
#
# Fold 0
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 1
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 2
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
# Fold 3
# Classe 0: 36.69%
# Classe 1: 43.66%
# Classe 2: 19.65%
#
#
# Fold 4
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 5
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 6
# Classe 0: 36.70%
# Classe 1: 43.65%
# Classe 2: 19.65%
#
#
# Fold 7
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 8
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%
#
#
# Fold 9
# Classe 0: 36.70%
# Classe 1: 43.64%
# Classe 2: 19.66%

# %%
kf_accuracy = list()
kf_conf_mat = list()
kf_precision = list()
kf_f1 = list()
kf_recall = list()
kf_roc = list()

# %%
pca = PCA(n_components=10)
enn = EditedNearestNeighbours(sampling_strategy='all', n_neighbors=1, kind_sel='all', n_jobs=-1)

# %% [markdown]
# ## Laço para execução do gridsearch em cada fold

# %%
for train_ix, test_ix in kf.split(X_normalized,y):
    X_train, X_test = X_normalized[train_ix, :], X_normalized[test_ix, :]
    y_train, y_test = y[train_ix], y[test_ix]
    X_train_res, y_train_res = enn.fit_resample(X_train, y_train)
    X_train_pca = pca.fit_transform(X_train_res)
    X_test_pca = pca.transform(X_test)  
    model = Sequential()
    model.add(Dense(units=16, activation="linear",input_dim=10))
    model.add(Dropout(0.1))
    model.add(Dense(units=16, activation="linear"))
    model.add(Dropout(0.1))
    model.add(Dense(units=3, activation="softmax"))
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["sparse_categorical_accuracy"])
    # executar treinamento do modelo
    result = model.fit(X_train_pca, y_train_res, batch_size=32, epochs=20)
    # teste dos melhores parâmetros
    predicted_y = model.predict(X_test_pca)
    predicted_y_transform = [np.argmax(t) for t in predicted_y]
    #transformação de itens para cálculo do ROC
    le = LabelEncoder()
    y_test_dummy = le.fit_transform(y_test)
    predicted_y_dummy = le.fit_transform(predicted_y_transform)
    y_test_dummy = np_utils.to_categorical(y_test)
    predicted_y_dummy = np_utils.to_categorical(predicted_y_dummy)
    # métricas do modelo
    acc = accuracy_score(y_test, predicted_y_transform)
    conf_mat = confusion_matrix(y_test, predicted_y_transform)
    f1 = f1_score(y_test, predicted_y_transform, average = "macro")
    recall = recall_score(y_test, predicted_y_transform, average = "macro")
    roc = roc_auc_score(y_test_dummy,predicted_y_dummy,multi_class="ovo",average = "macro")
    #armazenamento de métricas
    kf_accuracy.append(acc)
    kf_conf_mat.append(conf_mat)
    kf_f1.append(f1)
    kf_recall.append(recall)
    kf_roc.append(roc)
    #métricas
    print(">acc=%.4f,>f1=%.4f,>rec=%.4f,>roc=%.4f" % (acc,f1,recall,roc))
    print(conf_mat)
# Out:
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 0.9878 - sparse_categorical_accuracy: 0.5180
# Epoch 2/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8566 - sparse_categorical_accuracy: 0.6005
# Epoch 3/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8157 - sparse_categorical_accuracy: 0.6229
# Epoch 4/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8095 - sparse_categorical_accuracy: 0.6269
# Epoch 5/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8027 - sparse_categorical_accuracy: 0.6264
# Epoch 6/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8023 - sparse_categorical_accuracy: 0.6272
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7988 - sparse_categorical_accuracy: 0.6219
# Epoch 8/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8014 - sparse_categorical_accuracy: 0.6234
# Epoch 9/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8023 - sparse_categorical_accuracy: 0.6214
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7998 - sparse_categorical_accuracy: 0.6239
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8015 - sparse_categorical_accuracy: 0.6232
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8022 - sparse_categorical_accuracy: 0.6264
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7993 - sparse_categorical_accuracy: 0.6319
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7961 - sparse_categorical_accuracy: 0.6262
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7961 - sparse_categorical_accuracy: 0.6272
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7964 - sparse_categorical_accuracy: 0.6334
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7976 - sparse_categorical_accuracy: 0.6239
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7958 - sparse_categorical_accuracy: 0.6257
# Epoch 19/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7966 - sparse_categorical_accuracy: 0.6262
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7944 - sparse_categorical_accuracy: 0.6272
# >acc=0.5631,>f1=0.5326,>rec=0.5228,>roc=0.6415
# [[153  84   2]
#  [ 73 172  38]
#  [  4  83  41]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 0.9644 - sparse_categorical_accuracy: 0.5507
# Epoch 2/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8457 - sparse_categorical_accuracy: 0.6016
# Epoch 3/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8184 - sparse_categorical_accuracy: 0.6066
# Epoch 4/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8128 - sparse_categorical_accuracy: 0.6106
# Epoch 5/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8065 - sparse_categorical_accuracy: 0.6183
# Epoch 6/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8009 - sparse_categorical_accuracy: 0.6238
# Epoch 7/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8029 - sparse_categorical_accuracy: 0.6133
# Epoch 8/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8043 - sparse_categorical_accuracy: 0.6223
# Epoch 9/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8043 - sparse_categorical_accuracy: 0.6161
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8049 - sparse_categorical_accuracy: 0.6257
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8036 - sparse_categorical_accuracy: 0.6148
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8032 - sparse_categorical_accuracy: 0.6180
# Epoch 13/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8001 - sparse_categorical_accuracy: 0.6153
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7993 - sparse_categorical_accuracy: 0.6220
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8050 - sparse_categorical_accuracy: 0.6131
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8031 - sparse_categorical_accuracy: 0.6161
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8040 - sparse_categorical_accuracy: 0.6203
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8017 - sparse_categorical_accuracy: 0.6208
# Epoch 19/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7987 - sparse_categorical_accuracy: 0.6200
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7987 - sparse_categorical_accuracy: 0.6210
# >acc=0.5738,>f1=0.5285,>rec=0.5180,>roc=0.6400
# [[139  95   5]
#  [ 62 200  21]
#  [  6  88  34]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 1.0054 - sparse_categorical_accuracy: 0.5066
# Epoch 2/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8514 - sparse_categorical_accuracy: 0.6013
# Epoch 3/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8131 - sparse_categorical_accuracy: 0.6137
# Epoch 4/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8035 - sparse_categorical_accuracy: 0.6177
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8040 - sparse_categorical_accuracy: 0.6187
# Epoch 6/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8005 - sparse_categorical_accuracy: 0.6314
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8007 - sparse_categorical_accuracy: 0.6214
# Epoch 8/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8036 - sparse_categorical_accuracy: 0.6219
# Epoch 9/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7991 - sparse_categorical_accuracy: 0.6222
# Epoch 10/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8001 - sparse_categorical_accuracy: 0.6212
# Epoch 11/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7944 - sparse_categorical_accuracy: 0.6269
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8019 - sparse_categorical_accuracy: 0.6259
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7991 - sparse_categorical_accuracy: 0.6209
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7998 - sparse_categorical_accuracy: 0.6271
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7976 - sparse_categorical_accuracy: 0.6269A: 0s - loss: 0.7950 - sparse_categorical_accuracy: 0.630
# Epoch 16/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7945 - sparse_categorical_accuracy: 0.6311
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7949 - sparse_categorical_accuracy: 0.6257
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7996 - sparse_categorical_accuracy: 0.6252
# Epoch 19/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7991 - sparse_categorical_accuracy: 0.6244
# Epoch 20/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7999 - sparse_categorical_accuracy: 0.6271
# >acc=0.5846,>f1=0.5554,>rec=0.5432,>roc=0.6569
# [[158  80   1]
#  [ 78 179  26]
#  [ 10  75  43]]
# Epoch 1/20
# 127/127 [==============================] - 1s 2ms/step - loss: 0.9645 - sparse_categorical_accuracy: 0.5398
# Epoch 2/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8598 - sparse_categorical_accuracy: 0.5963
# Epoch 3/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8258 - sparse_categorical_accuracy: 0.6030
# Epoch 4/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8154 - sparse_categorical_accuracy: 0.6107
# Epoch 5/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8099 - sparse_categorical_accuracy: 0.6156
# Epoch 6/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8110 - sparse_categorical_accuracy: 0.6195
# Epoch 7/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8076 - sparse_categorical_accuracy: 0.6247
# Epoch 8/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8055 - sparse_categorical_accuracy: 0.6173
# Epoch 9/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8073 - sparse_categorical_accuracy: 0.6161
# Epoch 10/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8013 - sparse_categorical_accuracy: 0.6218
# Epoch 11/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8041 - sparse_categorical_accuracy: 0.6210
# Epoch 12/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8062 - sparse_categorical_accuracy: 0.6250A: 0s - loss: 0.8067 - sparse_categorical_accuracy: 0.624
# Epoch 13/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8004 - sparse_categorical_accuracy: 0.6235
# Epoch 14/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8085 - sparse_categorical_accuracy: 0.6166
# Epoch 15/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8055 - sparse_categorical_accuracy: 0.6198
# Epoch 16/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8014 - sparse_categorical_accuracy: 0.6181
# Epoch 17/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8047 - sparse_categorical_accuracy: 0.6181
# Epoch 18/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8032 - sparse_categorical_accuracy: 0.6186
# Epoch 19/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8020 - sparse_categorical_accuracy: 0.6190
# Epoch 20/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8035 - sparse_categorical_accuracy: 0.6195
# >acc=0.5785,>f1=0.5361,>rec=0.5249,>roc=0.6449
# [[148  90   1]
#  [ 65 193  25]
#  [  5  88  35]]
# Epoch 1/20
# 125/125 [==============================] - 1s 2ms/step - loss: 0.9971 - sparse_categorical_accuracy: 0.4880
# Epoch 2/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8699 - sparse_categorical_accuracy: 0.5833
# Epoch 3/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8286 - sparse_categorical_accuracy: 0.6048
# Epoch 4/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8123 - sparse_categorical_accuracy: 0.6118
# Epoch 5/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8091 - sparse_categorical_accuracy: 0.6211
# Epoch 6/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8088 - sparse_categorical_accuracy: 0.6201
# Epoch 7/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8025 - sparse_categorical_accuracy: 0.6263
# Epoch 8/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8074 - sparse_categorical_accuracy: 0.6201
# Epoch 9/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8056 - sparse_categorical_accuracy: 0.6236
# Epoch 10/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8035 - sparse_categorical_accuracy: 0.6313
# Epoch 11/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8029 - sparse_categorical_accuracy: 0.6256
# Epoch 12/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8049 - sparse_categorical_accuracy: 0.6173
# Epoch 13/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8044 - sparse_categorical_accuracy: 0.6253
# Epoch 14/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8097 - sparse_categorical_accuracy: 0.6243
# Epoch 15/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8048 - sparse_categorical_accuracy: 0.6163
# Epoch 16/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8050 - sparse_categorical_accuracy: 0.6278
# Epoch 17/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8017 - sparse_categorical_accuracy: 0.6191
# Epoch 18/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8032 - sparse_categorical_accuracy: 0.6241
# Epoch 19/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8042 - sparse_categorical_accuracy: 0.6251
# Epoch 20/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8042 - sparse_categorical_accuracy: 0.6238
# >acc=0.5662,>f1=0.5229,>rec=0.5139,>roc=0.6367
# [[147  90   1]
#  [ 65 187  32]
#  [  8  86  34]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 0.9888 - sparse_categorical_accuracy: 0.5368
# Epoch 2/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8623 - sparse_categorical_accuracy: 0.5926
# Epoch 3/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8250 - sparse_categorical_accuracy: 0.6108
# Epoch 4/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8147 - sparse_categorical_accuracy: 0.6181
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8138 - sparse_categorical_accuracy: 0.6146
# Epoch 6/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8100 - sparse_categorical_accuracy: 0.6126
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8133 - sparse_categorical_accuracy: 0.6151
# Epoch 8/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8116 - sparse_categorical_accuracy: 0.6163
# Epoch 9/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8114 - sparse_categorical_accuracy: 0.6185
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8126 - sparse_categorical_accuracy: 0.6121
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8145 - sparse_categorical_accuracy: 0.6168
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8113 - sparse_categorical_accuracy: 0.6171
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8125 - sparse_categorical_accuracy: 0.6121
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8072 - sparse_categorical_accuracy: 0.6188
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8118 - sparse_categorical_accuracy: 0.6195
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8107 - sparse_categorical_accuracy: 0.6128
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8091 - sparse_categorical_accuracy: 0.6156
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8084 - sparse_categorical_accuracy: 0.6133
# Epoch 19/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8063 - sparse_categorical_accuracy: 0.6188
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.8077 - sparse_categorical_accuracy: 0.6195
# >acc=0.5862,>f1=0.5582,>rec=0.5448,>roc=0.6578
# [[153  82   3]
#  [ 75 184  25]
#  [  5  79  44]]
# Epoch 1/20
# 127/127 [==============================] - 1s 2ms/step - loss: 0.9703 - sparse_categorical_accuracy: 0.5478
# Epoch 2/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8520 - sparse_categorical_accuracy: 0.5954
# Epoch 3/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8206 - sparse_categorical_accuracy: 0.6147
# Epoch 4/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8167 - sparse_categorical_accuracy: 0.6120
# Epoch 5/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8100 - sparse_categorical_accuracy: 0.6177
# Epoch 6/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8090 - sparse_categorical_accuracy: 0.6145
# Epoch 7/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8120 - sparse_categorical_accuracy: 0.6182
# Epoch 8/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8092 - sparse_categorical_accuracy: 0.6155
# Epoch 9/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8027 - sparse_categorical_accuracy: 0.6256
# Epoch 10/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8087 - sparse_categorical_accuracy: 0.6189
# Epoch 11/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8062 - sparse_categorical_accuracy: 0.6212
# Epoch 12/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8091 - sparse_categorical_accuracy: 0.6162
# Epoch 13/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8048 - sparse_categorical_accuracy: 0.6194A: 0s - loss: 0.8085 - sparse_categorical_accuracy: 0.6
# Epoch 14/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8060 - sparse_categorical_accuracy: 0.6202
# Epoch 15/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8051 - sparse_categorical_accuracy: 0.6234
# Epoch 16/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8054 - sparse_categorical_accuracy: 0.6177
# Epoch 17/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8039 - sparse_categorical_accuracy: 0.6187
# Epoch 18/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8055 - sparse_categorical_accuracy: 0.6172
# Epoch 19/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8012 - sparse_categorical_accuracy: 0.6259
# Epoch 20/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8072 - sparse_categorical_accuracy: 0.6182
# >acc=0.5831,>f1=0.5653,>rec=0.5553,>roc=0.6638
# [[159  77   2]
#  [ 81 168  35]
#  [  9  67  52]]
# Epoch 1/20
# 126/126 [==============================] - 1s 2ms/step - loss: 1.0052 - sparse_categorical_accuracy: 0.5219
# Epoch 2/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8658 - sparse_categorical_accuracy: 0.6077
# Epoch 3/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8128 - sparse_categorical_accuracy: 0.6217
# Epoch 4/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.8008 - sparse_categorical_accuracy: 0.6252
# Epoch 5/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7991 - sparse_categorical_accuracy: 0.6257
# Epoch 6/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7955 - sparse_categorical_accuracy: 0.6332
# Epoch 7/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7952 - sparse_categorical_accuracy: 0.6287
# Epoch 8/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7933 - sparse_categorical_accuracy: 0.6282
# Epoch 9/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7914 - sparse_categorical_accuracy: 0.6304
# Epoch 10/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7956 - sparse_categorical_accuracy: 0.6312
# Epoch 11/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7923 - sparse_categorical_accuracy: 0.6309
# Epoch 12/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7918 - sparse_categorical_accuracy: 0.6314
# Epoch 13/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7952 - sparse_categorical_accuracy: 0.6339
# Epoch 14/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7886 - sparse_categorical_accuracy: 0.6362
# Epoch 15/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7923 - sparse_categorical_accuracy: 0.6302
# Epoch 16/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7896 - sparse_categorical_accuracy: 0.6349
# Epoch 17/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7889 - sparse_categorical_accuracy: 0.6329
# Epoch 18/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7902 - sparse_categorical_accuracy: 0.6304
# Epoch 19/20
# 126/126 [==============================] - 0s 2ms/step - loss: 0.7911 - sparse_categorical_accuracy: 0.6334
# Epoch 20/20
# 126/126 [==============================] - 0s 1ms/step - loss: 0.7873 - sparse_categorical_accuracy: 0.6347
# >acc=0.5455,>f1=0.5190,>rec=0.5072,>roc=0.6282
# [[142  90   6]
#  [ 89 171  24]
#  [ 12  74  41]]
# Epoch 1/20
# 125/125 [==============================] - 1s 2ms/step - loss: 0.9949 - sparse_categorical_accuracy: 0.5121
# Epoch 2/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8716 - sparse_categorical_accuracy: 0.6014
# Epoch 3/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8242 - sparse_categorical_accuracy: 0.6142
# Epoch 4/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8100 - sparse_categorical_accuracy: 0.6192
# Epoch 5/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8047 - sparse_categorical_accuracy: 0.6239
# Epoch 6/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8045 - sparse_categorical_accuracy: 0.6267
# Epoch 7/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8020 - sparse_categorical_accuracy: 0.6209
# Epoch 8/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.7980 - sparse_categorical_accuracy: 0.6349
# Epoch 9/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8044 - sparse_categorical_accuracy: 0.6224
# Epoch 10/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.7994 - sparse_categorical_accuracy: 0.6307
# Epoch 11/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8015 - sparse_categorical_accuracy: 0.6257
# Epoch 12/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.7971 - sparse_categorical_accuracy: 0.6222
# Epoch 13/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8007 - sparse_categorical_accuracy: 0.6224
# Epoch 14/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.7988 - sparse_categorical_accuracy: 0.6242
# Epoch 15/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8004 - sparse_categorical_accuracy: 0.6267
# Epoch 16/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.7970 - sparse_categorical_accuracy: 0.6232
# Epoch 17/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.7994 - sparse_categorical_accuracy: 0.6289
# Epoch 18/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.8019 - sparse_categorical_accuracy: 0.6174
# Epoch 19/20
# 125/125 [==============================] - 0s 1ms/step - loss: 0.8003 - sparse_categorical_accuracy: 0.6259
# Epoch 20/20
# 125/125 [==============================] - 0s 2ms/step - loss: 0.7969 - sparse_categorical_accuracy: 0.6287
# >acc=0.5578,>f1=0.5205,>rec=0.5116,>roc=0.6342
# [[139  95   4]
#  [ 62 185  37]
#  [ 14  75  38]]
# Epoch 1/20
# 127/127 [==============================] - 1s 2ms/step - loss: 1.0211 - sparse_categorical_accuracy: 0.4679
# Epoch 2/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8751 - sparse_categorical_accuracy: 0.5816
# Epoch 3/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8247 - sparse_categorical_accuracy: 0.6039
# Epoch 4/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8133 - sparse_categorical_accuracy: 0.6138
# Epoch 5/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8103 - sparse_categorical_accuracy: 0.6143
# Epoch 6/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8115 - sparse_categorical_accuracy: 0.6161
# Epoch 7/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8106 - sparse_categorical_accuracy: 0.6128
# Epoch 8/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8111 - sparse_categorical_accuracy: 0.6133
# Epoch 9/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8090 - sparse_categorical_accuracy: 0.6089
# Epoch 10/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8095 - sparse_categorical_accuracy: 0.6096A: 0s - loss: 0.8089 - sparse_categorical_accuracy: 0.609
# Epoch 11/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8094 - sparse_categorical_accuracy: 0.6148
# Epoch 12/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8068 - sparse_categorical_accuracy: 0.6156
# Epoch 13/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8077 - sparse_categorical_accuracy: 0.6091
# Epoch 14/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8080 - sparse_categorical_accuracy: 0.6158
# Epoch 15/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8071 - sparse_categorical_accuracy: 0.6148
# Epoch 16/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8104 - sparse_categorical_accuracy: 0.6108
# Epoch 17/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8085 - sparse_categorical_accuracy: 0.6113
# Epoch 18/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8094 - sparse_categorical_accuracy: 0.6143
# Epoch 19/20
# 127/127 [==============================] - 0s 1ms/step - loss: 0.8071 - sparse_categorical_accuracy: 0.6235
# Epoch 20/20
# 127/127 [==============================] - 0s 2ms/step - loss: 0.8065 - sparse_categorical_accuracy: 0.6148
# >acc=0.5901,>f1=0.5536,>rec=0.5463,>roc=0.6618
# [[158  73   7]
#  [ 61 183  40]
#  [ 10  75  42]]

# %%
print("Accuracy: %.4f (%.4f)" % (np.mean(kf_accuracy), np.std(kf_accuracy)))
print("F1-score: %.4f (%.4f)" % (np.mean(kf_f1), np.std(kf_f1)))
print("Recall: %.4f (%.4f)" % (np.mean(kf_recall), np.std(kf_recall)))
print("ROC: %.4f (%.4f)" % (np.mean(kf_roc), np.std(kf_roc)))
# Out:
# Accuracy: 0.5729 (0.0137)
# F1-score: 0.5392 (0.0164)
# Recall: 0.5288 (0.0162)
# ROC: 0.6466 (0.0119)

# %%
kf_accuracy
# Out:
# [0.563076923076923,
#  0.5738461538461539,
#  0.5846153846153846,
#  0.5784615384615385,
#  0.5661538461538461,
#  0.5861538461538461,
#  0.583076923076923,
#  0.5454545454545454,
#  0.5577812018489985,
#  0.5901386748844376]

# %%
conf_mat_mean = np.mean(kf_conf_mat,axis=0)

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
plot_confusion_matrix(conf_mat_mean,["0-Bad","1-Medium","2-Good"])
plt.savefig('MLP_ENN_PCA.png', transparent=True, dpi=300, bbox_inches="tight")
# Out:
# Confusion matrix, without normalization
# [[149.6  85.6   3.2]
#  [ 71.1 182.2  30.3]
#  [  8.3  79.   40.4]]
